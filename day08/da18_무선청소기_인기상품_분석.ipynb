# %% [markdown]
# ##### 빅데이터 실습
#
# ### 다나와 {{encodeKeyword}} 상품분석
#
# #### 데이터 수집
#
# ##### 셀레니움 사용

# %%
# 필수 라이브러리 사용등록
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from urllib import parse
from tqdm import tqdm
import time

# %%
## 웹드라이브로 크롬 오픈
driver = webdriver.Chrome()
url = r'https://search.danawa.com/dsearch.php?k1=%EC%97%90%EC%96%B4%EB%A9%94%EC%9D%B4%EB%93%9C+%EC%8A%A4%EB%A7%88%ED%8A%B8%ED%83%80%EC%9B%8C&module=goods&act=dispMain'
driver.get(url)
time.sleep(5)

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
prodItems = soup.select('ul.product_list > li.prod_item')

# %%
len(prodItems)
# Out:
# 9

# %%
prodItems[0].select('p.prod_name > a')[0].text.strip()
# Out:
# '에어메이드 스마트타워 AMC-3501A'

# %%
prodItems[0].select('div.spec_list')[0].text.strip().replace('\t', '')
# Out:
# '핸디스틱청소기 / 무선 / 흡입형 / 흡입력: 370W / 2024년형 / [구성] 먼지비움 / 충전 / UVC LED / 브러쉬: 바닥 / 침구 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 40분(최대) / 충전시간: 5시간 / 분리형(1개) / 2500mAh / [청소] LED라이트 / BLDC모터 / [부가] 디스플레이표시 / 헤파필터 / 색상: 화이트 / 무게: 2.5kg / 크기(가로x세로x깊이): 252x1253x185mm'

# %%
# 만약에 수가 아닌 문자열 들어왔을때는 False
prodItems[0].select('input')[1].get('value').isdecimal()
# Out:
# False

# %% [markdown]
# #### 다나와 무선청소기 웹크롤링 다시
# - 가격외에는 안들어오도록 변환

# %%
def getSearchPageUrl(keyword, page):
        ecKeyword = parse.quote(keyword)
        url = f'https://search.danawa.com/dsearch.php?query={ecKeyword}&originalQuery={ecKeyword}&previousKeyword={ecKeyword}&checkedInfo=N&volumeType=allvs&' + \
                f'page={page}&limit=120&sort=saveDESC&list=list&boost=true&tab=goods&addDelivery=N&coupangMemberSort=N&mode=simple&isInitTireSmartFinder=N&' + \
                'recommendedSort=N&defaultUICategoryCode=10325109&defaultPhysicsCategoryCode=72%7C80%7C81%7C0&defaultVmTab=3138&defaultVaTab=1098867&isZeroPrice=Y&' + \
                'quickProductYN=N&priceUnitSort=N&priceUnitSortOrder=A'
        return url

# %%
## 상품정보 추출하는 함수
def getProdItems(prodItems):
    prodData = []

    for prodItem in prodItems:
        try:
            prodName = prodItem.select('p.prod_name > a')[0].text.strip() # 상품명 가져오기
            specList = prodItem.select('div.spec_list')[0].text.strip().replace('\t','') #상품 스펙목록 가져오기
            if prodItem.select('input')[1].get('value').isdecimal() == True:
                price = prodItem.select('input')[1].get('value') # 최저가 가져오기
            else:
                price = 0 # 문자열 들어온것 막음
                
            prodData.append([prodName, specList, price])
        except:
            pass
        
    return prodData

# %%
## 여러페이지 검색 후 크롤링하는 작업
driver = webdriver.Chrome()
# 암묵적으로 웹 자원 로드를 위해 3초정도 대기
driver.implicitly_wait(3.0)

keyword = '무선청소기'
startPage = 1
totalPage = 20
prodDataTotal = [] # 최종적으로 저장할 리스트

for page in tqdm(range(startPage, totalPage+1)):
    # 검색 페이지 이동
    url = getSearchPageUrl(keyword, page)
    driver.get(url)
    # 페이지 로딩이 완료될때까지 5초간 대기
    time.sleep(5)
    
    # 현재 페이지 HTML 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    
    # 상품정보 추출
    prodItems = soup.select('ul.product_list > li.prod_item')
    prodItemList = getProdItems(prodItems) # 리스트로 추출하는 함수
    
    # 추출된 정보를 prodDataTotal 추가
    prodDataTotal += prodItemList
# Out:
# 100%|██████████| 20/20 [03:13<00:00,  9.66s/it]

# %%
dfProdData = pd.DataFrame(prodDataTotal)

# %%
dfProdData.columns = ['제품명','제품스펙','최저가']

# %%
dfProdData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2120 entries, 0 to 2119
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     2120 non-null   object
#  1   제품스펙    2120 non-null   object
#  2   최저가     2120 non-null   object
# dtypes: object(3)
# memory usage: 49.8+ KB

# %%
dfProdData.to_excel('./data/다나와_무선청소기_결과.xlsx', index = False)

# %% [markdown]
# ## 크롤링 데이터 전처리

# %%
# 저장한 엑셀을 재로드
dfProdDanawa = pd.read_excel('./data/다나와_무선청소기_결과.xlsx')
dfProdDanawa.tail()
# Out:
#                                                 제품명  \
# 2115                      미니센 무선 소형 청소기 MNC-100 먼지통
# 2116               프리라벨 2in1 무선 진공 청소기 LS-2000 헤파필터
# 2117  상품상세설명 참조 캐치웰 텀블러 디자인 초경량 무선 핸디형 진공청소기_아이언그레이
# 2118                                포쉬 워시젯 V2 WJ200
# 2119                                    업킵 MJ-BC779
#
#                                                    제품스펙     최저가
# 2115                                       차량용청소기 / 먼지통    7000
# 2116                            차량용청소기 / 필터 / [필터] 헤파필터    3500
# 2117                                                NaN       0
# 2118  침구청소기 / 핸디형 / 무선 / 사용시간: 25분(최대) / [기능] 청소모드: ...  219000
# 2119  침구청소기 / 핸디형 / 무선 / [기능] 청소모드: UV살균 / 속도조절 / 헤파...   89900

# %%
dfProdDanawa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2120 entries, 0 to 2119
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     2120 non-null   object
#  1   제품스펙    2110 non-null   object
#  2   최저가     2120 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 49.8+ KB

# %%
# 결측치 검색
condition = dfProdDanawa['제품스펙'].isnull() == True

# %%
dfProdDanawa[condition]
# Out:
#                                                     제품명 제품스펙  최저가
# 1846  스팀청소기 샤오미 무선 휴대용 자동차 진공 청소기 스마트 홈 흡입 및 블로잉 다기능...  NaN    0
# 1861      상품상세설명 참조 캐치웰 텀블러 디자인 초경량 무선 핸디형 진공청소기_아이언그레이  NaN    0
# 1910  스팀청소기 샤오미 무선 휴대용 자동차 진공 청소기 스마트 홈 흡입 및 블로잉 다기능...  NaN    0
# 1925      상품상세설명 참조 캐치웰 텀블러 디자인 초경량 무선 핸디형 진공청소기_아이언그레이  NaN    0
# 1974  스팀청소기 샤오미 무선 휴대용 자동차 진공 청소기 스마트 홈 흡입 및 블로잉 다기능...  NaN    0
# 1989      상품상세설명 참조 캐치웰 텀블러 디자인 초경량 무선 핸디형 진공청소기_아이언그레이  NaN    0
# 2038  스팀청소기 샤오미 무선 휴대용 자동차 진공 청소기 스마트 홈 흡입 및 블로잉 다기능...  NaN    0
# 2053      상품상세설명 참조 캐치웰 텀블러 디자인 초경량 무선 핸디형 진공청소기_아이언그레이  NaN    0
# 2102  스팀청소기 샤오미 무선 휴대용 자동차 진공 청소기 스마트 홈 흡입 및 블로잉 다기능...  NaN    0
# 2117      상품상세설명 참조 캐치웰 텀블러 디자인 초경량 무선 핸디형 진공청소기_아이언그레이  NaN    0

# %%
## 결측치가 있는 행(row)을 삭제
dfProdDanawa = dfProdDanawa.dropna(axis=0)

# %%
condition = dfProdDanawa['최저가'] == 0

# %%
# 최저가가 0인 제품을 제외한 나머지
dfProdDanawa = dfProdDanawa[condition == False]

# %%
# 행들이 삭제되면서 인덱스가 꼬임. 인덱스 초기화
dfProdDanawa.reset_index(drop=True, inplace=True)

# %%
# 결측치, 이상치를 제거한 최종 DF
# 회사명, 모델명, 카테고리, 사용시간, 흡입력 추출한 결과도 2057개가 필수
dfProdDanawa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2057 entries, 0 to 2056
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     2057 non-null   object
#  1   제품스펙    2057 non-null   object
#  2   최저가     2057 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 48.3+ KB

# %%
# 회사명, 제품명 분리 split(' ', n) n=> 자를 공백의 번호
dfProdDanawa['제품명'][:5][0].split(' ',1)
# Out:
# ['LG전자', '오브제컬렉션 코드제로 A9S AX9884']

# %%
## 회사명, 모델명 분리 시작
compList = []
modelList = []
count = 0

for temp in dfProdDanawa['제품명']:
    titles = temp.split(' ', 1) # 길이 2 배열 생성
    if(len(titles) >1):
        compList.append(titles[0])  # 회사명
        modelList.append(titles[1]) # 모델명
    else:
        compList.append('')
        modelList.append(titles[0])
        
    count += 1

# %%
len(compList)
# Out:
# 2057

# %%
modelList
# Out:
# ['오브제컬렉션 코드제로 A9S AX9884',
#  '비스포크 제트 VS20B956AX',
#  '미홀 M22',
#  '오브제컬렉션 코드제로 A9S AX9604',
#  '오브제컬렉션 코드제로 A9S AX9988',
#  '오브제컬렉션 코드제로 A9 AU9202WD',
#  '오브제컬렉션 코드제로 A9S AX9984',
#  '오브제컬렉션 코드제로 A9 AS9202WD',
#  '코드제로 A9 A912PM',
#  '비스포크 슬림 VS15A680AEG',
#  'V11',
#  '비스포크 제트 AI VS25C970DW',
#  'ED12',
#  'ALLNEW29000 PLUS',
#  '오브제컬렉션 코드제로 A9 AU9272WD',
#  '에보 파워 플러스 WV250KR2',
#  '오브제컬렉션 코드제로 A9S AX9888',
#  '싸이클론 V10',
#  'V15 디텍트 컴플리트',
#  '비스포크 제트 AI VS28C973DR',
#  '오브제컬렉션 코드제로 A9 AS9272WD',
#  '비스포크 제트 VS20B956D5',
#  '에어포스 라이트 TY6545KL',
#  'V8',
#  '오브제컬렉션 코드제로 A9 AU9402WD',
#  '오브제컬렉션 코드제로 A9S AX9674',
#  '다이애드 프로 콤보',
#  '다이애드 프로',
#  '비스포크 제트 AI VS25C972DR',
#  '오브제컬렉션 코드제로 A9 AU9472WD',
#  '코드제로 A9 AT9100SA',
#  'Well Q8 WQ81-3BSWF',
#  '디어마 VC03S',
#  'V12 오리진 컴플리트',
#  '오브제컬렉션 코드제로 A9S AU9872',
#  'V10',
#  '얼티밋홈 900 EFP91814',
#  'i30 아이타워',
#  '바로바로 MC-B250',
#  'VC7210',
#  'COCLEAN V30',
#  '비스포크 제트 VS20B956BUE',
#  '크로스웨이브 3.0 PRO 2765Z',
#  '오브제컬렉션 코드제로 A9S AX9874',
#  'WELL Q6 WQ61-1OGG',
#  '파워스틱 VS02R6512JG',
#  'SVC-K720TW',
#  '제트 VS20T92K3QD',
#  'V12 디텍트 슬림',
#  '오브제컬렉션 코드제로 A9S AX9804',
#  'AST-009 플러스',
#  'GAS18V-1',
#  '오브제컬렉션 코드제로 A9S AU9672WD',
#  '오엘라 네오스핀 OBC-AW09',
#  '오브제컬렉션 코드제로 A9S AT9201WB',
#  'NEW i20 (23년형)',
#  '오브제컬렉션 코드제로 A9S AX9974WE',
#  '에보 파워시스템 ADV CS601',
#  '오브제컬렉션 코드제로 A9S AX9888WE + M9 MO972WA',
#  'VC1003',
#  'V12s 디텍트 슬림 서브마린 컴플리트 (골드/골드)',
#  'VC10 PRO',
#  '오브제컬렉션 코드제로 A9S AX9984TE + M9 MO971WA',
#  '오브제컬렉션 코드제로 A9S AX9984WE + MO972WA',
#  '비스포크 제트 AI VS28C973IS',
#  '오브제컬렉션 코드제로 A9S AT9201WC',
#  '오브제컬렉션 코드제로 A9S AU9602WD',
#  '오브제컬렉션 코드제로 A9S AX9984GE + M9 MO972GA',
#  '오브제컬렉션 코드제로 A9 AU9402WD + MO972WA',
#  '비스포크 제트 AI VS28C973ES',
#  '오브제컬렉션 코드제로 A9 AU9572WD + M9 MO972WA',
#  'V12 디텍트 슬림 컴플리트 (골드)',
#  '오브제컬렉션 코드제로 A9S AX9984WE + M9 MO972WA + R9 RO965WB',
#  '오브제컬렉션 코드제로 A9S AX9974WE + MO972WA',
#  '오브제컬렉션 코드제로 A9S AX9804WE + M9 MO972WA',
#  'V15s 디텍트 슬림 서브마린 (옐로우/니켈)',
#  '디지털 슬림',
#  '에어포스 라이트 TY6541KM',
#  '코드제로 A9 AT9170IA',
#  '오브제컬렉션 코드제로 A9S AX9884GE + M9 MO972GA + R9 RO965GB',
#  '오브제컬렉션 코드제로 A9S AX9604WE + 에어로퍼니처(원형) AS062PWHAR',
#  '오브제컬렉션 코드제로 A9S AX9888WE + M9 MO972WA +R9 RO965WB',
#  '오브제컬렉션 코드제로 A9S AX9804WE + M9 MO972WA + R9 RO965WB',
#  '비스포크 제트 VS20B957F5',
#  '오브제컬렉션 코드제로 A9S AX9884TE + M9 MO972WA + R9 RO965WB',
#  '비스포크 제트 VS20B957E5',
#  'ED11',
#  'G040 Ver.4',
#  '오브제컬렉션 코드제로 A9 AU9572WD',
#  'ED20 PRO',
#  'TW100 매직타워',
#  'V10 플러피 오리진',
#  '비스포크 제트 VS20C954AQB',
#  'V15 오리진 컴플리트',
#  '오브제컬렉션 코드제로 A9S AU9882',
#  'Shunzao H100 Pro',
#  '마이크로 1.5kg SV21',
#  '올인원 컴팩트',
#  'Jet 60 Flex',
#  '디어마 DEM-T30W',
#  '엑스퍼트 3.60 TY6974',
#  'SVC-BS06KP',
#  'ALLNEW22000 (22년형)',
#  '비스포크 제트 VS30D973HR',
#  '옴니 글라이드',
#  'CV6 PLUS',
#  '윈드포스 F9',
#  'ZET-10',
#  '코드제로 A9 Air AS9000WR',
#  'WELL Q6 WQ61-1EDB',
#  'VC903MF',
#  'IQ+ IW3241KR',
#  '비스포크 제트 VS20A957E3',
#  '비스포크 제트 VS20A956A3',
#  '클래파 BVC-H10',
#  'V15 오리진 플러피',
#  'THC-1000',
#  'DCL180Z',
#  '비스포크 슬림 VS15A680DFW',
#  'Gen5 디텍트 컴플리트',
#  'SVC-S380IM',
#  '얼티밋홈 900 EFP91813',
#  '비스포크 제트 VS20B957D4',
#  '엑스나노 TY1131KO',
#  'V12s 디텍트 슬림 서브마린 (옐로/니켈)',
#  'NEW i20 (21년형)',
#  'HCV-B290',
#  '에보 파워 시스템 IQ CS851 AED',
#  '비스포크 슬림 VS15A680AEW',
#  'V11 앱솔루트',
#  'ALLNEW22000+',
#  '유핀 M3',
#  'V12s 오리진 서브마린',
#  'V15s 디텍트 슬림 서브마린 컴플리트 (골드/골드)',
#  '에이센스 VC234 MJ35-7S20',
#  '인스퓨어 파워클론 CVC-AME1420UG',
#  '스마트포스 AMC-3500',
#  '파워클론 CVC-AE1420',
#  '미지아 K10',
#  'i20 엘리트',
#  'DEX-EV7000',
#  'V10 앱솔루트',
#  '미지아 MJXCQ01DY',
#  '블랙스완 트윈브러쉬 SWX1',
#  '코드제로 A9 Air AS9000HR',
#  'V12 디텍트 슬림 컴플리트 (옐로/니켈)',
#  'ALLNEW29000',
#  '엑스나노 TY1133KO',
#  'DWVC-DC9180KP',
#  'THE NEW',
#  '비스포크 제트 VS20B956AUE',
#  'SVC-S500YT',
#  '홈플래닛 858B-DC',
#  'SVC-R60BCK',
#  'V1 퍼펙트 케어',
#  '40V MAX BSV4020AS',
#  'SVC-S4800SJ',
#  '유니버셜브러쉬',
#  'G10',
#  '에르고라피도 파워프로 ZB3416AK',
#  '오브제컬렉션 코드제로 A9 AU9202WD + M9 MO972WA',
#  '듀얼클린 2in1 BVMC-22W',
#  '비스포크 제트 VS20B957D5',
#  'V3',
#  'VC10',
#  '트리플 플러스 HSBC-6000W',
#  '엑스퍼트 6.60 TY6831',
#  'Well Q8 WQ81-3OMBF',
#  '미니멀 투인원 MT7',
#  '비스포크 제트 VS30D973JS',
#  '비스포크 제트 AI VS28C973GSK',
#  'M20 BR-611XLDC',
#  'WELL Q7 WQ71-2OIBF',
#  'TPV1820RAC',
#  'SVC-PB732DG',
#  '비스포크 제트 AI VS25C972HR',
#  'CVC-B1020UG',
#  'EKV-P500',
#  'naVee NV92-ECL77',
#  'DCL181',
#  '메이블 슬림라이트 AS-A220',
#  'AUTO17000',
#  '에어포스 라이트 TY6544',
#  'C10 PRO',
#  '얼티밋홈 700 EFS71423',
#  '비스포크 제트 VS30D973IS',
#  'THC3000',
#  '오브제컬렉션 코드제로 A9S AX958A',
#  'SVC-599WS',
#  'SVC-499WS',
#  '엑스포스 8.60 라이트 TY9635',
#  'XJC-C030',
#  'SVC-K7500P',
#  'V8 플러피',
#  'AST-009 메가',
#  '제트 VS15A6031N5',
#  '에어포스360라이트 TY5510',
#  'V10 플러피',
#  '엑스콤보 GF3039',
#  '제우스 i30',
#  'ZB3512IG',
#  'W400',
#  '비스포크 제트 VS20B956D2C',
#  'CM6+',
#  '파워클론 CVC-B1010UG',
#  '에어본 VC-PS86',
#  '에보 파워시스템 IQ CS851',
#  'T12 Plus Rinse',
#  '트리플 플러스 2.0 QNBC-6000W',
#  '에르고라피도 ZB3511DB',
#  '오브제컬렉션 코드제로 A9S AX958',
#  '오브제컬렉션 코드제로 A9S AU9982',
#  '얼티밋홈 900 EFP91822',
#  'SVC-RK200WS',
#  '욕실청소기 BPLD01',
#  '제트 VS15A6031N5AA',
#  'H12',
#  '뉴 오비큠 (2022년형)',
#  'V15 디텍트 앱솔루트 엑스트라',
#  'VH-400WT',
#  '디어마 DX115C',
#  '옴니 글라이드 컴플리트',
#  'SVC-H4000BBT',
#  'GSC-1993',
#  'WELL Q7 WQ71-2BSWF',
#  'SVC-PB220WU',
#  'SVC-DC2200SK',
#  '에르고라피도 ZB3104',
#  'ZL-274H',
#  'Elite 3',
#  'SVC-T8000KP',
#  '이오니카 4in1',
#  '더 퀸 익스트림 V11 LHN-V8200',
#  '스마트타워 AMC-3501A',
#  'LCZ858',
#  'HV-5099',
#  '에르고라피도 ZB3316AK',
#  '코드제로 A9 A9100S',
#  '비스포크 슬림 VS15A680AF',
#  '엑스퍼트 3.60 TY6921',
#  '인스퓨어 파워클론 CVC-AME1410UG',
#  '마카롱 M20',
#  'S3',
#  'THE VACUUM WELFIN-002',
#  '벤투스 아쿠아 멀티플',
#  '보아르 워시스핀 VCL-030WH',
#  '코드제로 A9S AT9270',
#  'NSVA315J',
#  'CX PRO 매직타워',
#  '에어포스360 라이트 이지 TY5520',
#  '40V MAX CL003GZ09',
#  '올인원 UV',
#  'CV9',
#  '3in1 레트로 NMV241L',
#  '비스포크 제트 VS20A957D2',
#  '오브제컬렉션 코드제로 A9S AO9571',
#  'SVC-P6000HP',
#  'HV-5088',
#  '충전식 무선 욕실청소기',
#  '비스포크 제트 AI VS25C970D2C',
#  '유핀 CL99',
#  '얼티밋홈 700 EFS71436',
#  '클린백 프로 HMV-2000W',
#  'DM-FC1001',
#  '에보 파워 플러스 WV260KR',
#  '보아르 포스 D14',
#  '인스퓨어 파워클론 CVC-AME1420NW',
#  '아쿠아 진공 X100',
#  '엑스포스 8.60 라이트 TY9676',
#  'V12',
#  'VO2000PG',
#  '코드제로 A9S AT9271',
#  'UVC-1990',
#  'MC-A10',
#  '익스트림 X10',
#  'DEX-EV5000',
#  'DW200',
#  'H12S',
#  '코드제로 A9 A9100N',
#  '투인원 KVC-2894',
#  '에어포스360 라이트 이센셜 TY5530',
#  '마하 V1 울트라',
#  '디지털 슬림 컴플리트',
#  '에르고라피도 베드프로 ZB3323BO',
#  'V11 파워 300W',
#  'DVA320BF',
#  '얼티밋홈 700 라이트 EFP71522',
#  '미홀 K11',
#  '스톰파워 V25000',
#  'OA-CL010',
#  'LT-124',
#  '엑스퍼트 3.60 TY6935',
#  'OG-20',
#  '미지아 B201CN',
#  '솔러스에어 AIR651V',
#  '퓨어 Q9 PQ91-2OG',
#  '디지털 슬림 플러피 플러스',
#  '코드제로 A9S AS9200BA',
#  '에어포스360 라이트 아쿠아 TY5584',
#  'NF8',
#  'V9',
#  'L7',
#  '얼티밋홈 900 EFP91814WH',
#  'SVC-K820TW',
#  '홈플래닛 무선 욕실청소기 1503',
#  '스마트클린 DWVC-420SG',
#  '코너리스 HCBC-1250',
#  'SVC-DC2000PK',
#  '얼티밋홈 900 EFP91835',
#  '에르고라피도 ZB3311',
#  '하우리즈 NS-WVCC03',
#  '에어포스360 라이트 아쿠아 TY-5588KS',
#  '에어슬림',
#  '코드제로 A9S AT9200BA',
#  'TPD1420',
#  '퓨어 F9 PF91-5OGF',
#  '하우리즈 NS-WVCA02',
#  'V8 오리진',
#  'L40',
#  '코드제로 A9S AT9471',
#  '파인포스 DP-895VC',
#  '비스포크 제트 VS20A956AVW',
#  '더 클리너 C01B',
#  'D18 플러스',
#  '파워클론 CVC-AE1410',
#  'V8 앱솔루트',
#  'eufy H30',
#  'H5',
#  '벤투스 아쿠아 프로',
#  '노브랜드 2in1 CVL-N2001',
#  'PV1420MEXT',
#  '스마트포스 라이트 AMC-2700L',
#  '듀얼 글라이드 360 P11',
#  '디지털 슬림 플러피 오리진',
#  'T10',
#  '제트 VS20T92P7SF',
#  '유핀 M2',
#  'D10',
#  '하이그로시 미니 SVC-B880',
#  'T12 Pro Rinse',
#  '메나르 T11 MATE',
#  'VC2206',
#  '옴니 글라이드 컴플리트 플러스',
#  'IW2241KR',
#  '스톰파워 V31000',
#  '몽땅 BVC201',
#  'SVC-8858PNX',
#  '에어포스360 라이트 아쿠아 TY5586',
#  '제트 VS15R8547Q1',
#  'COMS 휴대용 미니 NE875',
#  'V38 스페셜 에디션',
#  '5in1 다용도 무선 청소기',
#  'ALLNEW22000',
#  'TPD1810BGEXT',
#  'T20',
#  'P10 Pro',
#  '파인포스 DP-890VC',
#  '비스포크 제트 VS20A957D3',
#  '퓨어 Q9 파워프로 PQ92-3BWF',
#  '에어포스 라이트 TY6547KM',
#  'DCL182ZW',
#  '솔러스에어 AIR651VW',
#  '디어마 VC20 PLUS',
#  'SMA-BL2000',
#  '비스포크 제트 VS20A956E3',
#  'DCL281FZW',
#  'T12 Home Extra',
#  '글래스 백',
#  'XJC-Y010',
#  '스마트포스 터보 AMC-3000T',
#  'FC5 코드리스',
#  'DCL180RTE',
#  '브리즈 QNCV-N6000',
#  '마이크로 1.5kg',
#  '퓨어 Q9 파워프로 PQ92-3OBF',
#  '스톰건 V12 VC-R201',
#  'D18',
#  '전동 청소솔',
#  '이지에 YE-01',
#  '20V MAX TBSV2020S',
#  '얼티밋홈 900 EFP91825',
#  '비스포크 제트 AI VS25C970DWG + VR50C95A46A',
#  '엑스퍼트 3.60 TY6938',
#  'ATIVA 데스크 미니 청소기',
#  '파워쎈',
#  'V7 플러피',
#  'V20 BCVM-115GR',
#  'H7',
#  '일루젠 알파 GTLVC-2500',
#  '비스포크 제트 VS20B957E4',
#  '올인원뉴',
#  'TROUVER SOLO10',
#  'TSX-25000A',
#  '엑스퍼트 3.60 플러피 TY6963',
#  'V25 더 퀸 앱솔루트 LHVC-N250',
#  '에어슬림 SMA-BV2200',
#  '비스포크 제트 AI VS25C972DRS + VR50C95A46S',
#  '더 데일리 HNZ-X5000RV',
#  'V15 디텍트',
#  'GN-RV19A',
#  'V10',
#  'ST-6655',
#  'L30',
#  'M500 퀀텀',
#  'SWDK K611',
#  '엑스포스 8.60 라이트 TY9634',
#  'V8 슬림 플러피+',
#  'YK-330',
#  '크로스웨이브 X7 2832S',
#  '오딕스 욕실 청소용 브러쉬 ODIX-B100',
#  '오브제컬렉션 코드제로 A9S AO9471WKT',
#  '코드제로 A9 A978',
#  'C5',
#  '보아르 포스 D12 VCL-022BK',
#  'KHAN A15',
#  'W10 Pro B302GL',
#  'C10 PLUS',
#  'LCZ2116',
#  '2 in 1 핸디형 IMMU-VC01',
#  'WC255',
#  'AIR A5C',
#  '얼티밋홈 700 라이트 EFP71512',
#  'EWM2',
#  '엑스콤보 GF3038',
#  '코드제로 A9S A9370',
#  '멀티 유저블 GTLHVC-1000',
#  '오브제컬렉션 코드제로 A9 AU9202WD + 에어로퍼니처(원형) AS062PWHAR',
#  '네오스틱 T1',
#  'H11',
#  'AMG9',
#  'M500 클래스',
#  '에르고라피도 파워프로 ZB3424BL',
#  '싹쓸이 SVC-4000BBT',
#  '스톰파워 VE12',
#  '스니커즈 클리너 GCA1000/60',
#  '에르고라피도 클래식 ZB3501EB',
#  'V8 애니멀',
#  '퓨어라이트 V9-B1',
#  'SVC-RE250KP',
#  '인스퓨어 파워클론 CVC-A1410UG',
#  '스톰건 스마트 T1',
#  '코드제로 A9 Air AS9000HRT',
#  'WELL Q8 WQ81-3PSGF',
#  '비스포크 제트 VS20A957E2',
#  'AVC-OTOA6',
#  'THE 500 플러스 AMC-4500',
#  'VC4I 코드리스 PLUS',
#  '파워스틱 VS03R6523J2',
#  '에르고라피도 파워프로 ZB3411',
#  '다용도',
#  '엑스나노 TY1134KO',
#  '트윈에어 SMA-VC2200',
#  'V8',
#  '에어포스360 에센셜',
#  '퓨어클린 멀티 슬림 TMDF-FB2a',
#  'H4',
#  'C10',
#  'SVC-C450KP',
#  '지미 JV51',
#  '솔러스에어 AIR651VG',
#  '유니버셜백 18',
#  '코드제로 A9 Air AS9000WRT',
#  'SWDK FG2020 Pro',
#  '글림 VD-VCS50WT',
#  '크로스웨이브 3.0 맥스 2765S',
#  '제트 VS20R9078S2',
#  'MO-VC7000',
#  'ZB3302AK',
#  'SVC-C106JA',
#  'V12 디텍트 슬림 앱솔루트 엑스트라',
#  '디지털 슬림 플러피 엑스트라',
#  '파워스톰 GOOD-T3',
#  '파워스틱 VS60M6010KG',
#  '하이메이드 HV-JH14G',
#  '디지털 슬림 플러피',
#  '듀얼포스 TY6751',
#  '에르고라피도 파워프로 ZB3423BO',
#  '듀얼 HEVS-D2000',
#  '전동청소솔',
#  '바로바로 슬림 MSH-220WH',
#  '홈리아 HA-17BL',
#  'W200',
#  '엑스퍼트 3.60 플러피 TY6964',
#  '오엘라 뉴 네오스핀 OA-NS03',
#  'S2',
#  'SVC-PB195BUP',
#  '올 뉴 파워스윙 SWING 8600',
#  'V11 컴플리트 플러스',
#  'PV1820CEXT',
#  '데스크청소기 무당벌레',
#  '미지아 K10 프로',
#  '제트 VS15R8543S1',
#  '슬림핏',
#  'CX11 PLUS',
#  '데스크 청소기',
#  '벤투스 아쿠아 드라이 VT_AQ_DRY',
#  '디어마 VC01',
#  'V6 헤파',
#  'QAZ-H1100',
#  'PD1810BEXT',
#  '40V MAX CL003GZ14',
#  '360도 프리무빙 스무스 DV55',
#  '하우리즈 더라이트 NS-HV1300',
#  'NE-V200',
#  'V10 앱솔루트 플러스',
#  'VBC15',
#  '크로스웨이브 맥스 올인원 2554A',
#  '리빈치 LWC-100',
#  '홈플리 HP-V2120W',
#  'AST-009 플러스 맥스',
#  'X30 프로',
#  '에이스 K9',
#  '400W',
#  '비스포크 제트 VS20A956A3P',
#  'MO-900BCL',
#  '2017-SC01',
#  '비스포크 제트 VS20B957G5',
#  'WELL Q6 WQ61-1EDBF',
#  'WELL Q7 WQ71-2OIB',
#  '얼티밋홈 700 EFS71421',
#  '몽땅 BVC201 (23년형)',
#  'SPACE C508',
#  '무선 청소기',
#  'FC9',
#  'THE 클린 HC-720BP',
#  'F803',
#  'BLDC 옵티마 BR-VC200',
#  '스톰파워 VE30',
#  '얼티메이트',
#  'MO-VC300',
#  '코드제로 A9S AS9201IB',
#  '셀프클린 WYPE B20-T',
#  'VIOMI A9 V-HWVC12A',
#  '오엘라 네오스핀 CM01',
#  '웰스톰 VC150',
#  '에이스 프로',
#  '런던필2 LF-570',
#  '리부트 29000 V9-RB1',
#  'FC7 Cordless',
#  'P10',
#  '다이애드',
#  '클래파 BFB-VC120',
#  'ZB3301',
#  'UVC-1686A',
#  '인스퓨어 파워클론 CVC-A1420UG',
#  'FC3D 코드리스',
#  '제트 VS15R8543S1CW',
#  '제트 VS20T9278S7',
#  'V11 컴플리트',
#  'BBHL2181KR',
#  'A10 HNZ-XC505V',
#  '트라이플렉스 HX2',
#  'VO1000PG',
#  'Well Q6 Pet WQ61-1PSH',
#  'SVC-80SHI',
#  '얼티밋홈 700 EFS71425WH',
#  '오브제컬렉션 코드제로 A9S AU9872MPD',
#  '롤링 2세대 5 IN 1',
#  '아토케어 EP450',
#  'GNOVC2',
#  '옴니 글라이드 플러스',
#  'V10 플러스',
#  'SS4PN',
#  '오브제컬렉션 코드제로 A9S AX9884WE + AS153HWWC + HW500DAS',
#  '비스포크 제트 VS20A957F3P',
#  '제트 VS20T9218QDCC',
#  '퓨어 Q9 PQ91-3BW',
#  'F20 맥스',
#  'T6',
#  'S1 Special',
#  'BR-611XLDC',
#  '벤투스 아쿠아 맥스',
#  'SHUNZAO Z11 프로',
#  '곰돌이 책상 지우개 청소기 AMJ-MDD013',
#  '트윈파워 MAX',
#  '모어 클린 LXQV-6000',
#  'HV-1000',
#  'AVC-4600V',
#  '퓨어 Q9 파워프로 PQ92-2OGF',
#  'RS1',
#  '퓨어 F9 PF91-6BWF',
#  'VC40',
#  'BHFEA520J',
#  '제트 VS15R8500BF',
#  'D-9',
#  '파워건 VS80M8090',
#  'H155',
#  'X4',
#  'T30',
#  '미지아 라이트 MJWXCQ03DY',
#  'SVC-D170P',
#  '에르고라피도 플러스 ZB3105AK',
#  '150W 파워 H01C',
#  'KB-001',
#  'DLBC-P335NK',
#  '델핀 DPVC-5000BL',
#  '하우리즈 블랙9 NS-WV200',
#  'IK-SCP6S',
#  'VX11',
#  'M500',
#  'V8 카본파이버',
#  '메카닉 BR-SV680RC',
#  '오브제컬렉션 코드제로 A9S AS9201WC',
#  'DLBC-224NK',
#  'VC7212',
#  'S10 2세대',
#  '2 in 1 18P01',
#  '슬림 파워건 BHFEA420J',
#  'T12 Home Rinse',
#  '2세대 전동청소솔 PRO FB-B270PRO',
#  '자일렉 ZL-217RC',
#  'WC1720W',
#  '코드제로 A9S A9700',
#  '에이스 K7',
#  'WHS-100V',
#  '퓨어 Q9 PQ91-3EM',
#  'MF-7700V',
#  '스톰샷 VH806',
#  'P2',
#  '오브제컬렉션 코드제로 A9S AT9401WC',
#  'MAX200',
#  '파워클론 ATC-111',
#  'i20',
#  '아토케어 퍼펙트 에브리원 EP HANARO-100',
#  '아토만 AT-HC300',
#  '전동 청소솔',
#  '데스크청소기 버섯',
#  '휴빅 HB-2142BW',
#  '코맘스 WC0736P',
#  '코드제로 A9S AS9270IA',
#  '에어포스360 라이트 논스톱 TY5518',
#  'SVC-P950DY',
#  'ABC-romin99',
#  'BL-100',
#  '보아르 워시스핀C VCL-031WH',
#  '코드제로 A9S AS9271',
#  'BR-V108SC',
#  'GWELL-G3',
#  '파워프로 아쿠아 FC6404',
#  'CS1820T',
#  '다라이프 클린스팟 4in1 DLA-PH2000V',
#  'P3',
#  '얼티밋홈 700 라이트 EFP71523',
#  '코드제로 A9S AT9201IBB',
#  '오브제컬렉션 코드제로 A9S AU9972',
#  '제트 VS20T9259SFCS',
#  '비스포크 제트 VS20A957G3P',
#  '오엘라 네오스핀 NS02',
#  'SVC-9958PNX',
#  'SSV-G7',
#  'HV-5000',
#  'V10 카본파이버',
#  '메이드조이 MV-W300',
#  '오브제컬렉션 코드제로 A9S AS9201WB',
#  '오브제컬렉션 코드제로 A9S AT9201WBK',
#  '보아르 포스W',
#  'TROUVER POWER 11',
#  '에어포스360 플랙스프로 TY9298',
#  'K30',
#  'V10 애니멀',
#  '후버 DK-4010-TE',
#  '3 in 1',
#  '비스포크 제트 VS20A957E3P',
#  'CV6 PLUS ADDITION',
#  '에어포스 TY8846KM',
#  'W1',
#  'BVC-H12',
#  '홈마블 H80BL',
#  '제트 VS20R9043SA',
#  '롤링스턴 SVC-C1012WS',
#  '파워건 VS80M8051KL',
#  '2in1 CD-707',
#  'EL611',
#  '에보 파워 시스템 CS401KR',
#  'HCV-B450GN',
#  '제트 VS20T92K8QD',
#  '얼티밋홈 900 EFP91824BU',
#  'PRG-2020-0010',
#  'LH20',
#  '에어포스360 TY9079',
#  '바로바로 MHC-720',
#  'AVC-V100',
#  '브이클린 에어 HB-2700W',
#  'V12 slim',
#  '오브제컬렉션 코드제로 A9S AT9271',
#  'V8 플러피 오리진',
#  '트윈파워 OP-030',
#  '디어마 VC25 프로',
#  '클래파 BFB-VC160',
#  'V11 220 에어와트 CF+',
#  'BR-SV380RC',
#  'PB101',
#  '제네스 H83BL',
#  '제트 VS20T9213QDCCW',
#  'SCV-30N',
#  '코드제로 A9S A9570',
#  '파워건 VS80M8030',
#  'SVC-UB1000',
#  '데스크청소기 머깨비',
#  '데스크청소기 TC-DC1',
#  'LV-30',
#  '미홀 H17 Pro',
#  'V11 플러피+',
#  '제트 VS20R9074S2',
#  '코드제로 A9 A958A',
#  '파워건 VS80M8065K2',
#  '에르고라피도 프로 플러스 ZB3113AK',
#  '데스크탑 미니 CL-C500',
#  '아쿠아 파워S',
#  '듀얼360 클린케어 BCR-120WH',
#  'DEEP841',
#  '비스포크 제트 VS20B956D5E + VR30T85513B',
#  '에르고라피도 ZB3515ST',
#  '비스포크 제트 VS20A956A3 + 물걸레',
#  'WELL Q7 WQ71-2ESSF',
#  '바로바로 MDC-910',
#  '미지아 1C SCWXCQ02ZHM',
#  'Q10 BR-Q390RV',
#  'BVC-120RS',
#  '에어본 VC-H71',
#  'V20 BCVM-115WH',
#  'YTE-S7',
#  'H2 PLUS',
#  'iMUZ 아쿠아 클링 F1',
#  'X10 BR-H490RV',
#  '바로바로 MDC-900',
#  '욕실청소기',
#  '더블 클리너 DS-V-0191',
#  '무선 욕실 청소기 + 브러쉬 6종 세트 BBC-2201',
#  '비스포크 제트 VS20A957D3P',
#  '비스포크 제트 VS20A957D2P',
#  '초강력 무선청소기',
#  'V11 토크 드라이브+',
#  'SY-306',
#  '코드제로 A9 A948',
#  '얼티밋홈 700 라이트 EFP71512 + 익스플로어7 컴팩트 블렌더 E7CB1-53CW',
#  '360 슬림 AGC-SS360',
#  '100W 파워 A31',
#  'LH-01',
#  'SY-303',
#  '코드제로 A9 A9579',
#  '데스크청소기 너구리',
#  '트윈버드 TB70',
#  'AKBC-6000W',
#  'HKH-C250B',
#  'CM-100W',
#  '4 in 1',
#  '파워스핀 ST-9000',
#  '트라이플렉스 HX2 Pro',
#  'CV8 LIGHT',
#  '제트 VS15R8577S5',
#  'VC-K350W',
#  'D008 프로',
#  '에어포스 라이트 TY6543KL',
#  '오브제컬렉션 코드제로 A9S AO9571GAKT',
#  '코드제로 A9S AS9571',
#  '제트 VS20T9213QDCSB',
#  '엑스퍼트 3.60 TY6933',
#  '에르고라피도 프로 ZB3114AK',
#  'BLDC 무선',
#  'BTS-SC212',
#  'COCLEAN V30',
#  '얼티밋홈 900 EFP91824BR',
#  'X9',
#  'CX-2022LC',
#  '코드제로 A9S A9470',
#  '코드제로 A9 A9479',
#  '스톰 2in1 코드리스 BSHV-01',
#  '홈마블 H83BL',
#  '비스포크 제트 VS20A956AVE',
#  '코드제로 A9 A9200I',
#  '파워스윙 SWING 10000-BLDC',
#  'FC6166/01',
#  'SVC-750SG',
#  'CBL1815TP',
#  '파워풀 K9',
#  'S3',
#  '오브제컬렉션 코드제로 A9S AU9882WD + MO971WA',
#  '다용도 무선 욕실청소기',
#  '디어마 VC20 프로',
#  '리빈치 LHV-100',
#  '클로모',
#  'V11 SE',
#  '아토케어 EP-11UP',
#  'Q10',
#  '슈퍼파워 프리플러스 V3 TR-8810BL',
#  '아미코 A10',
#  '에르고라피도 베드 프로 ZB3233B',
#  '에르고라피도 ZB3112',
#  'CEB-131F',
#  '다용도 HB-807',
#  '4 in 1',
#  'PS-MVAC001',
#  '무선 욕실청소기',
#  '미지아 MJWXCQ06SZ',
#  'V12 디텍트 슬림 컴플리트 (블루/코퍼)',
#  '트라이플렉스 HX1',
#  '벤투스 멀티',
#  'WT-81',
#  '블랙홀 CA-VC1605',
#  'V11 플러피',
#  'V20 플러스',
#  '파워건 VS80M8080',
#  '에어포스 TY8841KL',
#  '미라스 MS21Y-01A',
#  '100W 파워',
#  '샤인 매직 브러쉬 3in1 ITS-K001W',
#  '오엘라 VC01',
#  '블랙파인 JYW-BP01',
#  'PLA25',
#  'V10 플러피 엑스트라',
#  'V6 코드프리 엑스트라',
#  'NKC-T77',
#  '미니 VG-VC5000',
#  '데스크청소기 동물',
#  '네오스틱 S1',
#  'SWDK-K11',
#  '제트 VS15R8543Q4',
#  '무선전동 욕실청소기',
#  'V10 카본파이버 프로',
#  '톨즈 몬스터',
#  '원더스 다이나킹 Z4',
#  '에어포스 익스트림 사일런스 TY8909',
#  'UVC-1894',
#  '뉴파워건 VS80N8083',
#  'CL107FDZW',
#  '욕실청소기 K-129',
#  'MC-NS10K-W',
#  'SVC-T990',
#  '클래파 BFB-VC170',
#  'BLDC 올인원 무선청소기',
#  '아토케어 EP-10UP',
#  '제로 QM-V200',
#  'V11 컴플리트 엑스트라',
#  'D18S',
#  '퓨어 F9 PF91-5EBF',
#  '비스포크 제트 VS20A957F3',
#  'V11 토탈클린 프로',
#  '에어쎈 EVC-A010ARD',
#  '벤투스 아쿠아',
#  '바스웰 KSC-5000',
#  '코지 HAVG-160AW',
#  '데스크청소기 자동차',
#  'A-VAC 에이백 MFV-899H',
#  '단순 파워풀 미니',
#  '에어클레버 SMA-OV2500',
#  'H11 MAX',
#  '코드제로 A9S AS9370IKT',
#  '코드제로 A9S AS9471',
#  '코드제로 A9S AS9470',
#  'SCV80',
#  'V10 앱솔루트 프로',
#  'AL-7100',
#  '코드제로 터보2.0 S87GMW',
#  'MM-X10',
#  'G80',
#  '코드제로 A9S AT9201IB',
#  '클린에어 DSG-HBWV-2200',
#  '비스포크 제트 VS20A957G3',
#  'HE-C287',
#  '허리케인 VMK-21A30E050',
#  'RVC-3000',
#  'VS-700BL (23년형)',
#  '트라이플렉스 HX1 Pro',
#  '제트 VS15R8577Q5',
#  '디지털 슬림 플러피 프로',
#  'TC-E123SBK',
#  '파워스틱 VS60K6050KW',
#  '마하 V1',
#  'YZC-110',
#  '오브제컬렉션 코드제로 A9 AU9402WD + M9 MO972WA + R9 RO965WB',
#  '원더스 다이나킹 Z24',
#  '휴빅 브이클린 HB-2802VW',
#  'V17',
#  '벤투스 V3',
#  'BS-1604-BC',
#  '큐티오리 데스크탑 진공청소기',
#  'HE-C287N',
#  '비스포크 제트 VS20B957G5U + VR50T95936U',
#  '스위트 KV-17IV',
#  '코드제로 A9S AT9300IA',
#  '제트 VS20T9258SDCC',
#  'NEW F8',
#  'IC-SLDCP6',
#  '에이스 맥스',
#  '제트 VS20R9078S3',
#  'SVJ520BFSP',
#  '무선미니청소기',
#  '오브제컬렉션 코드제로 A9S AX9984WE + R5 R585WKA',
#  '오브제컬렉션 코드제로 A9S AX9884WE + AS283DWFC + PWH8DBA',
#  '토네이도 V6 2.0',
#  '코어 프로',
#  'SVC-CO2600CP',
#  '에어맥스 Amax-1000',
#  '트라이플렉스 HX1 Cat&Dog',
#  'V200 LDVCLA200',
#  '코드제로 A9S A9300',
#  '퓨어 Q9 파워프로 PQ92-3EMF',
#  'V11 220AW 컴플리트',
#  'ST-9500',
#  '보아르 포스 B25 PRO',
#  '스톰파워 A9 플러스 S VWH9',
#  'A-10',
#  'BTS-5000',
#  'DCL280FZW',
#  '제트 VS20T9213QA',
#  'S250W',
#  'EL-GY008',
#  '코드제로 A9 A906SM',
#  'V8 플러피 플러스',
#  '제트 VS20R9044SC',
#  'IC-SLDC4',
#  'GWELL-501',
#  '퓨어 F9 PF91-6XRF',
#  '닐피스크 Handy 2-in-1 14.4V',
#  'VC-LSE91',
#  '무선욕실청소기 DS-258',
#  '디디오랩 DVC-K09WG',
#  '오브제컬렉션 코드제로 A9S AU9802WD',
#  'MV90P',
#  '더홈 ES-607VC',
#  '타이푼 DK-4010-PA',
#  '제트 VS20T9278S7CS',
#  '제트 VS15R8548S5',
#  'IC-SLDCP5',
#  '에어포스 익스트림 사일런스 TY8909 고급형',
#  '코드제로 A9 A938A',
#  '더 플라 MAW10',
#  '제트 VS15R8543Q5',
#  '크로스웨이브 펫 프로 2225N',
#  'V10 플러피 프로',
#  '에어포스360 플랙스프로 TY9471KS',
#  '퓨리타 심플 플러스 BVC-160RS',
#  '퓨어 Q9 PQ91-3OB',
#  'AL-3300NF',
#  'V10 카본파이버 플러스',
#  'SCV9',
#  'CL107FDSYW',
#  'NEW i20 (22년형)',
#  'ANA-2020WB',
#  '코드제로 이지스틱 S749IA',
#  '아이콘펫 2602S',
#  '제트 VS19R1004BF',
#  'LNMC-100',
#  'HSV-TIT-KA',
#  'CS300',
#  '이지클린 ROV',
#  'CX-222BM',
#  '데스크 청소기',
#  '파파스핀 B63-E',
#  '네오스틱 TW1200',
#  'V11 앱솔루트 프로',
#  '미니 진공 청소기',
#  'KL-8050',
#  'K7',
#  'XQ01',
#  '비스포크 제트 VS20B956D5U + VR30T85513B',
#  'MC1',
#  'V11 토탈클린',
#  'XM17',
#  '오브제컬렉션 코드제로 A9S AX9884WE + HW500DAS',
#  '휴빅 브이클린 엑스 HB-2600B',
#  'LCHA003',
#  'SVC-0422BLDC',
#  '코드제로 A9S A9470IK',
#  'DQC-DVB-KA',
#  'ZL-11RV',
#  '제트 VS20T9213QE',
#  'SVC-R185WS',
#  'HNZ-QR888VC',
#  'SVC-1019L',
#  'TY9051',
#  'VC-H70S',
#  '4 in 1',
#  'HW-OPWMF-KA',
#  '코드엑스',
#  '제트 VS20R9044SA',
#  'MHC-230',
#  '하우리즈 에이미 NS-WVCA01',
#  '40V MAX BSV4020RBLS',
#  'SMA-Z9',
#  'X10',
#  '보아르 포스 B30',
#  '홈마블 H100',
#  '아웃사이즈',
#  '오엘라 VC03',
#  'I-100',
#  '콘일렉트릭 V1',
#  '제트 VS20R9078S2CS',
#  '에어포스360 TY7233',
#  '일루젠 GTLVC-1500',
#  'ATS-100',
#  'SVC-S89WK',
#  'SVC-40SG',
#  '코드제로 A9S 펫 AS9571BPKT',
#  'DT11',
#  'EC25L',
#  '제트 VS20R9043QA',
#  '리액트 HSV-REC-KA',
#  'ST-609',
#  ...]

# %%
len(modelList)
# Out:
# 2110

# %%
# 스펙목록 데이터
specList = dfProdDanawa.loc[2000, '제품스펙'].split(' / ')

# %%
specList
# Out:
# ['핸디스틱청소기',
#  '무선',
#  '흡입+물걸레(동시)',
#  '흡입력: 250W',
#  '소비전력: 620W',
#  '2023년형',
#  '[구성] 거치대: 올인원타워',
#  '먼지비움',
#  '충전',
#  'UVC LED',
#  '액서서리수납',
#  '스탠드거치',
#  '먼지비움시간: 30초',
#  '브러쉬: 와이드바닥',
#  '물걸레: 스팀, 고온, 일반',
#  '솔형',
#  '틈새',
#  '먼지봉투: 2.5L',
#  '[배터리] 사용시간: 30분(최대)',
#  '충전시간: 4시간',
#  '분리형(2개)',
#  '리튬이온',
#  '25.2V',
#  '[청소] 싸이클론흡입',
#  'LED라이트',
#  '자동물공급',
#  '스마트인버터모터',
#  '[부가] 스마트폰제어',
#  '대화형알림창',
#  '워셔블헤파필터',
#  '5단계여과',
#  '색상: 카밍베이지',
#  '무게: 2.47kg',
#  '크기(가로x세로x깊이): 300x1120x245mm']

# %%
useTime=''
suctionPow = ''

for spec in specList:
    if '사용시간' in spec:
        useTime = spec
    elif '흡입력' in spec:
        suctionPow = spec

print(useTime.split(' ')[1].strip())
print(suctionPow.split(' ')[1].strip()) #흡입력이 없어서 ''경우는 split(':')에서 예외발생
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[126], line 10
#       7     elif '흡입력' in spec:
#       8         suctionPow = spec
# ---> 10 print(useTime.split(' ')[1].strip())
#      11 print(suctionPow.split(' ')[1].strip()) #흡입력이 없어서 ''경우는 split(':')에서 예외발생
#
# IndexError: list index out of range

# %%
dfProdDanawa.loc[0, '제품스펙']
# Out:
# '핸디스틱청소기 / 무선 / 흡입+물걸레(동시) / 흡입력: 250W / 소비전력: 620W / 2023년형 / [구성] 거치대: 올인원타워 / 먼지비움 / 충전 / UVC LED / 액서서리수납 / 스탠드거치 / 먼지비움시간: 30초 / 브러쉬: 와이드바닥 / 물걸레: 스팀, 고온, 일반 / 솔형 / 틈새 / 먼지봉투: 2.5L / [배터리] 사용시간: 30분(최대) / 충전시간: 4시간 / 분리형(2개) / 리튬이온 / 25.2V / [청소] 싸이클론흡입 / LED라이트 / 자동물공급 / 스마트인버터모터 / [부가] 스마트폰제어 / 대화형알림창 / 워셔블헤파필터 / 5단계여과 / 색상: 카밍베이지 / 무게: 2.47kg / 크기(가로x세로x깊이): 300x1120x245mm'

# %%
## 위의 테스트를 기반으로 카테고리, 사용시간, 흡입력 추출
categoryList = []
useTimeList = []
suctionPowList = []
count = 0

for spec in dfProdDanawa['제품스펙']:
    # ' / ' 로 문자열 분리
    specList = spec.split(' / ')
    # 카테고리 추출
    category = specList[0]
    categoryList.append(category)
    # 사용시간, 흡입력 추출
    useTimeVal = None
    suctionPowVal = None
    
    for temp in specList:
        if '사용시간' in temp:
            useTimeVal = temp.replace('[배터리] ', '') # 1. [배터리]가 값 오류 발생시킴
        elif '흡입력' in temp:
            suctionPowVal = temp
            
    # 끝난 다음에도 사용시간, 흡입력 = None이면 스펙에 찾을값이 없었음
    if useTimeVal != None:
        useTime = useTimeVal.split(' ')[1].strip().replace('(최대)', '') #2. (최대) 삭제
    else:
        useTime = ''
        
    if suctionPowVal!= None:
        suctionPow = suctionPowVal.split(' ')[1].strip()
    else:
        suctionPow = ''
        
    useTimeList.append(useTime)
    suctionPowList.append(suctionPow)
    count +=1

# %%
len(categoryList)
# Out:
# 2057

# %%
useTimeList
# Out:
# ['30분',
#  '1시간',
#  '',
#  '30분',
#  '1시간',
#  '1시간',
#  '30분',
#  '1시간',
#  '50분',
#  '50분',
#  '1시간30분',
#  '1시간',
#  '30분',
#  '50분',
#  '1시간',
#  '12분',
#  '30분',
#  '1시간',
#  '1시간',
#  '1시간20분',
#  '1시간',
#  '1시간',
#  '30분',
#  '1시간',
#  '1시간',
#  '30분',
#  '43분',
#  '43분',
#  '1시간',
#  '1시간',
#  '40분',
#  '53분',
#  '40분',
#  '1시간',
#  '1시간',
#  '1시간',
#  '1시간',
#  '50분',
#  '20분',
#  '10~15분',
#  '1시간',
#  '1시간',
#  '30분',
#  '30분',
#  '45분',
#  '',
#  '18분',
#  '1시간',
#  '1시간',
#  '30분',
#  '40분',
#  '42분',
#  '1시간',
#  '50분',
#  '1시간',
#  '50분',
#  '30분',
#  '60분',
#  '30분',
#  '32분',
#  '1시간',
#  '1시간',
#  '30분',
#  '30분',
#  '1시간40분',
#  '1시간',
#  '1시간',
#  '30분',
#  '1시간',
#  '1시간20분',
#  '1시간',
#  '1시간',
#  '30분',
#  '30분',
#  '30분',
#  '1시간',
#  '40분',
#  '30분',
#  '40분',
#  '30분',
#  '30분',
#  '30분',
#  '30분',
#  '1시간',
#  '30분',
#  '1시간',
#  '',
#  '57분',
#  '1시간',
#  '1시간',
#  '1시간',
#  '1시간',
#  '1시간',
#  '1시간',
#  '1시간',
#  '35분',
#  '20분',
#  '50분',
#  '40분',
#  '45분',
#  '45분',
#  '30분',
#  '40분',
#  '1시간20분(대용량배터리기준)',
#  '20분',
#  '40분',
#  '40분',
#  '',
#  '40분',
#  '45분',
#  '50분',
#  '42분',
#  '1시간',
#  '1시간',
#  '20분',
#  '1시간',
#  '28분',
#  '20분',
#  '50분',
#  '1시간10분',
#  '',
#  '1시간',
#  '1시간',
#  '40분',
#  '1시간',
#  '50분',
#  '44분',
#  '62분',
#  '50분',
#  '1시간',
#  '50분',
#  '45분',
#  '1시간',
#  '1시간',
#  '50분',
#  '35분',
#  '45분',
#  '35분',
#  '1시간5분',
#  '50분',
#  '50분',
#  '1시간',
#  '',
#  '25분',
#  '40분',
#  '1시간',
#  '48분',
#  '40분',
#  '40분',
#  '50분',
#  '1시간',
#  '9분',
#  '30분',
#  '20분',
#  '',
#  '1시간18분',
#  '9분',
#  '45분',
#  '1시간5분',
#  '48분',
#  '1시간',
#  '10분',
#  '1시간',
#  '55분',
#  '1시간',
#  '1시간40분',
#  '45분',
#  '53분',
#  '',
#  '1시간20분(대용량배터리기준)',
#  '1시간20분',
#  '30분',
#  '50분',
#  '12분',
#  '35분',
#  '1시간',
#  '33분',
#  '',
#  '',
#  '40분',
#  '50분',
#  '',
#  '30분',
#  '1시간',
#  '53분',
#  '1시간20분(대용량배터리기준)',
#  '32분',
#  '30분',
#  '10분',
#  '8~12분',
#  '45분',
#  '75분',
#  '30분',
#  '40분',
#  '40분',
#  '40분',
#  '30분',
#  '1시간',
#  '20분',
#  '40분',
#  '35분',
#  '30분',
#  '1시간',
#  '2시간30분',
#  '33분',
#  '15분',
#  '62분',
#  '1시간10분',
#  '4시간',
#  '35분',
#  '30분',
#  '1시간',
#  '1시간',
#  '22분',
#  '1시간40분',
#  '40분',
#  '30분',
#  '1시간',
#  '1시간',
#  '20분',
#  '',
#  '20분',
#  '',
#  '20분',
#  '50분',
#  '35분',
#  '35분',
#  '30분',
#  '',
#  '50분',
#  '30분',
#  '26분',
#  '35분',
#  '30분',
#  '40분',
#  '48분',
#  '40분',
#  '50분',
#  '45분',
#  '35분',
#  '30분',
#  '42분',
#  '35분',
#  '28분',
#  '',
#  '1시간',
#  '',
#  '1시간',
#  '33분',
#  '',
#  '50분',
#  '',
#  '12분',
#  '1시간',
#  '1시간',
#  '20분',
#  '40분',
#  '',
#  '1시간',
#  '50분',
#  '53분',
#  '',
#  '25분',
#  '12분',
#  '45분',
#  '35분',
#  '30분',
#  '45분',
#  '1시간30분',
#  '40분',
#  '1시간',
#  '20분',
#  '40분',
#  '45분',
#  '30분',
#  '35분',
#  '35분',
#  '50분',
#  '30분',
#  '33분',
#  '1시간22분',
#  '40분',
#  '48분',
#  '1시간10분',
#  '10분',
#  '50분',
#  '',
#  '40분',
#  '25분',
#  '4시간',
#  '45분',
#  '40분',
#  '40분',
#  '15분',
#  '50분',
#  '40분',
#  '1시간',
#  '30분',
#  '25분',
#  '60분',
#  '45분',
#  '1시간',
#  '18분',
#  '1시간40분',
#  '40분',
#  '14분',
#  '30분',
#  '1시간',
#  '48분',
#  '50분',
#  '30분',
#  '38분',
#  '1시간',
#  '11분',
#  '55분',
#  '',
#  '40분',
#  '50분',
#  '1시간',
#  '33분',
#  '1시간',
#  '30분',
#  '45분',
#  '35분',
#  '40분',
#  '20분',
#  '30분',
#  '30분',
#  '',
#  '11분',
#  '35분',
#  '30분',
#  '40분',
#  '1시간',
#  '1시간',
#  '1시간20분',
#  '35분',
#  '9분',
#  '1시간10분',
#  '50분',
#  '40분',
#  '20분',
#  '42분',
#  '',
#  '30분',
#  '30분',
#  '28분',
#  '40분',
#  '',
#  '50분',
#  '35분',
#  '40분',
#  '13분29초',
#  '1시간10분',
#  '1시간',
#  '33분',
#  '1시간',
#  '53분',
#  '30분',
#  '40분',
#  '15분',
#  '22분',
#  '40분',
#  '1시간',
#  '20분',
#  '42분',
#  '30분',
#  '57분',
#  '46분',
#  '20분',
#  '20분',
#  '',
#  '20분',
#  '53분',
#  '35분',
#  '45분',
#  '2시간',
#  '2시간',
#  '1시간',
#  '1시간',
#  '1시간',
#  '45분',
#  '',
#  '',
#  '30분',
#  '25분',
#  '1시간30분',
#  '',
#  '1시간',
#  '50분',
#  '48분',
#  '45분',
#  '45분',
#  '30분',
#  '30분',
#  '1시간',
#  '38분',
#  '1시간',
#  '35분',
#  '30분',
#  '3시간',
#  '50분',
#  '50분',
#  '40분',
#  '45분',
#  '40분',
#  '17분',
#  '30분',
#  '1시간30분',
#  '1시간',
#  '40분',
#  '',
#  '50분',
#  '50분',
#  '35분',
#  '30분',
#  '27분',
#  '20분',
#  '',
#  '30분',
#  '50분',
#  '20분',
#  '1시간',
#  '1시간',
#  '30분',
#  '1시간',
#  '30분',
#  '30분',
#  '40분',
#  '50분',
#  '48분',
#  '20분',
#  '40분',
#  '',
#  '30분',
#  '40분',
#  '',
#  '1시간',
#  '35분',
#  '35분',
#  '40분',
#  '53분',
#  '1시간',
#  '1시간',
#  '1시간',
#  '30분',
#  '',
#  '48분',
#  '30분',
#  '40분',
#  '30분',
#  '45분',
#  '28분',
#  '',
#  '',
#  '30분',
#  '20분',
#  '45분',
#  '15분',
#  '20분',
#  '40분',
#  '30분',
#  '1시간10분',
#  '30분',
#  '1시간',
#  '25분',
#  '42분',
#  '35분',
#  '1시간',
#  '40분',
#  '40분',
#  '40분',
#  '25분',
#  '40분',
#  '45분',
#  '48분',
#  '',
#  '',
#  '50분',
#  '40분',
#  '30분',
#  '45분',
#  '1시간',
#  '1시간',
#  '35분',
#  '물걸레:',
#  '1시간',
#  '12분',
#  '',
#  '1시간5분',
#  '40분',
#  '50분',
#  '60분',
#  '',
#  '28분',
#  '30분',
#  '20분',
#  '30분',
#  '17분',
#  '',
#  '30분',
#  '',
#  '2시간30분',
#  '1시간',
#  '40분',
#  '30분',
#  '35분',
#  '50분',
#  '',
#  '1시간10분',
#  '35분',
#  '1시간',
#  '1시간',
#  '30분',
#  '60분',
#  '1시간',
#  '45분',
#  '50분',
#  '53분',
#  '30분',
#  '3시간',
#  '',
#  '35분',
#  '35분',
#  '',
#  '40분',
#  '40분',
#  '40분',
#  '25분',
#  '1시간',
#  '1시간',
#  '1시간',
#  '1시간30분',
#  '35분',
#  '45분',
#  '',
#  '45분',
#  '45분',
#  '50분',
#  '35분',
#  '40분',
#  '42분',
#  '',
#  '35분',
#  '20분',
#  '40분',
#  '1시간',
#  '1시간',
#  '40분',
#  '25분',
#  '1시간',
#  '50분',
#  '45분',
#  '',
#  '53분',
#  '1시간',
#  '1시간',
#  '42분',
#  '',
#  '20분',
#  '60분',
#  '11분',
#  '30분',
#  '1시간',
#  '1시간',
#  '55분',
#  '50분',
#  '',
#  '50분',
#  '30분',
#  '30분',
#  '1시간',
#  '2시간',
#  '',
#  '40분',
#  '23분',
#  '10분',
#  '50분',
#  '40분',
#  '1시간',
#  '50분',
#  '',
#  '40분',
#  '45분',
#  '40분',
#  '30분',
#  '45분',
#  '1시간30분',
#  '45분',
#  '20분',
#  '30분',
#  '26분',
#  '',
#  '1시간',
#  '20분',
#  '30분',
#  '30분',
#  '1시간',
#  '40분',
#  '40분',
#  '40분',
#  '1시간',
#  '1시간',
#  '15분',
#  '40분',
#  '45분',
#  '29분',
#  '42분',
#  '1시간20분',
#  '50분',
#  '20분',
#  '1시간',
#  '1시간10분',
#  '',
#  '55분',
#  '30분',
#  '20~30분',
#  '40분',
#  '1시간',
#  '40분',
#  '35분',
#  '50분',
#  '흡입',
#  '60분',
#  '',
#  '',
#  '50분',
#  '30분',
#  '1시간',
#  '33분',
#  '20분',
#  '35분',
#  '1시간30분',
#  '',
#  '1시간',
#  '25분',
#  '30분',
#  '40분',
#  '14~20분',
#  '30분',
#  '45분',
#  '50분(흡입),',
#  '1시간',
#  '1시간',
#  '1시간',
#  '1시간',
#  '1시간50분',
#  '30분',
#  '23분',
#  '20분',
#  '1시간',
#  '20분',
#  '1시간',
#  '1시간',
#  '35분',
#  '1시간',
#  '30분',
#  '40분',
#  '1시간',
#  '35분',
#  '30분',
#  '1시간',
#  '40분',
#  '45분',
#  '35분',
#  '30분',
#  '45분',
#  '60분',
#  '30분',
#  '40분',
#  '30분',
#  '40분',
#  '20분',
#  '48분',
#  '1시간',
#  '1시간',
#  '2시간',
#  '2시간',
#  '20분',
#  '18분',
#  '30분',
#  '30분',
#  '55분',
#  '1시간',
#  '40분',
#  '40분',
#  '50분',
#  '35분',
#  '1시간',
#  '40분',
#  '40분',
#  '45분',
#  '1시간',
#  '45분',
#  '1시간',
#  '40분',
#  '7~10분',
#  '',
#  '30분',
#  '40분',
#  '30분',
#  '1시간',
#  '1시간',
#  '40분',
#  '40분',
#  '45분',
#  '3시간',
#  '',
#  '40분',
#  '30분',
#  '1시간',
#  '35분',
#  '1시간',
#  '50분',
#  '2시간30분',
#  '1시간',
#  '30분',
#  '45분',
#  '12분',
#  '25분',
#  '35분',
#  '노멀모드:23분,',
#  '35분',
#  '25분',
#  '2시간30분',
#  '50분',
#  '',
#  '1시간20분',
#  '1시간',
#  '1시간',
#  '',
#  '1시간',
#  '1시간20분',
#  '40분',
#  '50분',
#  '30분',
#  '35분',
#  '23분',
#  '40분',
#  '40분',
#  '',
#  '30분',
#  '2시간',
#  '2시간30분',
#  '사용시간:',
#  '30분',
#  '2시간30분',
#  '1시간',
#  '30분',
#  '40분',
#  '25분',
#  '30분',
#  '30분',
#  '1시간',
#  '1시간',
#  '1시간',
#  '45분',
#  '45분',
#  '30분',
#  '55분',
#  '1시간',
#  '1시간',
#  '40분',
#  '30분',
#  '1시간',
#  '40분',
#  '',
#  '45분',
#  '1시간',
#  '40분',
#  '물걸레:',
#  '25분',
#  '15분',
#  '50분',
#  '1시간',
#  '42분',
#  '1시간',
#  '1시간30분',
#  '50분',
#  '20분',
#  '30분',
#  '1시간',
#  '1시간',
#  '40분',
#  '40분',
#  '40분',
#  '45분',
#  '45분',
#  '1시간',
#  '',
#  '',
#  '',
#  '',
#  '45분',
#  '1시간',
#  '',
#  '33분',
#  '30분',
#  '35분',
#  '1시간',
#  '35분',
#  '40분',
#  '45분',
#  '35분',
#  '35분',
#  '2시간',
#  '35분',
#  '30분',
#  '50분',
#  '1시간',
#  '20분',
#  '',
#  '15분',
#  '',
#  '50분',
#  '25분',
#  '40분',
#  '',
#  '1시간',
#  '35분',
#  '30분',
#  '40분',
#  '20~30분',
#  '40분',
#  '',
#  '40분',
#  '',
#  '10분',
#  '40분',
#  '30분',
#  '1시간10분',
#  '30분',
#  '1시간',
#  '30분',
#  '55분',
#  '1시간',
#  '1시간',
#  '35분',
#  '30분',
#  '2시간',
#  '25분',
#  '',
#  '20분',
#  '25분',
#  '1시간',
#  '35분',
#  '1시간',
#  '1시간',
#  '1시간',
#  '26분',
#  '1시간',
#  '8~10분',
#  '20분',
#  '30분',
#  '45분',
#  '1시간',
#  '40분',
#  '1시간',
#  '30분',
#  '',
#  '30분',
#  '',
#  '1시간',
#  '40분',
#  '40분',
#  '',
#  '30분',
#  '1시간22분',
#  '30분',
#  '1시간',
#  '50분',
#  '25분',
#  '1시간',
#  '30분',
#  '1시간',
#  '',
#  '27분',
#  '1시간',
#  '',
#  '1시간',
#  '1시간',
#  '25분',
#  '20~30분',
#  '30분',
#  '1시간',
#  '25분',
#  '',
#  '30분',
#  '30분',
#  '40분',
#  '',
#  '30분',
#  '',
#  '1시간',
#  '34분',
#  '1시간',
#  '53분',
#  '1시간',
#  '25분~40분',
#  '1시간',
#  '30분',
#  '30분',
#  '4시간',
#  '20분',
#  '1시간',
#  '25분',
#  '40분',
#  '40분',
#  '',
#  '1시간',
#  '30분',
#  '40분',
#  '1시간',
#  '25분',
#  '24분',
#  '1시간40분',
#  '',
#  '1시간',
#  '30분',
#  '45분',
#  '35분',
#  '1시간',
#  '40분',
#  '40분',
#  '40분',
#  '50분',
#  '40분',
#  '',
#  '1시간',
#  '35분',
#  '30분',
#  '55분',
#  '7~10분',
#  '1시간',
#  '40분',
#  '25분',
#  '50분',
#  '30분',
#  '40분',
#  '50분',
#  '40분',
#  '1시간30분~2시간',
#  '24분',
#  '50분',
#  '38분',
#  '30분',
#  '',
#  '37분',
#  '1시간',
#  '1시간',
#  '',
#  '1시간30분',
#  '',
#  '1시간15분',
#  '1시간',
#  '1시간30분',
#  '1시간',
#  '25분',
#  '30분',
#  '16분',
#  '2시간20분',
#  '40분',
#  '1시간',
#  '10분',
#  '20분',
#  '1시간',
#  '20분',
#  '30분',
#  '20분',
#  '20분',
#  '',
#  '32분',
#  '31분',
#  '1시간',
#  '60분',
#  '12분',
#  '35분',
#  '1시간40분',
#  '30분',
#  '35분',
#  '50분',
#  '30분',
#  '1시간',
#  '35분',
#  '25분',
#  '물걸레:',
#  '1시간',
#  '45분',
#  '30분',
#  '60분',
#  '',
#  '5분~10분',
#  '1시간',
#  '35분',
#  '20분',
#  '1시간',
#  '24분',
#  '40분',
#  '',
#  '40분',
#  ...]

# %%
time = '1시간20분'
time.split('시간')[-1].split('분')[0]
# Out:
# '20'

# %%
## 사용시간 단위 통일
# time = '1시간' , '30분' , '1시간 30분'
def convertHourToMin(time):
    try:
        if '시간' in time:
            hour = time.split('시간')[0]
            if '분' in time:
                minute = time.split('시간')[-1].split('분')[0]
            else:
                minute = 0
        else:
            hour = 0
            minte = time.split('분')[0]
        return int(hour)*60 + int(minute)
    except:
        return None

# %%
convertHourToMin('1시간30분')
# Out:
# 90

# %%
newUseTimeList = []
for time in useTimeList:
    value = convertHourToMin(time)
    newUseTimeList.append(value)

# %%
len(newUseTimeList)
# Out:
# 2057

# %%
## 흡입력 단위 통일 1W = 1AW = 100pa
def convertPow(value):
    try:

        value = value.upper()
        if 'AW' in value or 'W' in value:
            result = value.replace('A', '').replace('W', '').replace(',', '') # A도 삭제 W도 삭제 1000단위도 삭제
            result = int(result)
        elif 'PA' in value:
            result = value.replace('PA', '').replace(',', '') # PA 삭제, 1000단위 쉼표 삭제
            result = int(result) // 100
        else:
            result = None
            
        return result
    
    except:
        return None

# %%
newSuctionList = []
for power in suctionPowList:
    value = convertPow(power)
    newSuctionList.append(value)

# %%
len(newSuctionList)
# Out:
# 2057

# %%
# 엑셀 저장
dfLast = pd.DataFrame()
dfLast['카테고리'] = categoryList
dfLast['회사명'] = compList
dfLast['제품명'] = modelList
dfLast['가격'] = dfProdDanawa['최저가']
dfLast['사용시간'] = newUseTimeList
dfLast['흡입력'] = newSuctionList

# %%
dfLast.tail()
# Out:
#         카테고리   회사명                          제품명      가격  사용시간  흡입력
# 2052  차량용청소기   미니센      무선 소형 청소기 MNC-100 노즐 세트    7000   NaN  NaN
# 2053  차량용청소기   미니센        무선 소형 청소기 MNC-100 먼지통    7000   NaN  NaN
# 2054  차량용청소기  프리라벨  2in1 무선 진공 청소기 LS-2000 헤파필터    3500   NaN  NaN
# 2055   침구청소기    포쉬                 워시젯 V2 WJ200  219000   NaN  NaN
# 2056   침구청소기    업킵                     MJ-BC779   89900   NaN  NaN

# %%
dfLast.to_excel('./data/다나와_무선청소기_전처리결과.xlsx', index=False)

# %% [markdown]
# ## 무선청소기 분석

# %%
dfCleaner = pd.read_excel('./data/다나와_무선청소기_전처리결과.xlsx')

# %%
dfCleaner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2057 entries, 0 to 2056
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   카테고리    2057 non-null   object
#  1   회사명     2057 non-null   object
#  2   제품명     2057 non-null   object
#  3   가격      2057 non-null   int64
#  4   사용시간    446 non-null    float64
#  5   흡입력     1052 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 96.6+ KB

# %%
# 회사명 빠진조건
condition = dfCleaner['회사명'].isnull() == True

# %%
## 회사명 빠진것 10건은 직접 수동으로 채워넣음
dfCleaner[condition]
# Out:
# Empty DataFrame
# Columns: [카테고리, 회사명, 제품명, 가격, 사용시간, 흡입력]
# Index: []

# %%
## 사용시간, 흡입력 NaN인 것은 전부 0으로 채워넣기
dfCleaner = dfCleaner.fillna(0)

# %%
dfCleaner.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2057 entries, 0 to 2056
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   카테고리    2057 non-null   object
#  1   회사명     2057 non-null   object
#  2   제품명     2057 non-null   object
#  3   가격      2057 non-null   int64
#  4   사용시간    2057 non-null   float64
#  5   흡입력     2057 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 96.6+ KB

# %% [markdown]
# ## 필요제품 선별

# %% [markdown]
# #

# %%
# 카테고리별 제품 개수 -> 워드클라우드 가능
dfCleaner['카테고리'].value_counts()
# Out:
# 카테고리
# 핸디스틱청소기                1126
# 차량용청소기                  304
# 물걸레청소기                  217
# 침구청소기                    90
# 욕실청소기                    81
# 업소용청소기                   58
# 탁상용청소기                   52
# 핸디스틱청소기+로봇청소기            34
# 스틱청소기                    27
# 진공청소기                    18
# 창문청소기                    11
# 수영장청소기                   10
# 스팀청소기                     5
# 로봇청소기                     5
# 핸디/스틱청소기+핸디/스틱청소기         4
# 카펫소파청소기                   4
# 핸디스틱청소기+공기청정기세트           4
# 욕실+물걸레청소기                 1
# 핸디스틱청소기+핸디스틱청소기세트         1
# 핸디스틱청소기+가습기세트             1
# 핸디스틱청소기+공기청정기+가습기세트       1
# 신발세척기                     1
# 차량용선풍기                    1
# 핸디스틱청소기+물걸레청소기세트          1
# Name: count, dtype: int64

# %%
dfCleaner['회사명'].value_counts()
# Out:
# 회사명
# 삼성전자      144
# LG전자      131
# 신일전자       88
# 다이슨        75
# 일렉트로룩스     66
#          ...
# 다기능         1
# 디자인에버       1
# 워니코프        1
# 이누스         1
# 마이리빙        1
# Name: count, Length: 515, dtype: int64

# %%
# TEST -> 워드클라우드 가능
dfTest = pd.DataFrame( dfCleaner['회사명'].value_counts())
dfTest.reset_index().head(5)
# Out:
#       회사명  count
# 0    삼성전자    144
# 1    LG전자    131
# 2    신일전자     88
# 3     다이슨     75
# 4  일렉트로룩스     66

# %%
## 핸드스틱청소기만 선택해서 분석
dfDataFinal = dfCleaner[dfCleaner['카테고리'].isin(['핸디스틱청소기', '핸디스틱청소기+로봇청소기', '스틱청소기', '진공청소기'])]

# %%
dfDataFinal.to_excel('./data/2_danawa_data_final.xlsx', index=False)

# %%
dfDataFinal.tail()
# Out:
#        카테고리   회사명            제품명       가격  사용시간    흡입력
# 1962  진공청소기  LG전자  코드제로 T9 T960D  1523960   0.0  250.0
# 1981  진공청소기  LG전자   코드제로 싸이킹 K95  1359230   0.0    0.0
# 2002  진공청소기   마끼다         DCL501   761200   0.0   66.0
# 2024  진공청소기  LG전자  코드제로 T9 T960D  1523960   0.0  250.0
# 2043  진공청소기  LG전자   코드제로 싸이킹 K95  1359230   0.0    0.0

# %%
# 흡입력 기준으로 정렬, ascending=Treu(오름차순), ascending=False(내림차순)
suctionTopList = dfDataFinal.sort_values(['흡입력'], ascending=False)
suctionTopList.head()
# Out:
#         카테고리    회사명               제품명      가격  사용시간    흡입력
# 106  핸디스틱청소기    아이룸           윈드포스 F9  178000   0.0  420.0
# 349  핸디스틱청소기    비브르       V38 스페셜 에디션  195000   0.0  410.0
# 13   핸디스틱청소기  DIBEA  ALLNEW29000 PLUS  236550   0.0  400.0
# 130  핸디스틱청소기  DIBEA      ALLNEW22000+  199000   0.0  390.0
# 146  핸디스틱청소기  DIBEA       ALLNEW29000  249000   0.0  390.0

# %% [markdown]
# ## 분석용 재로드

# %%
dfDataFinal = pd.read_excel('./data/2_danawa_data_final.xlsx')

# %%
dfDataFinal.tail()
# Out:
#          카테고리    회사명                     제품명      가격  사용시간  흡입력
# 1148    스틱청소기   더트데빌  Quick Clean DQV-DVB-DA   69000   NaN  NaN
# 1149  핸디스틱청소기    마끼다                 BCL180Z   55150   NaN  NaN
# 1150  핸디스틱청소기  아로나전자                 AL-6200   64130   NaN  NaN
# 1151  핸디스틱청소기   키친아트                 WY-7070  129000   NaN  NaN
# 1152  핸디스틱청소기  아로나전자                 AL-4200   55890   NaN  NaN

# %%
# 흡입력을 기준으로 정렬, ascending=True(오름차순), ascending=False(내림차순)
suctionTopList = dfDataFinal.sort_values(['흡입력'], ascending=False)
suctionTopList.head()
# Out:
#         카테고리    회사명               제품명      가격  사용시간    흡입력
# 91   핸디스틱청소기    아이룸           윈드포스 F9  178000   NaN  420.0
# 320  핸디스틱청소기    비브르       V38 스페셜 에디션  195000   NaN  410.0
# 13   핸디스틱청소기  DIBEA  ALLNEW29000 PLUS  236550   NaN  400.0
# 466  핸디스틱청소기     행커              400W  197990  60.0  390.0
# 130  핸디스틱청소기  DIBEA       ALLNEW29000  249000   NaN  390.0

# %%
# 사용시간 기준 정렬
useTimeTopList = dfDataFinal.sort_values(['사용시간'], ascending=False)
useTimeTopList.head()
# Out:
#          카테고리    회사명           제품명      가격   사용시간    흡입력
# 289   핸디스틱청소기     무명        LT-124   29980  240.0   80.0
# 1141  핸디스틱청소기   라이녹스  원큐 RXBC-C200  174830  240.0    0.0
# 902   핸디스틱청소기     기펠      BTS-5000  471980  240.0    0.0
# 400   핸디스틱청소기     헤몬       ST-6655   39010  180.0  120.0
# 724   핸디스틱청소기  무궁화전자  바로바로 MDC-900  222270  150.0    0.0

# %%
# 사용시간, 흡입력 동시에 기준 정렬
topList = dfDataFinal.sort_values(['사용시간', '흡입력'], ascending=False)
topList.head()
# Out:
#          카테고리    회사명           제품명      가격   사용시간    흡입력
# 289   핸디스틱청소기     무명        LT-124   29980  240.0   80.0
# 902   핸디스틱청소기     기펠      BTS-5000  471980  240.0    0.0
# 1141  핸디스틱청소기   라이녹스  원큐 RXBC-C200  174830  240.0    0.0
# 400   핸디스틱청소기     헤몬       ST-6655   39010  180.0  120.0
# 714   핸디스틱청소기  무궁화전자  바로바로 MDC-910  225460  150.0    0.0

# %%
## 가성비 좋은 제품 찾기 전
# 평균값
priceMean = int(dfDataFinal['가격'].mean()) # 47만원
suctionMean = dfDataFinal['흡입력'].mean() # 115.8
useTimeMean = dfDataFinal['사용시간'].mean() # 39분
print(f'평균가격 : {priceMean:,d}원, 평균흡입력: {suctionMean:,.2f}W, 평균사용시간: {useTimeMean:,.2f}분')
# Out:
# 평균가격 : 469,661원, 평균흡입력: 115.86W, 평균사용시간: 16.74분

# %%
## 가성비 좋은 제품 조건
cond1 = dfDataFinal['가격'] <= priceMean
cond2 = dfDataFinal['흡입력'] >= suctionMean
cond3 = dfDataFinal['사용시간'] >= useTimeMean

# %%
## 가성비 좋은 제품 검색
chartData = dfDataFinal[cond1 & cond2 & cond3]

# %% [markdown]
# ## 데이터 시각화

# %%
# 필요라이브러리 사용등록
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')

# %%
# 한글깨짐 문제 해결
from matplotlib import rcParams, font_manager, rc

font_path = '/Users/gukjinhan/Library/Fonts/NanumGothicCoding-Bold.ttf' # 나눔고딕 코딩사용
font = font_manager.FontProperties(fname=font_path).get_name() # 실제 설치된 폰트 이름 조회
rc('font', family = font) # 한글깨짐현상 해결!
rcParams['axes.unicode_minus'] = False # 한글 사용 시 마이너스 표시 깨짐 해결!

# %%
## 흡입력, 사용시간 최대값, 최소값
suctionMax = chartData['흡입력'].max() # 420
useTimeMax = chartData['사용시간'].max() # 180
suctionMean2 = chartData['흡입력'].mean() # 229 
useTimeMean2 = chartData['사용시간'].mean() # 51.9

# %%
suctionMean2
# Out:
# 233.21818181818182

# %%
fig = plt.figure(figsize=(18, 8))

sns.scatterplot(data=chartData, x='흡입력', y='사용시간', size='가격', sizes=(10, 400), hue=chartData['회사명'], legend=False)
plt.plot([100, suctionMax], [useTimeMean2, useTimeMean2], 'r--', lw=1) # 사용시간 평균치 줄표시
plt.plot([suctionMean2, suctionMean2], [20, useTimeMax], 'b--', lw=1) # 흡입력 평균치 줄표시

plt.show()

# %%
## 인기제품 데이터 시각화
chartDataTop = chartData[:20]

# %%
import random

# 인기제품 시각화
fig = plt.figure(figsize=(20, 10))
plt.title('무선청소기 Top20')
sns.scatterplot(data=chartDataTop, x='흡입력', y='사용시간', size='가격', sizes=(20, 1000),
                hue=chartDataTop['회사명'])

for index, row in chartDataTop.iterrows():
    x = row['흡입력'] + random.randrange(-10, 10)
    y = row['사용시간'] + random.randrange(-5, 5)
    s = row['제품명']
    plt.text(x, y, s, size=13)

plt.show()

# %% [markdown]
# ##### 결론
# - 데이터분석을 위한 전처리른 쉽지 않음
# - 결과들이 예상이나, 실제와 다를 수 있음
