# %% [markdown]
# ##### 빅데이터 실습
#
# ### 스타벅스매장 입지 분석
#
# #### 데이터 수집
#
# ##### 웹사이트 제공 엑셀파일 수정

# %%
# 필수 라이브러리 사용등록
import pandas as pd
import numpy as np

# %%
dfSeoulManicipality = pd.read_excel('./data/전국_시군구_위경도.xlsx')
dfSeoulManicipality.tail()
# Out:
#       docity  do   city   longitude   latitude
# 290    충청충주시  충청    충주시  127.928144  36.988181
# 291    충청태안군  충청    태안군  126.299975  36.742667
# 292  충청한누리대로  충청  한누리대로  127.289926  36.485450
# 293    충청홍성군  충청    홍성군  126.662908  36.598361
# 294    충청대전시  충청    대전시  127.384862  36.350630

# %%
# 서울만 필터링
condition = dfSeoulManicipality['do'] == '서울'
dfSeoulGeo = dfSeoulManicipality[condition]

# %%
dfSeoulGeo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 138 to 162
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   docity     25 non-null     object
#  1   do         25 non-null     object
#  2   city       25 non-null     object
#  3   longitude  25 non-null     float64
#  4   latitude   25 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 1.2+ KB

# %%
# 필요로 만든 데이터는 항상 저장해둘 것
dfSeoulGeo.to_excel('./data/수정_서울_시군구_위경도.xlsx', index=False)

# %%
# 서울시 구별 인구데이터 로드
columns = ['구', '세대소계', '성별소계' , '남자', '여자', '한국인소계', '남자', '여자', '등록외국인소계', '남자', '여자', '세대당인구', '65세이상']
dfSeoulPop = pd.read_excel('data/서울시_구별_인구데이터.xlsx', header=2, usecols = 'B,O:Z')
dfSeoulPop.columns = columns
dfSeoulPop.tail()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#       구    세대소계    성별소계      남자      여자   한국인소계      남자      여자  등록외국인소계  \
# 21  관악구  284578  497883  249026  248857  481956  242651  239305    15927
# 22  서초구  169884  412078  196391  215687  407664  194291  213373     4414
# 23  강남구  239775  550282  262991  287291  544873  260520  284353     5409
# 24  송파구  285927  660025  316981  343044  654166  314347  339819     5859
# 25  강동구  203734  463318  226237  237081  459167  224423  234744     4151
#
#       남자    여자  세대당인구   65세이상
# 21  6375  9552   1.69   85418
# 22  2100  2314   2.40   65661
# 23  2471  2938   2.27   86606
# 24  2634  3225   2.29  108894
# 25  1814  2337   2.25   82984

# %%
## 서울시 인구데이터 저장
dfSeoulPop.to_excel('./data/수정_서울_구별인구.xlsx', index=False)

# %%
## 서울시 구별 사업체현황 로드
dfSeoulWork = pd.read_excel('./data/서울시_구별_사업체현황.xlsx')
dfSeoulWork
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     동별(1)  동별(2)      2021    2021.1    2021.2    2021.3    2021.4  \
# 0   동별(1)  동별(2)        합계        합계        합계        합계        합계
# 1   동별(1)  동별(2)        소계        소계        소계        소계        소계
# 2   동별(1)  동별(2)  사업체수 (개)  사업체수 (개)  종사자수 (명)  종사자수 (명)  종사자수 (명)
# 3   동별(1)  동별(2)        소계     여성대표자        소계         남         여
# 4      합계     소계   1188091    407948   5771226   3218529   2552697
# 5     NaN    종로구     48361     16563    275063    153210    121853
# 6     NaN     중구     70308     25794    386564    213782    172782
# 7     NaN    용산구     29680     10454    152605     84314     68291
# 8     NaN    성동구     41665     13447    203221    116978     86243
# 9     NaN    광진구     33706     12297    129707     71124     58583
# 10    NaN   동대문구     42813     14480    146383     78105     68278
# 11    NaN    중랑구     39310     13471    113144     59221     53923
# 12    NaN    성북구     34712     13393    124004     60275     63729
# 13    NaN    강북구     26385      9807     80222     38440     41782
# 14    NaN    도봉구     25391      8886     79097     41600     37497
# 15    NaN    노원구     37909     14092    133398     63208     70190
# 16    NaN    은평구     36509     14446    109031     51769     57262
# 17    NaN   서대문구     28522     10787    118256     58797     59459
# 18    NaN    마포구     56782     19865    279788    152822    126966
# 19    NaN    양천구     37929     14039    133776     70222     63554
# 20    NaN    강서구     58806     19887    290473    164478    125995
# 21    NaN    구로구     52791     16161    240689    140067    100622
# 22    NaN    금천구     47964     13700    255449    158019     97430
# 23    NaN   영등포구     74562     22629    435017    253173    181844
# 24    NaN    동작구     27915     10964    109281     54637     54644
# 25    NaN    관악구     37915     13641    128417     68392     60025
# 26    NaN    서초구     71958     23066    487976    290084    197892
# 27    NaN    강남구    110007     35453    801419    447809    353610
# 28    NaN    송파구     74531     25400    400781    244588    156193
# 29    NaN    강동구     41660     15226    157465     83415     74050
#
#         2021.5      2021.6    2021.7  ...            2021.33  \
# 0           합계          합계        합계  ...                 합계
# 1   농업 임업 및 어업  농업 임업 및 어업        광업  ...  공공행정 국방 및 사회보장 행정
# 2     사업체수 (개)    종사자수 (명)  사업체수 (개)  ...           사업체수 (개)
# 3           소계          소계        소계  ...                 소계
# 4          154         753        25  ...               1303
# 5            4          21         4  ...                100
# 6            1           1         2  ...                 65
# 7            4           8         -  ...                 45
# 8            7          15         1  ...                 45
# 9            3           4         -  ...                 38
# 10           2           4         1  ...                 49
# 11           -           -         2  ...                 47
# 12           1           3         -  ...                 49
# 13           1           1         -  ...                 42
# 14           2           4         -  ...                 37
# 15           5          22         -  ...                 40
# 16           4          12         -  ...                 54
# 17           1           2         -  ...                 44
# 18           6          11         2  ...                 60
# 19           1           2         1  ...                 47
# 20           5          44         -  ...                 61
# 21           6          18         -  ...                 46
# 22           1           2         -  ...                 31
# 23           9          17         2  ...                 70
# 24           4           6         -  ...                 41
# 25           2          18         1  ...                 50
# 26          19          86         1  ...                 69
# 27          27         137         6  ...                 58
# 28          26         241         1  ...                 70
# 29          13          74         1  ...                 45
#
#               2021.34   2021.35   2021.36          2021.37          2021.38  \
# 0                  합계        합계        합계               합계               합계
# 1   공공행정 국방 및 사회보장 행정   교육 서비스업   교육 서비스업  보건업 및 사회복지 서비스업  보건업 및 사회복지 서비스업
# 2            종사자수 (명)  사업체수 (개)  종사자수 (명)         사업체수 (개)         종사자수 (명)
# 3                  소계        소계        소계               소계               소계
# 4              155790     46855    361663            31866           450396
# 5               17436      1082     13298              830            19143
# 6               16141       644      9425              813            11585
# 7                3416       844      7352              632             8219
# 8                5243      1283     10453              815             9635
# 9                3592      1467     14698              981            12785
# 10               4023      1288     16173             1085            17183
# 11               4108      1151      7668             1111            14806
# 12               4607      1806     21226             1131            16668
# 13               3530       890      6164              867            11540
# 14               4256      1114      7191              859            12804
# 15               4047      2573     20726             1515            21536
# 16               5872      1847     10749             1322            18824
# 17               6013      1405     19646              875            15584
# 18               5969      2462     16804             1339            13243
# 19               5524      2900     15309             1293            17154
# 20               5236      2505     14779             1735            24758
# 21               5153      1613     11771             1258            18241
# 22               2368       937      6810              763             8866
# 23               9379      1717      9441             1345            19680
# 24               4213      1615     13728             1110            16024
# 25               3809      1596     17130             1257            16081
# 26              12994      3451     26294             1930            24825
# 27               7471      5459     34053             3522            47080
# 28               8333      3146     19154             2055            30552
# 29               3057      2060     11621             1423            23580
#
#                2021.39             2021.40                  2021.41  \
# 0                   합계                  합계                       합계
# 1   예술 스포츠 및 여가관련 서비스업  예술 스포츠 및 여가관련 서비스업  협회 및 단체 수리 및 기타 개인 서비스업
# 2             사업체수 (개)            종사자수 (명)                 사업체수 (개)
# 3                   소계                  소계                       소계
# 4                28722               88491                    77887
# 5                 1141                5650                     2591
# 6                  632                3258                     2175
# 7                  651                3006                     1866
# 8                  844                2956                     2341
# 9                 1139                3202                     2799
# 10                 889                2282                     2790
# 11                1029                2273                     3099
# 12                1043                2444                     2931
# 13                 869                1885                     2508
# 14                 738                1594                     2264
# 15                1131                3043                     3105
# 16                1027                2266                     3312
# 17                 742                1797                     2328
# 18                1505                4327                     3610
# 19                1070                2799                     3098
# 20                1479                4024                     4413
# 21                1047                2527                     2968
# 22                 697                1478                     2241
# 23                1395                4228                     3549
# 24                 916                2052                     2484
# 25                1286                2954                     3404
# 26                1752                6911                     3810
# 27                2579               11059                     5984
# 28                2026                7881                     4830
# 29                1095                2595                     3387
#
#                     2021.42
# 0                        합계
# 1   협회 및 단체 수리 및 기타 개인 서비스업
# 2                  종사자수 (명)
# 3                        소계
# 4                    186496
# 5                      7297
# 6                      7632
# 7                      5572
# 8                      7334
# 9                      5121
# 10                     4906
# 11                     4937
# 12                     5502
# 13                     4270
# 14                     4184
# 15                     5566
# 16                     5767
# 17                     4963
# 18                     9838
# 19                     6185
# 20                    10461
# 21                     6714
# 22                     5575
# 23                    11998
# 24                     5093
# 25                     6247
# 26                    12609
# 27                    21981
# 28                    10574
# 29                     6170
#
# [30 rows x 45 columns]

# %%
## 서울시 구별 사업체현황 로드
dfSeoulWork = pd.read_excel('./data/서울시_구별_사업체현황.xlsx', header=4, usecols='B:G')
dfSeoulWork
columns = ['구','소계','여성대표자','성별소계','남자','여자']
dfSeoulWork.columns = columns
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
## 서울시 구별 사업체현황 저장
dfSeoulWork.to_excel('./data/수정_서울_구별사업체.xlsx',index=False)
