# %% [markdown]
# ## Pandas 학습
#
# ### 데이터 통합 한번더
#
# #### merge
# - 데이터를 합칠때 컬럼을 옆으로 늘려서 합침
# - DataBase 의 JOIN과 동일한 기능

# %%
import pandas as pd

# %%
# header 엑셀에서 필요없는 제목줄 등 없개기
# skipfooter 아래쪽에 필요없는 행들을 삭제
df_left = pd.read_excel('/Users/gukjinhan/Documents/GitHub/bigdata-analysis-2024/day01/data/sample_1.xlsx', header =1, skipfooter=2, usecols='A:D')
df_left
# Out:
#   국적코드  성별    입국객수    전년동기
# 0  A01  남성  106320   85815
# 1  A01  여성  191436  125241
# 2  A31  남성     319     299
# 3  A31  여성      42      54
# 4  A18  남성  158912  124486
# 5  A18  여성  232943  163466

# %%
df_right = pd.read_excel('/Users/gukjinhan/Documents/GitHub/bigdata-analysis-2024/day01/data/sample_codemaster.xlsx')
df_left
# Out:
#   국적코드  성별    입국객수    전년동기
# 0  A01  남성  106320   85815
# 1  A01  여성  191436  125241
# 2  A31  남성     319     299
# 3  A31  여성      42      54
# 4  A18  남성  158912  124486
# 5  A18  여성  232943  163466

# %%
## 병합
df_total = pd.merge(left=df_left, right = df_right, how='left', left_on= '국적코드'
                    , right_on='국적코드')

# %%
# NaN : 난 국적코드가 뭔지 모름
df_total
# Out:
#   국적코드  성별    입국객수    전년동기  국적명
# 0  A01  남성  106320   85815   일본
# 1  A01  여성  191436  125241   일본
# 2  A31  남성     319     299  NaN
# 3  A31  여성      42      54  NaN
# 4  A18  남성  158912  124486   중국
# 5  A18  여성  232943  163466   중국

# %%
# DB INNER JOIN 과 동일
df_total = pd.merge(left=df_left, right = df_right, how='inner', left_on= '국적코드'
                    , right_on='국적코드')

# %%
# 일치하지 않은값을 생략(삭제)
df_total
# Out:
#   국적코드  성별    입국객수    전년동기 국적명
# 0  A01  남성  106320   85815  일본
# 1  A01  여성  191436  125241  일본
# 2  A18  남성  158912  124486  중국
# 3  A18  여성  232943  163466  중국

# %% [markdown]
# #### append
# - 데이터를 합칠때 데이터 수가 늘도록 합치는 방법
# - DB에 UNION 이라는 기능과 완전 동일

# %%
## append를 하기위한 데이터하나 더 생성
df_left2 = pd.read_excel('/Users/gukjinhan/Documents/GitHub/bigdata-analysis-2024/day02/data/sample_2.xlsx', header =1, skipfooter=2, usecols='A:D')
df_left2
# Out:
#   국적코드  성별    입국객수    전년동기
# 0  A01  남성   92556   75992
# 1  A01  여성  163737  115397
# 2  A18  남성  155540  129908
# 3  A18  여성  249023  191236

# %%
pd.__version__
# Out:
# '2.2.1'

# %%
## df_all = df_total + df_total2
## 중요!! pandas 2버전 이상에서는 append() 함수가 없어지
## pd.concat() 사용
df_all = df_left.cappend(df_left2)
df_all
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/gb/b00gj_y55zb3lhxtk9d7s87c0000gn/T/ipykernel_76004/1365033850.py in ?()
#       1 ## df_all = df_total + df_total2
#       2 ## 중요!! pandas 2버전 이상에서는 append() 함수가 없어지
#       3 ## pd.concat() 사용
# ----> 4 df_all = df_left.concat(df_left2)
#       5 df_all
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
pd.concat([df_left, df_left2])
# Out:
#   국적코드  성별    입국객수    전년동기
# 0  A01  남성  106320   85815
# 1  A01  여성  191436  125241
# 2  A31  남성     319     299
# 3  A31  여성      42      54
# 4  A18  남성  158912  124486
# 5  A18  여성  232943  163466
# 0  A01  남성   92556   75992
# 1  A01  여성  163737  115397
# 2  A18  남성  155540  129908
# 3  A18  여성  249023  191236

# %%
## 이렇게 합치면 안된다.
pd.concat([df_total, df_left2])
# Out:
#   국적코드  성별    입국객수    전년동기  국적명
# 0  A01  남성  106320   85815   일본
# 1  A01  여성  191436  125241   일본
# 2  A18  남성  158912  124486   중국
# 3  A18  여성  232943  163466   중국
# 0  A01  남성   92556   75992  NaN
# 1  A01  여성  163737  115397  NaN
# 2  A18  남성  155540  129908  NaN
# 3  A18  여성  249023  191236  NaN

# %%
## df_left2를 가지고 df_total2를 만듬, 국적명을 제대로 받기 위해서
df_total2 = pd.merge(left=df_left2, right=df_right,
                     how='left', left_on='국적코드', right_on='국적코드')
df_total2
# Out:
#   국적코드  성별    입국객수    전년동기 국적명
# 0  A01  남성   92556   75992  일본
# 1  A01  여성  163737  115397  일본
# 2  A18  남성  155540  129908  중국
# 3  A18  여성  249023  191236  중국

# %%
# ignore_index는 DF의 자체 인덱스를 무시하고 새로 인덱스를 생성
df_all = pd.concat([df_total, df_total2], ignore_index=True)

# %%
df_all
# Out:
#   국적코드  성별    입국객수    전년동기  국적명
# 0  A01  남성  106320   85815   일본
# 1  A01  여성  191436  125241   일본
# 2  A31  남성     319     299  NaN
# 3  A31  여성      42      54  NaN
# 4  A18  남성  158912  124486   중국
# 5  A18  여성  232943  163466   중국
# 6  A01  남성   92556   75992   일본
# 7  A01  여성  163737  115397   일본
# 8  A18  남성  155540  129908   중국
# 9  A18  여성  249023  191236   중국

# %%
## DF 저장 pd,to_...
# index=False DF가 만드는 임의의 인덱스는 저장안됨
df_all.to_excel('/Users/gukjinhan/Documents/GitHub/bigdata-analysis-2024/day02/data/df_all.xlsx', index=False)

# %%
## 기준년월 확인
df_total['기준년월'] = '2019-11'
df_total
# Out:
#   국적코드  성별    입국객수    전년동기  국적명     기준년월
# 0  A01  남성  106320   85815   일본  2019-11
# 1  A01  여성  191436  125241   일본  2019-11
# 2  A31  남성     319     299  NaN  2019-11
# 3  A31  여성      42      54  NaN  2019-11
# 4  A18  남성  158912  124486   중국  2019-11
# 5  A18  여성  232943  163466   중국  2019-11

# %%
df_total2['기준년월'] = '2019-12'
df_total2
# Out:
#   국적코드  성별    입국객수    전년동기 국적명     기준년월
# 0  A01  남성   92556   75992  일본  2019-12
# 1  A01  여성  163737  115397  일본  2019-12
# 2  A18  남성  155540  129908  중국  2019-12
# 3  A18  여성  249023  191236  중국  2019-12

# %%
df_all = pd.concat([df_total, df_total2], ignore_index=True)
df_all
# Out:
#   국적코드  성별    입국객수    전년동기  국적명     기준년월
# 0  A01  남성  106320   85815   일본  2019-11
# 1  A01  여성  191436  125241   일본  2019-11
# 2  A31  남성     319     299  NaN  2019-11
# 3  A31  여성      42      54  NaN  2019-11
# 4  A18  남성  158912  124486   중국  2019-11
# 5  A18  여성  232943  163466   중국  2019-11
# 6  A01  남성   92556   75992   일본  2019-12
# 7  A01  여성  163737  115397   일본  2019-12
# 8  A18  남성  155540  129908   중국  2019-12
# 9  A18  여성  249023  191236   중국  2019-12

# %% [markdown]
# #### Pivot테이블
# 통계를 내면서 테이블을 세로로된 DF를 가로로 바꿔주는 기능
# DB에서 바로 피벗작업 꽤 힘듦. 파이썬에서 피벗하는게 훨씬 쉬움

# %%
## aggfunc -> sum(총합), mean(평균), min, max, median(중앙값), count(개수), nunique(중복제거개수)
df_all.pivot_table(values='입국객수',index='국적코드',columns='기준년월', aggfunc='sum')
# Out:
# 기준년월   2019-11   2019-12
# 국적코드
# A01   297756.0  256293.0
# A18   391855.0  404563.0
# A31      361.0       NaN
