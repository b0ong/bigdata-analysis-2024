# %% [markdown]
# ## 머신러닝 학습
#
# ### 텍스트 마이닝
#
# #### 데이터 수집
#
# ##### 네이버 코로나 뉴스로 감성분석

# %%
# 필요 라이브러리 사용등록
import json

# %%
with open('./data/코로나_naver_news.json', encoding='UTF-8') as f:
    data = json.load(f)

# %%
import pandas as pd
import re

# %%
dfData = pd.DataFrame(data)

# %%
dfData.head()
# Out:
#    cnt                                        description  \
# 0    1  <b>코로나</b>발 경제 위기 대응을 위해 돈 쓸 곳은 늘어났지만, 국세 수입은 ...
# 1    2  ▲ 지난 2일 창녕군보건소 앞에 설치한 선별진료소에서 검사자가 체온을 측정하고 있다...
# 2    3  한편, ‘설현’은 최근 <b>코로나</b>19 바이러스를 다룬, MBC ‘시리즈M’...
# 3    4  변화의 핵심 중에서는 우리 사회가 신종 <b>코로나</b>바이러스 감염증(<b>코로...
# 4    5   이재갑 고용노동부 장관은 6월3일(수) 11시에 <b>코로나</b>19 긴급 고용...
#
#                  pDate                                          title
# 0  2020-06-04 14:12:00  결국 '증세론' 먼저 꺼내든 與…&quot;증세없는 '기본소득' 불가능&quot;
# 1  2020-06-04 14:12:00                         창녕군, ‘창녕형’비대면 선별진료소 운영
# 2  2020-06-04 14:12:00                   DK모바일, 메인 홍보 모델로 AOA '설현' 선정
# 3  2020-06-04 14:12:00   김병민 &quot;기본소득도 필요하면 논의 테이블에 올려야&quot; [인터뷰]
# 4  2020-06-04 14:12:00                        이재갑 장관, 고용안정지원금 서울센터 방문

# %%
## 한글 이외의 것 다 제거하는 작업 , title/description
dfData['title'] = dfData['title'].apply(lambda x: re.sub(r'[^가-힣|ㄱ-]+', ' ', x))

# %%
## 한글 이외의 것 다 제거하는 작업 , title/description
dfData['description'] = dfData['description'].apply(lambda x: re.sub(r'[^가-힣|ㄱ-]+', ' ', x))

# %%
dfData.head()
# Out:
#    cnt                                        description  \
# 0    1   코로나 발 경제 위기 대응을 위해 돈 쓸 곳은 늘어났지만 국세 수입은 줄어들면서 ...
# 1    2   지난 일 창녕군보건소 앞에 설치한 선별진료소에서 검사자가 체온을 측정하고 있다 사...
# 2    3  한편 설현 은 최근 코로나 바이러스를 다룬 시리즈 세계적 유행 에서 다큐멘터리 내레...
# 3    4  변화의 핵심 중에서는 우리 사회가 신종 코로나 바이러스 감염증 코로나 의 위기를 마...
# 4    5   이재갑 고용노동부 장관은 월 일 수 시에 코로나 긴급 고용안정지원금 서울 센터 서...
#
#                  pDate                            title
# 0  2020-06-04 14:12:00     결국 증세론 먼저 꺼내든 증세없는 기본소득 불가능
# 1  2020-06-04 14:12:00             창녕군 창녕형 비대면 선별진료소 운영
# 2  2020-06-04 14:12:00              모바일 메인 홍보 모델로 설현 선정
# 3  2020-06-04 14:12:00  김병민 기본소득도 필요하면 논의 테이블에 올려야 인터뷰
# 4  2020-06-04 14:12:00           이재갑 장관 고용안정지원금 서울센터 방문

# %%
dfData[['title','pDate', 'description']].to_excel('./data/코로나뉴스_전처리.xlsx', index=False)

# %%
dfData = pd.read_excel('./data/코로나뉴스_전처리.xlsx')

# %%
dfData.head()
# Out:
#                              title                pDate  \
# 0     결국 증세론 먼저 꺼내든 증세없는 기본소득 불가능   2020-06-04 14:12:00
# 1             창녕군 창녕형 비대면 선별진료소 운영  2020-06-04 14:12:00
# 2              모바일 메인 홍보 모델로 설현 선정  2020-06-04 14:12:00
# 3  김병민 기본소득도 필요하면 논의 테이블에 올려야 인터뷰   2020-06-04 14:12:00
# 4           이재갑 장관 고용안정지원금 서울센터 방문  2020-06-04 14:12:00
#
#                                          description
# 0   코로나 발 경제 위기 대응을 위해 돈 쓸 곳은 늘어났지만 국세 수입은 줄어들면서 ...
# 1   지난 일 창녕군보건소 앞에 설치한 선별진료소에서 검사자가 체온을 측정하고 있다 사...
# 2  한편 설현 은 최근 코로나 바이러스를 다룬 시리즈 세계적 유행 에서 다큐멘터리 내레...
# 3  변화의 핵심 중에서는 우리 사회가 신종 코로나 바이러스 감염증 코로나 의 위기를 마...
# 4   이재갑 고용노동부 장관은 월 일 수 시에 코로나 긴급 고용안정지원금 서울 센터 서...

# %% [markdown]
# #### 감성분석 모델 재구축

# %%
## 훈련용 데이터 가져오기
dfNsmcTrain = pd.read_csv('../day12/data/ratings_train.txt',engine='python', sep='\t', encoding='utf-8')

# %%
dfNsmcTrain.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %%
dfNsmcTrain = dfNsmcTrain[dfNsmcTrain['document'].notnull()]

# %%
## 한글이외 다 제거
dfNsmcTrain['document'] = dfNsmcTrain['document'].apply(lambda x: re.sub(r'[^가-힣|ㄱ-]+', ' ', x))

# %%
# 한글 제거 후 다시 document가 빈 row를 제거
dfNsmcTrain = dfNsmcTrain[ dfNsmcTrain['document'] != ' ']

# %%
## 백터화, 로지스틱회귀 모듈 사용등록
import konlpy
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# %%
okt = Okt()

# %%
def oktToken(text):
    tokens = okt.morphs(text)
    return tokens

# %%
## 백터화 객체 생성
tfidf = TfidfVectorizer(tokenizer=oktToken, ngram_range=(1,2), min_df=3, max_df=0.9)

# %%
tfidf.fit(dfNsmcTrain['document'])
nsmc_train_tfidf = tfidf.transform(dfNsmcTrain['document'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
nsmc_train_tfidf
# Out:
# <148434x113939 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2681545 stored elements in Compressed Sparse Row format>

# %%
## 로지스틱회귀 모델 생성
model = LogisticRegression(random_state=0, C =3.5)

# %%
model.get_params()
# Out:
# {'C': 3.5,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': 0,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
model.fit(nsmc_train_tfidf, dfNsmcTrain['label'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=3.5, random_state=0)

# %% [markdown]
# #### 네이버 뉴스 타이틀로 감성분석

# %%
## 분석할 데이터의 백터화
data_title_tfidf = tfidf.transform(dfData['title'])

# %%
# 감성분석(로지스틱회귀)
title_predict = model.predict(data_title_tfidf)

# %%
# 감성분석결과 DF 저장
dfData['title_label'] = title_predict

# %%
dfData
# Out:
#                                      title                pDate  \
# 0             결국 증세론 먼저 꺼내든 증세없는 기본소득 불가능   2020-06-04 14:12:00
# 1                     창녕군 창녕형 비대면 선별진료소 운영  2020-06-04 14:12:00
# 2                      모바일 메인 홍보 모델로 설현 선정  2020-06-04 14:12:00
# 3          김병민 기본소득도 필요하면 논의 테이블에 올려야 인터뷰   2020-06-04 14:12:00
# 4                   이재갑 장관 고용안정지원금 서울센터 방문  2020-06-04 14:12:00
# ..                                     ...                  ...
# 795   세계의 눈 코로나 영향 현대차 매출 큰 타격 하지만 차량은 순항   2020-06-04 13:36:00
# 796             중부발전 소규모 태양광사업자 판매대금 선 지급   2020-06-04 13:36:00
# 797          코로나 함께 극복 박종환 자유총연맹 총재 캠페인 참여  2020-06-04 13:36:00
# 798      치과의사 명 모이는 행사 앞두고 치협 회장 행사 취소해달라   2020-06-04 13:36:00
# 799                  포토|대종상영화제 문가영 발랄 듬 뿍   2020-06-04 13:36:00
#
#                                            description  title_label
# 0     코로나 발 경제 위기 대응을 위해 돈 쓸 곳은 늘어났지만 국세 수입은 줄어들면서 ...            0
# 1     지난 일 창녕군보건소 앞에 설치한 선별진료소에서 검사자가 체온을 측정하고 있다 사...            0
# 2    한편 설현 은 최근 코로나 바이러스를 다룬 시리즈 세계적 유행 에서 다큐멘터리 내레...            1
# 3    변화의 핵심 중에서는 우리 사회가 신종 코로나 바이러스 감염증 코로나 의 위기를 마...            0
# 4     이재갑 고용노동부 장관은 월 일 수 시에 코로나 긴급 고용안정지원금 서울 센터 서...            1
# ..                                                 ...          ...
# 795  글로벌기업 현대 기아차가 코로나 의 여파로 해외시장에서 고전을 면치 못하고 있는 가...            0
# 796  한국중부발전 본사 전경 한국중부발전 사장 박형구 은 코로나 장기화로 인해 경제적 어...            1
# 797  박종환 한국자유총연맹 총재 신종 코로나 바이러스 감염증 코로나 극복과 조기 종식을 ...            1
# 798  이상훈 회장은 코로나 신규 확진자가 수도권에서 발생했고 정부는 수도권 한정 사회적 ...            0
# 799  제 회 대종상영화제 참석한 문가영제 회 대종상영화제 참석한 문가영 코로나 여파로 무...            0
#
# [800 rows x 4 columns]

# %%
## 설명도 동일하게 감성분석
data_desc_tfidf = tfidf.transform(dfData['description'])

# %%
# 감성분석
dfData['description_label'] =  model.predict(data_desc_tfidf)

# %%
dfData.tail()
# Out:
#                                      title                pDate  \
# 795   세계의 눈 코로나 영향 현대차 매출 큰 타격 하지만 차량은 순항   2020-06-04 13:36:00
# 796             중부발전 소규모 태양광사업자 판매대금 선 지급   2020-06-04 13:36:00
# 797          코로나 함께 극복 박종환 자유총연맹 총재 캠페인 참여  2020-06-04 13:36:00
# 798      치과의사 명 모이는 행사 앞두고 치협 회장 행사 취소해달라   2020-06-04 13:36:00
# 799                  포토|대종상영화제 문가영 발랄 듬 뿍   2020-06-04 13:36:00
#
#                                            description  title_label  \
# 795  글로벌기업 현대 기아차가 코로나 의 여파로 해외시장에서 고전을 면치 못하고 있는 가...            0
# 796  한국중부발전 본사 전경 한국중부발전 사장 박형구 은 코로나 장기화로 인해 경제적 어...            1
# 797  박종환 한국자유총연맹 총재 신종 코로나 바이러스 감염증 코로나 극복과 조기 종식을 ...            1
# 798  이상훈 회장은 코로나 신규 확진자가 수도권에서 발생했고 정부는 수도권 한정 사회적 ...            0
# 799  제 회 대종상영화제 참석한 문가영제 회 대종상영화제 참석한 문가영 코로나 여파로 무...            0
#
#      description_label
# 795                  0
# 796                  1
# 797                  1
# 798                  1
# 799                  0

# %%
dfData.to_excel('./data/코로나뉴스_감성분석_결과.xlsx', index=False)

# %% [markdown]
# ## 시각화 준비

# %%
dfResult = pd.read_excel('./data/코로나뉴스_감성분석_결과.xlsx')

# %%
dfResult['title_label'].value_counts()
# Out:
# title_label
# 0    479
# 1    321
# Name: count, dtype: int64

# %%
# 기사 내용의 감성별 갯수
dfResult['description_label'].value_counts()
# Out:
# description_label
# 0    447
# 1    353
# Name: count, dtype: int64

# %%
## 긍정적 결과와 부정적 결과를 분리
columns_names = dfResult.columns.tolist()

# %%
columns_names.remove('pDate')

# %%
columns_names
# Out:
# ['title', 'description', 'title_label', 'description_label']

# %%
# 빈 DF생성
dfPositiveData = pd.DataFrame(columns=columns_names)
dfNegativeData = pd.DataFrame(columns=columns_names) 

# description_label이 긍정인지 부정인지 따라 dfPositiveData와 dfNegativeData에 나눠서 할당
for i, data in dfData.iterrows():
    title = data['title']
    description = data['description']
    title_label = data['title_label']
    description_label = data['description_label']
    
    if description_label == 1: # 긍정이면
        dfTemp = pd.DataFrame([[title, description, title_label, description_label]], columns=dfPositiveData.columns)
        dfPositiveData = pd.concat([dfPositiveData, dfTemp])
    else: # 부정감성데이터는 여기
        dfTemp = pd.DataFrame([[title, description, title_label, description_label]], columns=dfNegativeData.columns)
        dfNegativeData = pd.concat([dfNegativeData, dfTemp])

# %%
len(dfPositiveData), len(dfNegativeData)
# Out:
# (353, 447)

# %% [markdown]
# ## 시각화

# %%
# 긍정 데이터에서 단어 추출
posDescription = dfPositiveData['description']

# %%
posDescriptionWords = []

for d in posDescription:
    posDescriptionWords.append(okt.nouns(d)) # 명사 형태로만 추출

# %%
finalPosDescWords = []

for d in posDescriptionWords:
    d2 = [w for w in d if len(w)>1] # 글자 길이가 1보다 큰것만 추출
    finalPosDescWords.append(' '.join(d2))

# %%
finalPosDescWords
# Out:
# ['변화 핵심 우리 사회 신종 코로나 바이러스 감염증 코로나 위기 마주 언제 미래 국가 국민 어려움 해결 저희',
#  '한편 코로나 해외 재료 사재기 국민 먹거리 안정 생산 포스트 코로나 과제 부각 농민 기본소득 도입 통해 안정 생산 기반 확충',
#  '최근 갤러리 현대 창업 주년 기념 작품 전시 코로나 영향 마스크 착용 관람객 미술 트렌드 한국 미술 시장 정태희 서울 옥션 스페셜리스트 세계 경기 침체 코로나 여파',
#  '코로나 감안 면접 비대 역량 검사 도입 국내 최대 치킨 프랜차이즈 제너시스 비비큐 회장 채용 관계자 한국 대표 책임감 브랜드 로서 코로나 침체 채용 분위기',
#  '오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 가수 공연 보고 뉴스',
#  '플립 러닝 온라인 학습 교실 토론 심화 학습 거꾸로 교실 불리 포스트 코로나 시대 교육 방식 주목 아르고 리더십 상황 게임 통해 리더십 유형',
#  '코로나 사태 가운데 병영 생활 손흥민 경험 영국 화제 손흥민 서로 금방 이서 정말 서로 호흡',
#  '청와대 해외 보가 문재인 대통령 포스트 코로나 시대 경제위기 정상회담 통해 양국 협력 에너지 의료 확장 최근 카타르 코로나 관련',
#  '맥도날드 코로나 방역 작업 대구 지하철 청소 근로자 빅맥 커피 증정 패션 업계 나눔 활동 동참 코오롱 인더스 트리 직원 성과 상금 만원 코로나 어려움',
#  '정하영 김포시 혁신 교육 지구 사업 특수교육 대상자 사업 별도 편성 소외 학생 면서 코로나 교육과정 운영 판단 학생 안전 방역',
#  '군포 시청 서울시 리치 웨이 코로나 진자 동선 공개 군포로 번길 거주 자료 군포 시청 군포 시청 서울시 리치 웨이 코로나 진자 동선 공개 군포 시청 공식 블로그 통해 서울시',
#  '명품 함양 양파 특판전 모습 사진 제공 함양군 함양군 롯데 마트 서울 역점 양파 소비 촉진 판촉 행사 코로나 농심 위로 함양군 코로나 장기 소비 위축 판매 어려움',
#  '지난 방송 세기 힛트송 노래방 대리 만족 구석 트쏭 주제 코로나 노래방 대신 폭발 과거 힛트송 시청자 무료함',
#  '유플러스 코로나 언택트 시대 리얼 통해 글라스 온라인 애플리케이션 개발 세미나 개최 글라스 활용 개발 생태계 만들기',
#  '이창수 홈플러스 마케팅 총괄 이사 고기 과정 대표 외식 메뉴 코로나 이후 대표 집밥 메뉴 기획전 비롯',
#  '김병수 울릉 군수 가용 부지 절대 우리 울릉군 특성 청사 부지 선정 우리 발전 미래 대계 결정 매우 사안 코로나 다소 지연 울릉군 행정',
#  '청와대 카타르 액화천연가스 운반 수주 지목 코로나 사태 극복 과정 방역 최근 카타르 코로나 관련 진단 장비 공급 방역 경험 공유 양국 협력 범위 확대',
#  '유플러스 코로나 언택트 시대 리얼 글래스 온라인 개발 세미나 개최 오전 시간 동안 통해 실시간 참여 해당',
#  '안양시 서울 관악구 리치 웨이 방문자 코로나 양성 판정 진자 동안구 범계동 목련 아파트 거주 여성 안양 진자 가족 동안구 마을',
#  '오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 가수 수안 공연 보고 뉴스',
#  '행사 주최 서울시 치과의사 이하 서울 지부 코로나 관련 사회 우려 대한 심각 대회 장인 김민겸 서울 지부 회장 지난 코로나 관련 정부 지침 생활 방역',
#  '경기 성남시 판교동 건물 근무 중인 남성 코로나 양성 판정 건물 학원 명과 직원 대해 조사 실시 학원 편의점',
#  '영진 직방 빅데이터 코로나 시장 충격 거래량 둔화 가격 조정 제한 판단 올해 가구',
#  '포스트 코로나 시대 극보을 울산 뉴딜 사업 성과 울산 미래 산시 포스트 코로나 시대 극보을 울산 뉴딜 사업 성과 울산 미래 발판 마련',
#  '송하진 도지사 코로나 지역 사회 위해 공무원 기부 릴레이 천년 전북 미래 발전 지역 인재 양성 위해 관심 가지 장학 사업 동참',
#  '정하영 시장 장기 코로나 로부터 우리 스스로 생활 방역 일상 이번 발열 크기 도입 시민 더욱 안심 대중교통 이용',
#  '남양주 시청 코로나 진자 발생 남양주시 진자 여성 화도읍 우리 서희 스타 힐스 아파트 거주 남양주 시청 감염 경로 서대문구 진자',
#  '표광오 통복동 코로나 확산 위협 상황 방역 대원 모두 시민 건강 지킴 자부심 가지 방역 협력 체계 구축 감염병 통복동 적극',
#  '통해 코로나 어려움 취약 계층 원금 만원 동부 희망 케어 센터 지정 김복순 적십자 사회 호평 회장 얼마 금액 회원 정성 코로나',
#  '또한 원산지 표시 리플릿 원산지 표시 배부 식중독 예방 코로나 예방 홍보 활동 병행 예정 교상 감사 담당 이번 단속 통해 양심 행위 원산지 식품 위해 사고 예방 최선',
#  '코리아 화천군 보건 의료 음압 구급 차량 구입 코리아 화천군 보건 의료 코로나 대응 위해 음압 구급 차량 구입 화천군 코로나 진자 발생 이송 음압',
#  '환호 방교 코로나 국민 모두 시기 소방 공무원 칭찬 정말 더욱 서비스 국민 생명 안전 위해 최선',
#  '이번 폭염 대응 코로나 감염 예방 확산 방지 위해 사람 접촉 가능성 행동 요령 코로나 감염 예방 냉방 기기 용법 홍보 주민 건강 안전 집중 예정',
#  '사업 추진 앞서 지난 산림 바이오매스 집단 선발 완료 참여자 대상 코로나 관련 산림 녹지 이상일 산림 조성 코로나 침체 상황 이번 사업 통해 사회',
#  '코로나 국가 전염병 이슈 자연재해 대비 국민 안전 생존 지원 사회 안전 지속 개발 계획 한편 하이닉스 지난해 지역 사회 고객 협력 주주 대상',
#  '강경화 위원장 호국 영령 순국선열 기리 가장 첫걸음 태극기 게양 생각 코로나 외출 만큼 태극기 게양 통해 순국선열 대한 마음',
#  '내외 뉴스 통신 전남 무안군 지난 일과 남악 초등학교 무안 초등학교 개학 맞이 코로나 코로나 예방 적극 홍보 마스크 쓰기 친구 창문',
#  '독일 프랑크푸르트 예정 코로나 온라인 진행 이번 결과 자료 학회 홈페이지 통해 공개 셀트리온 발표',
#  '그날 이슈 정리 한눈 정리 코로나 토트넘 하세베 리버풀 베르너 외질 그래픽 황지영 사진 게티 이미지 코리아 포포투 무단 배포 금지',
#  '다단계 건강 용품 판매 업체 리치 웨이 관련 코로나 진자 오전 최소 파악 지난 리치 웨이 안산 환자 다음 날인 지난 두통 인후 코로나 의심 증상',
#  '가수 수안 오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 위해 공연 뉴스',
#  '가수 수안 오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 위해 공연 뉴스',
#  '정식품 관계자 코로나 이후 건강 트렌드 저당 지방 대한 소비자 관심 더욱 체계 설계 누구 안심',
#  '방문 코로나 대응 격려 직원 의견청취 당면 현안 업무 보고 본부장 예산 소방 주요 당면 현안 업무 보고 안전 센터 순회 코로나 상황',
#  '경북 교육청 코로나 경제 어려움 학부모 교육비 부담 위해 미리 납부 임종 교육감 학비 반환 통해 코로나 장기 화로 어려움 학부모 교육비 부담',
#  '남훈 주식 운용 본부장 테크 업종 코로나 무역 분쟁 일부 수혜 기업 기본 전기차 자동화 로봇 주요 테마 집중 목표 성과 달성',
#  '출시 원스 카드 구독 경제 특화 상품 코로나 영향 사회 거리 두기 일상 언택트 시대 더욱 주목 이번 광고 신한카드 매달 비용 물건',
#  '김용찬 행정부 지사 코로나 국내외 여건 상황 충남 빛낼 스타 기업 선정 자긍심 지역 경제 활성화 위해 노력 달라 기업인 당부 충남 스타 기업',
#  '선수금 만원 기준 쉐보레 코로나 어려움 수고 격려 위해 우리 히어로 여러분 쉐보레 응원',
#  '코로나 이후 시간 휴식 공간 엔터테인먼트 공간 공간 인테리어 수요 증가 인테리어 시공 결과 대해 불만 표시 소비자 덩달아 증가',
#  '오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 가수 수안 공연 보고 뉴스',
#  '광주 전남 지역 소재 중소기업 일자 리창 기업 최대 창업 기업 코로나 피해 중소기업 최대 이번 상생 펀드 통한 대출 금리 우대 실질 이자 부담 완화 코로나 경영 어려움',
#  '언론 이번 사태 관련 사실 정부 표현 규정 인종차별 코로나 사태 네가지 방위 경우 코로나 지원 투입 병력 합치 미국 각종 사태 동원 규모',
#  '코로나 경제 위기 극복 해법 비중 정부 산업 신진대사 촉진 코로나 위기 기회 방향 보고 신호',
#  '코로나 확산 온라인 수업 비대 활동 디지털 환경 적응 현대 생활 필수 요소 포스트 코로나 시대 대비 디지털 환경 토론회 이혜리 기자 기자 사상 초유 온라인',
#  '한편 석남 메트로 시티 홍보 인천광역시 서구 가좌동 위치 코로나 예방 방문객 편의 방문자 접촉 최소 위해 사전 방문 약제 실시',
#  '세계보건기구 도널드 트럼프 미국 대통령 코로나 예방 차원 복용 말라리아 앞서 워드 로스 사무 총장 지난달 코로나 치료 제의 효능 안전성 실험 연대 실험',
#  '금융 서비스 소비자 만족도 서비스 제공 신뢰 입사 희망 증가 요즘 코로나 또한 코로나 해외여행 중단 지금 직원 복지 차원 양평 별장 금융 마련',
#  '최근 수도권 중심 코로나 바이러스 감염 확산 자동차 설명 드라이브 스루 방식 진행 참석자 발열 검사 자료 자동차 라디오',
#  '방역 당국 손길 코로나 관리 위해 김학무 기자 보도 기자 최근 코로나 진자 속출 물류 센터 다중 이용 시설 종교 모임 정부',
#  '오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 가수 공연 보고 뉴스',
#  '코로나 확산 위해 무료 급식 소가 모두 허기 해결 노숙인 코로나 굶주림 지도 바이러스 우리 서로',
#  '수도권 중심 신종 코로나 바이러스 감염증 코로나 산발 집단 감염 윤미향 민주당 의원 이슈 중도 이탈 이어진 결과 이념 성향 중도',
#  '기술 완성 우선 기술 활용 코로나 생활 방역 지침 수어 애니메이션 제작 공개 이정우 기자 기자 코로나 이후 감염 정보 동선 감염병 예방 정부',
#  '국정 신문 최태원 국정 신문 서울 강서 구청 관내 코로나 진자 발생 소식 강서 구청 가양 거주 남성 화곡 거주 남성 각각 코로나 확진 판정',
#  '여수시 코로나 장기 화로 각종 문화 행사 취소 연기 경제 어려움 지역 오봉 여수시 코로나 어려움 여수 지역 문화 예술 단체 재정 지원 통해',
#  '통과 가구 만원 소득 증가 자영 업자 이득 신종 코로나 바이러스 감염증 코로나 여파 민생 현장 기반 생존 현실 법안',
#  '강행 둔덕동 홀로 어르신 지속 관심 사업 운영 지역 사회보장 협의 협력 코로나 시간 지역 주민 위해',
#  '임종 농협 손해 보험 부사 코로나 화훼농가 어려움 장기 농협 손해 보험 지속 농촌 활동 통해 농가 안정 기여 최선',
#  '다른 일시 요인 신종 코로나 바이러스 감염증 코로나 세계 경제 부진 수출 부진 영향 라며 통상 상품 수지 흑자 기록 소득 수지 적자 무역수지',
#  '경주시 코로나 사회 거리 두기 생활 거리 두기 전환 이후 관내 야영장 코로나 예방 조기 종식 최선 경주 유원 시설 야영장 사회 거리 두기 점검 모습',
#  '영양 군청 전경 영양군 설명 올해 상반기 코로나 세계 확산 중지 외국인 계절 근로 사업 추진 일정 도입 인원 코로나 상황 대한 대응 방안 설명',
#  '대상 코로나 진단 검사 실시 경주시 경희 학교 기숙사 고등학교 코로나 진단 검사 모습 경주시 제공 경주시보건소 교육지원청 지난달 관내 개교 학생',
#  '억이 초고 아파트 정부 부동산 규제 코로나 거래 침체 분위기 최근 억원 억원 거래 단지 강남 일대 아파트 단지',
#  '올해 코로나 영향 주목 디지털 비대 분야 기업 육성 위해 관련 사업 제안 기업 가점 부여 예정 또한 기업 부담 위해 정부 원금 수준 기업 부담 금도 전액',
#  '코로나 경기 침체 밤사이 뉴욕 증시 급등 코스피 또한 질문 코로나 팔지 재고 면세 시중 판매 관심 판매',
#  '경북 교육청 교육감 임종 지난 코로나 경제 어려움 학부모 교육비 임종 교육감 학비 반환 통해 코로나 장기 화로 어려움 학부모 교육비 부담',
#  '포스트 코로나 시대 대비 위해 클라우드 수요 급증 데이터 허브 설립 설명 한편 기부 올해 하반기 본격 추진 제조 플랫폼 사업 통해',
#  '코로나 침체 지역 사회 발전 기여 더욱 노력 포스트 코로나 대비 비대 온라인 수업 인프라 구축 콘텐츠 개발 취업률 향상 프로그램',
#  '국회 코로나 바이러스 감염증 이하 코로나 사태 극복 차원 정부 추가경정예산 처리 계획 일정 빼곡 계획 민주당 미래 통합',
#  '문체부 정책 담당자 이번 사업 통해 광고 인재 성함 코로나 여파 어려움 광고 산업 불어 라며 광고 산업 코로나 이후 시대',
#  '닭고기 가격 코로나 이후 하락 한우 돼지고기 반면 닭고기 요리 과정 때문 분석',
#  '실제 표고버섯 키트 경우 최근 무료 생활 코로나 대란 불리 화제 중심 자리 무럭무럭 버섯 재배 키트 구입 허브 비롯 기타',
#  '포스트 코로나 시대 비대 영업 환경 적극 대응 온라인 통해 고객 코로나 사태 대면 상담 고객 원거리 다이렉트 지점 방문 고객 누구 이용',
#  '패션 기업 그룹 회장 박순 지난달 코로나 치료 확산 방지 위해 대한민국 모든 박순 회장 코로나 극복 위해 대처 정부 관계자 밤낮없이 헌신',
#  '기후 환경 조절 효과 청장 녹지 정비 도심 녹색 공간 시민 더욱 이용 코로나 시민 마음 위안',
#  '최근 코로나 여파 경제 어려움 소상 공인 업자 수도 요금 요금 지자체 코로나 상황 반영 즉시 시행 권고 국민권익위 권익 개선 정책 국장 이번',
#  '하겐다즈 아이스크림 활용 이번 카페베네 여름 메뉴 코로나 여파 사회 거리 두기 일상 메뉴 선호 문화 빙수 프라 페노 음료',
#  '시즌 코로나 리그 개막 국방부 시계 명의 코로나 전입 선수 주간 자가 격리 공백 체력 훈련 만일 이번 선수',
#  '기업 그룹 신종 코로나 바이러스 감염증 코로나 전국 각지 분투 중인 의료 위해 메뉴인 크리스 치킨 간식 지원 계속',
#  '유플러스 코로나 언택트 시대 리얼 글래스 온라인 개발 세미나 개최 시간 동안 통해 실시간 참여 해당',
#  '코로나 사태 이후 기업 생존 대면 사업 비대 사업 최적 조합 이번 콘서트 김경준 딜로이트 컨설팅 부회장 코로나 이후 언택트 시대 우리 미래 주제',
#  '코로나 사태 이후 기업 생존 대면 사업 비대 사업 최적 조합 이번 콘서트 김경준 딜로이트 컨설팅 부회장 코로나 이후 언택트 시대 우리 미래 주제',
#  '전자 주가 연일 상승 코로나 이전 수준 회복 돌진 시장 신종 코로나 바이러스 감염증 코로나 언택트 비대 선호 현상 수요 증가 이유',
#  '정하영 김포시 혁신 교육 지구 사업 특수교육 대상자 사업 별도 편성 소외 학생 면서 코로나 교육과정 운영 판단 학생 안전',
#  '계획 코로나 이후 군민 문화생활 영위 위해 창의 공연 행정 방침 김돈 군수 코로나 때문 군민 경제 사회 분야 변화',
#  '이번 협약 신종 코로나 바이러스 감염증 코로나 경제 고용 사회 전반 시기 가운데 산림청 대한민국 중앙 행정기관 장애인 고용 대한 사회 책무 인식 선도',
#  '임종 농협 손해 보험 부사 코로나 화훼농가 어려움 장기 농협 손해 보험 지속 농촌 활동 통해 농가 안정 기여 최선',
#  '무안군 군수 김산 지난 일과 남악 초등학교 무안 초등학교 개학 맞이 코로나 예방 캠페인 코로나 예방 적극 홍보 마스크 쓰기 친구 창문',
#  '기업인 이동 보장 시장 개방 확대 포스트 코로나 협력 제안 박성준 기자 성윤 산업 통상 자원부 장관 아시아 국가 장관 코로나 현황 화상회의 참석 아시아 국가 기업인',
#  '오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 입장 체온 재고 뉴스',
#  '최근 포스트 코로나 비대 언택트 전환 게임 가능성 평가 정부 기회 산업 육성 언급 게임 다시금 주목 추세 지역 자치 단체',
#  '신종 코로나 바이러스 감염증 코로나 확산 언택트 시대 글래스 온라인 개발 세미나 개최 오전 시간 동안 통해 실시간 참여 해당',
#  '계획 코로나 이후 군민 문화생활 영위 위해 창의 공연 행정 방침 김돈 군수 코로나 때문 군민 경제 사회 분야 변화',
#  '제주도 교육청 관계자 코로나 장기 화로 어려움 방과후 학교 강사 조금 도움 지급 목표 헤드라인 제주',
#  '관계자 포스트 코로나 시대 시민 안전 더욱 이슈 라며 유관 기관 민간 단체 시민 적극 참여 안전 도시 당진 당진 박승 기자',
#  '국내 여행 해외여행 선호 세대 코로나 여파 제주도 발길 요즘 세대 최신 트렌드 추구 차별 이색 경험 선호 특징 세대 밀레',
#  '정부 코로나 극복 추경안 공개 가운데 노후 건축물 모델링 사업 포함 면서 어린이집 보건소 의료 기관 임대주택 효율 환기 시스템 보강',
#  '코로나 다시 기지개 엔젤스 파이팅 챔피언십 호준 대표 한국 맥그리거 실제 지난 대회 개최 세계 팬데믹 이어진 코로나 바이러스 사태 무기한',
#  '올해 현충일 추념 코로나 확산 대한 우려 생활 거리 두기 지침 당초 계획 인원 이춘희 시장 코로나 행사 규모 축소 순국선열 호국 영령 기리 마음',
#  '수확 시기 마늘 농가 코로나 영향 외국인 근로자 입국 지연 인력 수급 일손 돕기 참여자 마스크 착용 건강 거리 유지 코로나 예방 준수 농가 지원 길정섭',
#  '정부 코로나 대응 한국 뉴딜 일환 그린 뉴딜 추진 장관 기후 위기 시대 녹색 전환 경제 탄소 기반 생태계 순환 자정 복원 생태 회로 변화',
#  '오산시청 전경 사진 오산시 오산시 코로나 확산 방지 위해 예정 현충일 추념 취소 시민 누구 참배 자율 분향소 운영 자율 분향소 코로나',
#  '한국 마사회 김낙순 회장 데이터 제공 우수 기관 선정 코로나 극복 정부 디지털 뉴딜 정책 한국 마사회 최선 의미 데이터 문호 개방 민간 분야 협업 통한',
#  '코로나 사태 대비 국민 안전 생존 지원 사회 안전 개발 김윤욱 하이닉스 지속 경영 담당 대비 사회 성과 감소 부정 영향',
#  '코로나 위기 기회 전환 화훼 온라인 직거래 판매 또한 주목 행사 취소 코로나 여파 어려움 화훼농가 대책 기존 방식 전국 최초 온라인',
#  '코로나 때문 어디 서든 최선 다해 응원 야구장 야구 한국 시리즈 창원',
#  '가수 오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 위해 공연 뉴스',
#  '가수 오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 위해 공연 의료 진의 사연',
#  '코리아 대표 김대환 국내 코로나 극복 위해 자사 기술 자원 투입 코리아 이번 코리아 성금 코로나 방역 위해 노력 의료 자원봉사자 지원 도움',
#  '토트넘 프리미어리그 사무국 실시 코로나 진단 검사 명의 진자 발생 대해 토트넘 사무국 코로나 검사 결과 명의 무증상 진자 연락',
#  '대사 코로나 작년 중국 우한 발생 세계보건기구 세계 유행병 의미 팬데믹 분류 테드 로스 세계보건기구 사무 총장 걸음 세계 지금 코로나 전쟁',
#  '리얼 글래스 온라인 개발 세미나 개최 유플러스 코로나 언택트 시대 리얼 글래스 온라인 개발 세미나 개최 오전 시간 동안',
#  '올해 신종 코로나 바이러스 감염증 생활 거리 두기 준수 사회 혁신 창업 대표 이야기 소통 창업 특강 프로그램 온라인 전환 진행',
#  '의원 농어 금융 지원 추경 증액 보증 업무 중단 위기 천억원 추가 지원 절실 신종 코로나 바이러스 감염증 코로나 대응 정부 추가경정예산 축산 금융 지원',
#  '코로나 계기 마련 정부 주도 한국판 뉴딜 프로젝트 가시 양사 추진 포스트 코로나 시대 도시 주거 환경 디지털 트랜스 메이 선도',
#  '이상원 동장 코로나 모두 긴급 재난 원금 후원 물품 기부 지역 경제 취약 계층 도움 일석이조 효과 생각 기부 익명',
#  '지난 부처님오신날 국가 공휴일 신종 코로나 바이러스 감염증 코로나 확산 일인 일로 연기 개최 부처님오신날 봉축 행사 봉행 대미 문의',
#  '포스트 코로나 시대 극복 비대 스마트 공항 서비스 제공 위해 적극 노력 강용 와이즈넛 대표 국내 챗봇 상용 노하우 상용 서비스 운영',
#  '양사 산업혁명 포스트 코로나 시대 택트 솔루션 사물인터넷 인공 지능 김상철 한컴 그룹 회장 코로나 정부 부처 지자체 기업 학생 레퍼런스 사용자',
#  '코로나 국가 전염병 이슈 자연재해 대비 국민 안전 생존 지원 사회 안전 지속 개발 계획 한편 하이닉스 지난해 지역 사회 고객 협력 주주 대상',
#  '사진 광주시 이번 여름 마스크 기부 최근 수도권 중심 코로나 다시 확산 대해 신동헌 시장 최근 코로나 집단 감염 사례 생활 거리 두기 전환 개인 위생',
#  '길동 카드 마케팅 본부장 신종 코로나 바이러스 어려움 고객 조금 이벤트 준비 고객 생활 전반 혜택 제공',
#  '코로나 극복 위해 최선 광주 서부 교육지원청 장덕 초등학교 학생 거대 학교 장덕 코로나 로부터 학생 위해 입실 발열',
#  '올해 신종 코로나 바이러스 감염증 생활 거리 두기 준수 사회 혁신 창업 대표 이야기 소통 창업 특강 프로그램 온라인 전환 진행',
#  '한편 국선 수좌 코로나 감염 예방 동참 위해 경자년 하안거 결제 음력 윤달 일로 연기 경자년 하안거 결제 일로 전국 선원 명의 수좌',
#  '리얼 글래스 온라인 개발 세미나 개최 유플러스 코로나 언택트 시대 리얼 글래스 온라인 개발 세미나 개최 오전 시간 동안',
#  '주석 국빈 방일 당초 올해 예정 신종 코로나 바이러스 감염증 코로나 확산 여파 연기 주석 방일 시기 대해 예정 주요 개국 정상 회의 먼저 틀림',
#  '전남 여수시 코로나 장기 화로 어려움 지역 문화 예술 단체 만원 상당 사랑 상품권 지원 대상 고유 번호 사업자 등록증 소재지 여수',
#  '울산 기념 사업 위원회 코로나 국가 위기 진행 민주 항쟁 기념 생활 코로나 이후 변화 세상 가장 모범 방역 극복 이정표 국민 모두',
#  '오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 가수 공연 보고 뉴스',
#  '김용찬 행정부 지사 코로나 국내외 여건 상황 충남 빛낼 스타 기업 선정 자긍심 지역 경제 활성화 위해 노력 달라 기업인 당부 충남 스타 기업',
#  '임현 코로나 어려움 소득 위해 사용 달라 의왕시 성금 만원 기부 임현 대표 코로나 더욱 어려움 소득 성금 기탁',
#  '신종 코로나 백신 임상시험 중인 노비 백신 생산 상대 소송 백신 대량생산 정보 공개 신종 코로나 바이러스 백신 소송 개발 회사 노비 백신 제조 국내',
#  '농어촌 공사 경영 혁신 선희 부장 코로나 어려움 지역 중소기업 창업 기업 지원 창업 기업 코로나 피해 중소기업 최대 억원 한도 기존 대출 금리 자동',
#  '펀드 운용 남훈 주식 운용 본부장 펀드 설정 직후 코로나 본격 확대 무역 분쟁 점화 주식시장 등락 테크 업종 코로나 무역 분쟁 일부 수혜',
#  '크론 그룹 관계자 코로나 전세계 확산 가운데 이번 케어 밸브 마스크 국내 국가 요청 대응 코로나 예방 적극 기여 기업',
#  '연극 리미트 연출자 로써 리미트 대한 애정 사랑 김민교 연극 통해 코로나 관객 웃음 긍정 에너지 선물 리미트 대학로',
#  '코로나 극복 여름 보양식 우리 늦둥이 하이에나 남매 외식 생활 코로나 극복 여름 보양식 코로나 예년 더위 사람',
#  '코로나 우리 일상 경제 흐름 정책 국가 기조 이제 모두 포스트 코로나 초점 정부 지자체 차례 긴급 재난 원금 지급 경제 활성화 정치권',
#  '포스트 코로나 시대 대비 우리 경제 글로벌 선도 경제 변화 위해 과학기술 포스트 코로나 시대 경제위기 극복 방안 제시 선도 경제 실현 가능성 상징',
#  '버섯 건강 분식 자연 경관 자랑 괴산 코로나 심신 치유 기회 당부',
#  '독일 프랑크푸르트 예정 코로나 온라인 셀트리온 스케 코로나 병원 방문 환자 직접 투여',
#  '패션 기업 그룹 지난달 코로나 치료 확산 방지 위해 대한민국 모든 의료 대한 박순 회장 코로나 극복 위해 대처 정부 관계자 밤낮없이 헌신',
#  '정의당 심상정 대표 국회 상무 위원회 코로나 민생 절벽 대비 획기 최근 언론 인터뷰 통해 지사 코로나 종식 경제 상당 기간 가능성',
#  '정상회담 양국 협력 의료 정보통 기술 확장 최근 카타르 코로나 진단 카타르 코로나 관련 진단 장비 공급 방역 경험 공유 양국 협력 범위 확대',
#  '코로나 타격 전통 시장 서서히 활기 활기 계속 지속 관심 대해 이사장 전국 전통 시장 코로나 매우 시기',
#  '출처 온라인 커뮤니티 대구 달서구 위치 상원 중학교 학생 코로나 확진 판정 대구 지역 코로나 확진 환자 추가 대구시 중앙 방역 대책 본부 오전 달서구',
#  '올해 코로나 이후 언택트 비대 테마 언택트 기반 올해 코로나 팬데믹 글로벌 통신사 투자 규모 위축 영향 대감',
#  '이상직 의원 코로나 국난 극복 최대 이슈 상황 경선 합의 추대 통한 선출 방식 의견 민주당 도당 위원장 이상직 의원 주병',
#  '이사장 전국 전통 시장 코로나 매우 시기 최근 전통 시장 실제 방문객 모습 대한민국 동행 일과 공동 마케팅',
#  '공공시설 코로나 수도권 집단 발생 운영 일시 중단 금번 이용 중단 기간 향후 코로나 상황 연장 재개 일정 관련 부처 지침 지자체 지역 감염',
#  '인천 미추홀 거주 연수구 목사 코로나 확진 판정 개척 교회 집단 감염 양성 판정 미추홀 목사 지난달 차례',
#  '우리 종합 금융 코로나 사태 이익 누리 은행권 신규 대출 보수 관리 앞서 코로나 확산 무렵 우리 금은 억원 가량 유동성 확보 다음 본격',
#  '무산 스님 주기 다례 재는 코로나 확산 방지 위해 일로 연기 봉행 주기 다례 조계종 전계 대화 성우 스님 비롯 원로 의원 동화사 회주 의현 화암사 회주 정휴',
#  '시간 상담 문의 신종 코로나 바이러스 감염증 코로나 확산 방지 위해 사전 예약 제로 운영 때문 사전 방문 예약 필수 문의사항 대표 번호 문의 안내',
#  '올해 코로나 여파 국내 최초 무관 비대 형식 시간 온라인 생중계 방식 진행 엔카 박람회 사전 접수 통해 지원 구직 대상 온라인 화상 면접 실시 면접',
#  '요즘 한일 양국 모두 신종 코로나 바이러스 감염증 코로나 확산 대응 강제 징용 해법 찾기 사실 중단 분위기 더구나 최근 일본 수출 규제 조치 취소 갈등 고조',
#  '칼림바 소리 악보 요즘 코로나 취미 생활 인기 악기 프로그램 운영 드림 스타트 아동 부모 일주일 단위 연주 미션 악보 집의',
#  '코로나 여파 무관 진행 올해 공연 극장 돌체 최용민 재즈 스토리 학산 극장 김정식 미추홀 청장 코로나 상황 문화 예술 공연 직접 관람',
#  '스타트업 주간 이슈 리포트 코로나 급변 스타트업 생태계 기적 모니터링 적시성 트렌드 포스트 코로나 시대 국내외 스타트업 정책 주제 기획 예정',
#  '면세점 업계 코로나 여파 유급 휴직 확대 코로나 장기 화로 매출 회복 기미 보이지 만큼 인건비 절감 나선 분석 업계 신라 면세점 중순 서울 본점',
#  '박미순 회장 코로나 국민 어려움 시기 역설 지구 생물 더욱 생동 이상 지구 인간 유물 인식 환경',
#  '곽상욱 오산시 코로나 침체 지역 경제 활성화 위해 지역 소비 촉진 소상 공인 영세 자영 업자 불어 계기 이번 대상 수상 계기',
#  '서울시 온라인 국제 회의 글로벌 서밋 포스트 코로나 시대 서울 유망 포스트 코로나 시대 산업 모델 우리 기업 잠재력 확인',
#  '오산 사회 협의 코로나 취약 계층 물품 지원 협약 체결 기념 촬영 오산 사회 협의 회장 이규희 코로나 어려움 지역 취약 계층 지원 위해 오산시',
#  '신종 코로나 바이러스 감염증 코로나 지역 이동 경제 더욱 요즘 그동안 지역 특성 곳곳 자연 문화 상품화 주목 지역 창업',
#  '날씨 코로나 확산 생활 거리 두기 일환 민원 접촉 최소 가지 화초 녹색식물 종합 민원 시민 미적 안정감',
#  '코로나 영향 언택트 일상 자리 가운데 최근 언택트 온택트 마케팅 김정희 동아오츠카 스웨 캠페인 담당자 코로나 집콕 상황',
#  '요즘 한일 양국 모두 신종 코로나 바이러스 감염증 코로나 확산 대응 강제 징용 해법 찾기 사실 중단 분위기 더구나 최근 일본 수출 규제 조치 취소 갈등 고조',
#  '스타트업 주간 이슈 리포트 코로나 급변 스타트업 생태계 기적 모니터링 적시성 트렌드 포스트 코로나 시대 국내외 스타트업 정책 주제 기획 예정',
#  '코로나 영향 언택트 일상 자리 가운데 최근 언택트 온택트 마케팅 김정희 동아오츠카 스웨 캠페인 담당자 코로나 집콕 상황',
#  '면세점 업계 코로나 여파 유급 휴직 확대 코로나 장기 화로 매출 회복 기미 보이지 만큼 인건비 절감 나선 분석 업계 신라 면세점 중순 서울 본점',
#  '지사 코로나 지금 마스크 수급 톱텍 본격 마스크 생산 시작 도내 안정 마스크 수급 도움 공적 마스크 충남도 자체 비축 물량 만장',
#  '곽상욱 오산시 코로나 침체 지역 경제 활성화 위해 지역 소비 촉진 소상 공인 영세 자영 업자 불어 계기 이번 대상 수상 계기',
#  '언택트 비즈니스 분류 만큼 포스트 코로나 시대 성장 잠재력 무궁무진 지점 하나 모바일 플랫폼 금융 서비스 제공 입증 카카오 뱅크',
#  '우리 종합 금융 코로나 사태 이익 누리 은행권 신규 대출 보수 관리 앞서 코로나 확산 무렵 우리 금은 억원 가량 유동성 확보 다음 본격',
#  '양승조 충남지사 신종 코로나 바이러스 감염증 코로나 지금 마스크 수급 톱텍 본격 마스크 생산 시작 도내 안정 마스크 수급 도움',
#  '올해 코로나 여파 국내 최초 무관 비대 형식 시간 온라인 생중계 방식 진행 엔카 박람회 사전 접수 통해 지원 구직 대상 온라인 화상 면접 실시 면접',
#  '지멘스 헬시 어스 신종 코로나 바이러스 감염증 코로나 진단 항체 검사 긴급 사용승인 미국 획득 지멘스 헬시 어스 독일 엘랑겐 본사 의료 기업 지멘스',
#  '코로나 여파 무관 진행 올해 공연 극장 돌체 최용민 재즈 스토리 학산 극장 김정식 미추홀 청장 코로나 상황 문화 예술 공연 직접 관람',
#  '인천 개척 교회 모임 관련 파악 코로나 진자 현재 수도권 최근 개척 교회 집단 부흥회 관련 코로나 진자 모두 어제 방역 당국',
#  '공공시설 코로나 수도권 집단 발생 운영 일시 중단 금번 이용 중단 기간 향후 코로나 상황 연장 재개 일정 관련 부처 지침 지자체 지역 감염',
#  '신종 코로나 바이러스 감염증 코로나 확산 체온 측정 중요성 대두 시대 반영 이자 하나 기술 탑재 분야 관심 누리꾼 시선 다만 스마트폰',
#  '세종 뉴스 윤창 기자 정은경 질병 관리 본부 오후 세종시 정부 세종 청사 신종 코로나 바이러스 국내 발생 현황 브리핑 복지부 복수 차관 도입 보건 의료',
#  '사회 은행 모간 코로나 사태 어려움 소상 공인 지원 위해 온라인 코로나 소비 위축 비대 소비 비시 판도 변화 상공',
#  '더위 코로나 때문 경로당 무더위 운영 홀몸 시간 번은 환기 코로나 호흡기 질환 지금 대구 동성로',
#  '이번 정기 통해 코로나 사태 마음 위로 감성 작품 감상 또한 회화 서예 조소 장르 개성 작품 다수 지역 미술 문화 주소 가늠',
#  '올해 분기 대형 저축은행 실적 코로나 저축은행 대출 증가 이자 수익 코로나 여파 비대 문화 확산 상황 대형 저축은행 비대 마케팅 적극 향후',
#  '코로나 고용 위기 극복 지역 경제 활성화 협약 조근제 함안 군수 참석자 코로나 극복 공감 형성 역할 분담 협약 체결',
#  '신동빈 회장 안성 스마트 팩토리 포스트 코로나 대응 그룹 대표 사례 라며 스마트 팩토리 원자재 제품 생산 제조 이력 추적 만큼 식품 안전 대응',
#  '선수금 만원 기준 쉐보레 코로나 어려움 수고 격려 위해 우리 히어로 여러분 쉐보레 응원',
#  '당초 올해 개최 예정 코리아 투어 차례 일정 연기 최근 코로나 진자 개최 일정 역시 연기 고등학생 참여 오픈 대회 병행 코리아 투어',
#  '코로나 장기 고립 경제 시대 디지털 간편식 집콕 관련 주식 비대 콘텐츠 산업 로봇 물류 산업 주가 코로나 완전 종식 비대 단절 고립 화두 전망',
#  '국내 신종 코로나 바이러스 감염증 코로나 백신 임상시험 시작 서울대 병원 국제 연구소 코로나 백신 국내 임상시험 계약 발표 국내 코로나 백신',
#  '후세 오늘 현재 코로나 경제 여건 수출입 통관 관세 행정 집중 지원 위기 극복 전력 허광욱 글로벌 코노믹 기자',
#  '신동빈 롯데 회장 포스트 코로나 시대 대비 디지털 전환 가속 다짐 롯데 신동빈 신동빈 회장 코로나 영향 디지털 전환 더욱 가속 범위 확대 예상',
#  '신동빈 회장 코로나 영향 디지털 전환 더욱 가속 범위 확대 예상 안성 스마트 팩토리 올해 주요 시스템 구축 완료 만큼 포스트 코로나 대응',
#  '대표 기업 요즘 코로나 펜데믹 사태 가장 기업 넷플릭스 회사 일체 보너스 최고 연봉 보장 직원 대우 양질 직원 확보',
#  '이제 대다수 사람 코로나 시대 단계 바로 우리 사람 인기 요즘 전기자전거 사기 코로나 초기 정제 사기',
#  '코로나 대비 위해 개수대 화장실 여러 사람 반드시 마스크 휴대 손소독제 준비 릴랙스 힐링 안정감 기본 박윤선 기업 커뮤니케이션 컨설팅 그룹 메디아',
#  '코로나 연구 프로세서 기반 고성능 컴퓨팅 시스템 제공 이번 시스템 제공 조성 펀드 통해 진행 펀드 컴퓨팅 자원 제공 통해 연구기관 코로나',
#  '코로나 때문 시합 걱정 환경 시합 김대환 대표 정문 대표 감사 이번 경기 사실 마음 경기 때문 마음',
#  '신종 코로나 바이러스 감염증 코로나 확산 랜선 응원 리그 리그 구단 대한 이야기 불법 스포츠 도박 근절 내용 동영상 확인 이벤트',
#  '코로나 정국 아주 생경 시간 다소 흥분 순간 세상 다시 한번 급변 애플 실시 제품 브리핑 대략 가지 형식 진행',
#  '신종 코로나 바이러스 감염증 코로나 장기 화로 언택트 비대 교육 디지털화 대한 관심 온라인 교육 패러다임 교육 기술 결합 에듀 테크 시장 주목',
#  '이번 행사 코로나 확산 방지 행사 규모 년도 간소화 생활 방역 지침 자리 라며 코로나 모두 시기 지금 시기 순국선열',
#  '오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 가수 공연 보고 뉴스',
#  '코로나 장기 여파 살이 사람 신조어 전쟁 공개 선언 다이어트 관심사 최근 요요 현상 다이어트 성공 인생',
#  '산시 코로나 위축 청년 창업 기업 지역 인지도 판로 개척 위해 산시 시장 송철호 코로나 위축 청년 창업 기업 지역 인지도 판로 개척 위해',
#  '이번 콘서트 김경준 딜로이트 컨설팅 부회장 코로나 이후 언택트 시대 우리 미래 주제 영상 강연 부회장 코로나 서적 전화 정보 교환 아날로그 세계',
#  '오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 가수 공연 보고 뉴스',
#  '다만 코로나 확산 방지 차원 비대 실시간 온라인 강의 전환 진행 테크 리더 아카데미 금융 위원회 테크 지원 사업 하나로 직장인 일반인 수강 대상 교육',
#  '부산 구치소 코로나 사태 수용 안정 위해 교화 프로그램 사랑 편지 쓰기 사회 단절 코로나 접견 제한 수용 부모님 사랑 안부',
#  '버드와이저 브랜드 매니저 코로나 집콕 생활 소비자 위해 실력 뮤지션 크루 온택트 라이브 퍼포먼스 마련 버드와이저 버드 엑스 비츠 통해 실력',
#  '이번 코로나 경제 위기 극복 국가 협력 방안 시장 개방 유지 확대 상품 서비스 이동 원활 기업인 이동 보장 코로나 이후 대비 협력 확대 제시 코로나 이후 협력',
#  '코로나 의료 폐기물 처리 모습 사진 포천시 제공 신종 코로나 바이러스 감염증 코로나 여파 우리나라 의료 폐기물 처리 체계 해외 노하우 의료 폐기물 제대로',
#  '연구원 소재 매출 본격 화가 전사 실적 성장 라며 중국 정부 역시 코로나 침체 경기 회복 위해 전기차 보조금 기간 연장 방안 발표 대외 환경',
#  '해남군 공청회 제시 지역 주민 전문가 의견 수렴 의회 의견청취 월경 도시재생 뉴딜 사업 최종 공모 예정 공청회 코로나 감염 예방 위해 마스크 착용 생활',
#  '유플러스 코로나 언택트 시대 리얼 글래스 온라인 개발 세미나 개최 오전 시간 동안 통해 실시간 참여 해당',
#  '코로나 사태 확산 체온계 방역 최전선 널리 활용 아이 개학 연기 상황 교육 기관 등교 대비 대책 우리나라 해외 코로나',
#  '건강 용품 판매 다단계 홍보 리치 웨이 관련 코로나 진자 무더기 주로 노인 상대로 홍보 밀폐 공간 때문 집단 감염 가능성 앞서 이태원 클럽',
#  '일자리 과장 이번 교육 코로나 생애 환기 취업 어려움 중장 대가 요양보호사 출발 디딤돌 역할 교육',
#  '이번 행사 코로나 확산 방지 위해 행사 규모 년도 간소화 생활 방역 지침 자리 라며 코로나 모두 시기 지금 시기 순국선열',
#  '글로벌 치킨 전문 브랜드 기업 그룹 코로나 전국 각지 분투 중인 의료 위해 메뉴인 크리스 치킨 간식 지원 계속 코로나 확산',
#  '게다가 코로나 사람 판매 피핀 전체 주류 비량 태국 코로나 정부 맥주 업계 한바탕 갈등 빚었다 정부 지난 술자리 사회 활동',
#  '최근 코로나 때문 해외여행 서비스 수지 최근 개선 흐름 주요 기업 상표권 특허권 사용 수취 지식 재산권 사용 수지 적자',
#  '교육 최근 코로나 수도권 지역 확산 학생 개학 대량 환자 발생 대응 단계 사전 예방 교육 일환 코로나 로부터 방역 검사 환자 대응 방법 방역 사항 검사 방법 실제',
#  '실무 코로나 관련 한국 의료 폐기물 관리 대응 경험 지식 공유 이번 세미나 유엔 개발 계획 요청 마련 나은 환경 재건 코로나 대응 한국 국가',
#  '올해 코로나 팬데믹 위기 극복 위해 신청 전원 소정 장학금 전달 동일 이사장 이번 장학금 전달 코로나 감염병 확산 국가 재난 상황 고자 탁자',
#  '처음 시작 올해 호국 보훈행사 개최 대학교 코로나 국가행사 취소 거나 축소 가운데 예년 간소 대학 매년 행사 나라 사랑',
#  '출시 원스 카드 구독 경제 특화 상품 코로나 영향 사회 거리 두기 일상 언택트 시대 더욱 주목 이번 광고 신한카드 매달 비용 물건',
#  '고등학교 등교 시작 한국 교육과정평가원 주관 대학 수학 능력 시험 모의 평가 중순 예정 그간 신종 코로나 바이러스 감염증 코로나 확산 때문 설명 자동차 방식',
#  '대표 코로나 신종 코로나 바이러스 감염증 타격 올해 매출 억원 지난해 매출 만원 영업 이익 만원 기록 국내 세계',
#  '최근 수도권 중심 확산 코로나 감염 사태 외부 출입 코로나 확산 지속 상황 대규모 모임 비판',
#  '신종 코로나 감염증 코로나 영향 면역 대한 관심 면역 증진 도움 전남 장흥 표고버섯 주목 장흥군 표고버섯 본초강목 동의보감',
#  '펀드 운용 남훈 주식 운용 본부장 펀드 설정 직후 코로나 본격 확대 무역 분쟁 점화 주식시장 등락 테크 업종 코로나 무역 분쟁 일부 수혜',
#  '글래스 온라인 개발 세미나 개최 유플러스 코로나 언택트 시대 리얼 글래스 온라인 개발 세미나 개최 오전 통해 실시간',
#  '최근 신종 코로나 바이러스 감염증 코로나 장기 화로 언택트 비대 교육 대한 관심 가운데 교육 기술 결합 에듀 테크 시장 급부 에듀 테크 시장 전세계 시장 규모 조원',
#  '이번 업무 협약 신종 코로나 바이러스 감염증 코로나 영향 온라인 쇼핑 축산물 거래 동월 대비 기준 증가 언택트 비대 구매 서비스 비문 대응 지역 특산 물의',
#  '코로나 비대 요구사항 모바일 접수 상담 예약 사회 거리 두기 실천 방문 시험 인증 수요 충족 설명 이번 서비스 사용',
#  '북도 올해 코로나 극복 추경 예산 편성 비대 사업 일환 경북 우수 제품 온라인 입점 지원 온라인 쇼핑 입점 어려움 신규 업체 대상 온라인 입점 교육 예정 코로나',
#  '이번 새김 국난 극복 순국선열 마음 신종 코로나 바이러스 감염증 코로나 위기 우리 사회 당면 여러 난제 의미 박진영',
#  '한편 시상식 매년 토요일 개최 안양시 청소년 예정 올해 코로나 장기 화로 표창장 학교 전달 수여 계획',
#  '코로나 때문 시합 걱정 환경 시합 김대환 대표 정문 대표 감사 이번 경기 사실 마음 경기 때문 마음',
#  '한우 군수 군민 목소리 관광 시장 다변 관광 트랜드 정책 더없이 코로나 극복 희망이 살기',
#  '코로나 사태 발생 이후 크루즈선 부산 입항 지난 퀀텀 오브 이후 개월 만이 부산 항만 공사 정부 협의 통해 특별 검역 코로나 검사 일간 지정 시설 추가 격리 조치 조건',
#  '코로나 사회 격리 완화 이후 유니클로 호점 호치민시 개장 베트남 식품 의류 사진 유니클로 베트남 식품 의류 인테리어 업종 월말 코로나 사회 격리 완화',
#  '김순철 재단 사무 총장 온라인 교육 코로나 사회 거리 두기 차원 효율 지원이 금년 협력 기관 내외 확대 온라인 교육 컨텐츠 지속 개발',
#  '신종 코로나 바이러스 감염증 코로나 치료 개발 기업 간의 무한 경쟁 총성 전쟁 비견 만하 각국 대표 제약 바이오 치료 개발',
#  '독일 프랑크푸르트 예정 코로나 온라인 셀트리온 스케 코로나 병원 방문 환자 직접 투여',
#  '정하영 김포시 장기 코로나 로부터 우리 스스로 생활 방역 일상 이번 발열 크기 도입 시민 더욱 안심 대중교통 이용',
#  '국제 영화제 코로나 여파 관객 영화인 안전 우선 영화제 형식 실험 벌이 영화제 단기 온라인 상영 장기 상영 변신 독도 영화 아버지',
#  '코로나 예방 위해 별도 폐회식 발열 체크 방역 소독 추진 만전 서종열 문화 관광 체육 진흥 코로나 상황 대회 긴장',
#  '정부 임시 국무회의 경제위기 극복 포스트 코로나 시대 대비 추경안 확정 국회 제출 공감 언론 뉴시스 독자 여러분',
#  '코로나 전반 고용 시장 침체 분위기 가운데 지난해 올해 사회 고용 채용 관계자 한국 대표 책임감 브랜드 로서 코로나 침체 채용 분위기',
#  '정부 임시 국무회의 경제위기 극복 포스트 코로나 시대 대비 추경안 확정 국회 제출 공감 언론 뉴시스 독자 여러분',
#  '정부 임시 국무회의 경제위기 극복 포스트 코로나 시대 대비 추경안 확정 국회 제출 공감 언론 뉴시스 독자 여러분',
#  '정부 임시 국무회의 경제위기 극복 포스트 코로나 시대 대비 추경안 확정 국회 제출 공감 언론 뉴시스 독자 여러분',
#  '또한 봄철 화재 특수 시책 코로나 방서 운영 소방 안전교육 중단 온라인 강의 통해 소방 안전교육 가정 사무실 기회 제공 소방관 온라인',
#  '코로나 위생 중요성 강조 요즘 시기 호응 박찬 위원장 지역 사회보장 협의 이불 세탁 서비스 사업 통해 지역 어르신 장애인 먼지 진드기',
#  '코로나 전반 고용 시장 침체 분위기 가운데 지난해 올해 사회 고용 채용 관계자 한국 대표 책임감 브랜드 로서 코로나 침체 채용 분위기',
#  '오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 가수 공연 보고 뉴스',
#  '지난달 전체 직원 이메일 코로나 이후 직원 희망 경우 업무 코로나 세계 유행 기간 동안 일반 차원 가상공간 협업 프로그램 무료 공개',
#  '오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 가수 공연 보고 뉴스',
#  '오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 가수 공연 보고 뉴스',
#  '오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 가수 공연 보고 뉴스',
#  '노비 개발 후보 물질 임상시험 개시 서울대학교 병원 국제 연구소 신종 코로나 바이러스 감염증 코로나 백신 국내 임상시험 수행 협력 계약',
#  '오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 가수 공연 보고 뉴스',
#  '제주 서귀포 롯데 스카이 제주 롯데 칸타타 여자오픈 신종 코로나 바이러스 감염증 코로나 확산 방지 위해 무관 경기 진행 사진 번홀 그린 전경',
#  '실무 코로나 관련 한국 의료 폐기물 관리 대응 경험 지식 공유 이번 세미나 유엔 개발 계획 요청 마련 나은 환경 재건 코로나 대응 한국 국가',
#  '보령 중부 발전 본사 한국 중부 발전 사장 형구 코로나 장기 재생 공급 인증서 형구 중부 발전 사장 코로나 모두 시국 극복 조치 적극 발굴',
#  '과정 이수 학생 동안 미국 구글 애플 인공 지능 분야 첨단 기업 방문 실리콘 밸리 연수 프로그램 기회 다만 코로나 사태 추이 변동',
#  '통영시 시설 관리 사업 소장 코로나 상황 한국어 교육 열정 수강생 시립 도서관 생활 거리 두기 지침 준수 방역 물품 비치 개인 위생',
#  '코로나 전반 고용 시장 침체 분위기 가운데 지난해 올해 사회 고용 채용 관계자 한국 대표 책임감 브랜드 로서 코로나 침체 채용 분위기',
#  '강석주 통영시 코로나 기업 불구 관내 소외 계층 기부 동참 소외 이웃 사회',
#  '오후 서울 중랑구 의료 의료 잠시 콘서트 신종 코로나 바이러스 감염증 코로나 환자 진료 위해 수고 의료 가수 공연 보고 뉴스',
#  '이번 업무 협약 코로나 영향 온라인 쇼핑 축산물 거래 동월 대비 기준 송하진 도지사 포스트 코로나 시대 개인 방역 건강 대한 관심 부쩍',
#  '이번 캠페인 코로나 관계 인원 참석 청각장애 이해 판넬 진열 농아인 협회 지속 청각장애 자원 봉사활동 평생교육 프로그램 통한 사회 참여',
#  '코로나 바이러스 예방 대응 위해 노력 의료 감사 존경 마음 전하 덕분 린지 캠페인 참여 덕분 린지 캠페인 보건복지부 코로나 예방 위해 고생 의료',
#  '코로나 사태 전기차 판매 급증 화학 수혜 예상 화학 글로벌 배터리 시장 향후 코로나 사태 이후 수요 더욱 전망 미래에셋 대우 증권 세계 전기 차용 배터리',
#  '참여 사회 이번 좌담 코로나 감염 예방 수칙 준수 위해 마스크 대신 서로 거리 본격 이야기 앞서 요즘 코로나 상황 일상 학교 수업 거의',
#  '무주 산골 영화제 코로나 여파 관객 무주 군민 안전 도모 영화제 또순이 우주 대해 주체 자신 개척 주인공 또순이 캐릭터 코로나 시대',
#  '코로나 수업 활성화 수강신청 수가 지난해 대비 만큼 주목 단계 올해 코로나 상황 반영 서울대 고려대 종바이러스 이해 건강 보건 증진 전염병 대응',
#  '대외 경제정책 연구원 보고서 통해 중국 부양책 고용 민생 안정 집중 코로나 충격 예상 다만 코로나 중국 세계 다시 대유행 경우',
#  '또한 코로나 여파 시기 혼신 의료 덕분 시기 만큼 우리 모두 응원',
#  '세계 보건 질병 관리 본부 중앙 방역 대책 본부 상황 코로나 사망 환자 희생 추모 묵념 시행 복지부 미국 또한',
#  '광산구청 식품위생 과로 우편 방문 접수 광산구 관계자 이번 사업 음식점 위생 상태 개선 코로나 어려움 상공 부담',
#  '롯데 자산 개발 롯데 김포공항 코로나 확산 방지 위해 내부 공간 야외 광장 행사 개최 롯데 김포공항 코로나 실내 야외 공간 선호',
#  '윤석환 부장 코로나 어려움 군민 조금 도움 회원 기부 동참 코로나 이웃 나눔 손길 예년',
#  '농가 코로나 영향 외국인 근로자 입국 지연 인력 수급 어려움 농가 일손 돕기 참여자 마스크 착용 건강 거리 유지 코로나 예방 준수 농가',
#  '신종 코로나 바이러스 감염증 코로나 국가 전염병 이슈 자연재해 대비 국민 안전 생존 지원 사회 안전 지속 개발 계획 김윤욱 하이닉스 지속 경영 담당',
#  '대중음악 뮤지션 콘서트 코로나 확산 우려 취소 가운데 박기영 공연 취소 박기영 소속사 문라이트 퍼플 플레이 예정 공연 취소',
#  '가평군 제공 포스트 코로나 시대 관광명소 가평 부상 가평군 최근 가평군 자라섬 올해 한국 관광 공사 선정 야간 경관 앞서 경기도 코로나 시대 안전 관광',
#  '코로나 확산 집합 교육 경우 어플리케이션 통한 온라인 휴대전화 교육 대체 병행 예정 모집 대상 청년 정책 활동 관심 사람',
#  '김남성 어촌 계장 코로나 어려움 어업 위해 관내 남북 한강 방류 어업 생계 유지 자본형성 도움 감사 인사',
#  '경기도 부천 쿠팡 물류 창고 관련 신종 코로나 바이러스 감염증 코로나 진자 최근 경기도 동부 교회 감염 번지 모양새 경기도 광명시 수원시',
#  '이번 업무 협약 코로나 영향 온라인 쇼핑 축산물 거래 대비 가까이 증가 송하진 전라북도지사 포스트 코로나 시대 개인 방역 건강 대한 관심 부쩍',
#  '코로나 바이러스 세계 축구 시계 베스트 일레븐 축구 위해 재물 준비 해외 클럽 대표 최고 레전드 소개 기획 이름 레전드 타임머신',
#  '코로나 확산 우리 주변 일상 모습 크게 대표 매일 차례 반복 포스트 코로나 시대 선제 대비 필요성 지적 현재 시민 체험 디지털',
#  '포스트 코로나 시대 언택트 비대 방식 구현 타인 접촉 도면 관리 혁신 처리 플랫폼 주목 만하 관계자',
#  '보건소 코로나 검사 양성 판정 경기도 의료 파주 병원 이송 군포시 보건소 구급 차량 한편 서울 관악구 다단계 판매 업체 리치 웨이 직원 판매원 코로나 확진 판정 리치 웨이',
#  '고등학교 등교 시작 한국 교육과정평가원 주관 대학 수학 능력 시험 모의 평가 중순 예정 그간 신종 코로나 바이러스 감염증 코로나 확산 때문 설명 자동차 방식',
#  '코로나 집합 행사 모임 자제 사회 거리 두기 추진 상황 사안 코로나 다소 지연 입지 선정위 협조 체계 군민 중심 청사',
#  '고등학교 등교 시작 한국 교육과정평가원 주관 대학 수학 능력 시험 모의 평가 중순 예정 그간 신종 코로나 바이러스 감염증 코로나 확산 때문 설명 자동차 방식',
#  '코로나 사태 해지 비용 증가 지난해 분기 영업 이익 순이익 실적 이상 감소 또한 지난해 분기 운용 손익 금융 수지 부문 규모 영업 수익',
#  '추진단 코로나 영향 현장 점검 앞서 서면 자료 확보 현장 민원 주안 운영 공익 제보 핫라인 방법 통해 도민 누구 제보 홍보 위법 사례',
#  '양승조 지사 코로나 지금 마스크 수급 톱텍 본격 마스크 생산 시작 충남도 마스크 수급 안정화 공적 마스크 충남도 자체 비축 물량 확보',
#  '링크 플로우 김용국 대표 최근 신종 코로나 바이러스 감염증 코로나 영향 산업 현장 원격 커뮤니케이션 대한 필요성 버넥트 협업 통해 산업 현장 업무 효율',
#  '포스트 코로나 시대 언택트 비대 방식 구현 타인 접촉 도면 관리 혁신 처리 플랫폼 주목 만하 관계자',
#  '일자리 과장 이번 교육 코로나 생애 환기 취업 어려움 중장 대가 요양보호사 출발 디딤돌 역할 교육',
#  '연기 올림픽 축소 개최 방안 대한 검토 요미우리 신문 내년 여름 코로나 아베 신조 일본 총리 그동안 연기 통해 도쿄올림픽 코로나 극복 인류 제전',
#  '올해 신종 코로나 바이러스 감염증 생활 거리 두기 준수 사회 혁신 창업 대표 이야기 소통 창업 특강 프로그램 온라인 전환 진행',
#  '보건소 코로나 검사 양성 판정 경기도 의료 파주 병원 이송 군포시 보건소 구급 차량 한편 서울 관악구 다단계 판매 업체 리치 웨이 직원 판매원 코로나 확진 판정 리치 웨이',
#  '코로나 한국 마사회 영역 맞춤 지원 한국 마사회 특색 동시 사회 코로나 위기 화훼농 돕기 한국 마사회 화훼 농가 역시 코로나 생계 직격탄',
#  '양사 산업혁명 포스트 코로나 시대 언택트 솔루션 사물인터넷 인공 지능 김상철 한컴 그룹 회장 코로나 정부 부처 지자체 기업 학생 레퍼런스 사용자',
#  '오늘 오전 기준 서울 지역 코로나 진자 어제 새벽 시보 서울시 추가 진자 감염 경로 이상 수도권 개척 교회 관련 관악구 건강 용품 회사 관련',
#  '추진단 코로나 영향 현장 점검 앞서 서면 자료 확보 현장 민원 주안 운영 공익 제보 핫라인 방법 통해 도민 누구 제보 홍보 위법 사례',
#  '코로나 당분간 비대 중심 행사 진행 기관 변호사 온라인 강의 전문가 토크 법률 콘텐츠 제공 법률 플랫폼 논리 변호사 유튜브 채널 법률',
#  '또한 신종 코로나 바이러스 감염증 코로나 확산 인도 시장 봉쇄 침체 예상 신제품 출시 대응 평가 실제 전자 지난 인도 공장',
#  '코로나 사태 발생 이후 크루즈선 부산 입항 지난 퀀텀 오브 이후 개월 위해 부산 항만 공사 정부 협의 통해 특별 검역 코로나 검사 일간 지정 시설 추가',
#  '시상식 매년 토요일 안양시 청소년 예정 올해 코로나 장기 화로 표창장 학교 전달 수여 계획 최대호 안양시장 축하 시상식',
#  '중부 매일 여군 기자 영동군 공무원 농촌 일손 돕기 본격 추진 코로나 농촌 시름 나채정 기획 감사 코로나 더욱 가중 지역 농민 어려움 살피 지역 사회',
#  '과학기술 기초 연구 조명 사실 소개 과학기술 원동력 한국 코로나 세계 주목 위기 극복 모델 강조',
#  '독일 프랑크푸르트 예정 코로나 온라인 셀트리온 스케 코로나 병원 방문 환자 직접 투여',
#  '김선희 대표 코로나 위해 공직자 지역 사회 단체 회원 코로나 예방 방역 활동 적극 진자 군민 안심 생활 조금',
#  '경기도 수원시 권선구 남성 코로나 확진 판정 남성은 지난달 추정 감염 경로 조사 수원시 관내 코로나 진자 모두',
#  '준비 코로나 생활 거리 두기 생활 이상 거리 두기 참가자 체온 측정 자주 환기 참가 신청 운영 추후 코로나 추이 참가자 계획',
#  '이번 정기 통해 코로나 사태 마음 위로 감성 작품 감상 권종 포항 미술 협회장 코로나 상황 작품 출품 회원 감사',
#  '전경련 허창수 회장 미국 의회 감사 서한 송부해 먼저 코로나 매우 시간 미국 국민 위로 말씀 국전 지금 지난 시간 동안',
#  '한국 코로나 대응 모델 강조 세계 도시 동시 감염병 만큼 한국 위기 극복 사례 적용 피해 최소 취지 코로나 극복 대응',
#  '원외 신분 의원 코로나 국난 극복 여당 대표 활동 기회 차기 대선 도전 발판 현재 민주당 전당대회 의원 의원 홍영표 의원',
#  '제주 서귀포 롯데 스카이 제주 롯데 칸타타 여자오픈 신종 코로나 바이러스 감염증 코로나 확산 방지 위해 무관 경기 진행 사진 번홀 그린 전경',
#  '코로나 타격 전통 시장 서서히 활기 활기 계속 지속 관심 대해 이사장 전국 전통 시장 코로나 매우 시기',
#  '강원 화천군 보건 의료 코로나 대응 위해 음압 구급 차량 구입 화천군 코로나 진자 발생 이송 음압 구급 차량 구입 업무 배치 구급차 구입 예산',
#  '윤재관 청와대 부대 변인 연합뉴스 부대 변인 정상회담 통해 양국 협력 에너지 의료 확장 최근 카타르 코로나 관련 진단 장비 공급 방역 경험 공유 양국 협력 범위',
#  '대구시 달서구 상인동 위치 상원 중학교 학생 코로나 확진 판정 대구시 오전 상원 학년 학생 코로나 검사 양성 판정 코로나 공식 통계',
#  '코로나 사태 불교 가르침 기반 명상 수행 대중 지점 직접 선일 스님 지금 코로나 사태 극복 치유 가지 명상 수행',
#  '시장 다만 코로나 종식 다소 걱정 이번 기회 토양오염 정화 사업 출입 어려움 예상 행사 추진 시민 건강',
#  '항진 여주시 자연환경 코로나 청정 지역 이미지 상승 여주 방문객 증가 신륵사 관광지 금은 모래 유원지 금은 모래 강변 공원 관광지 중심 마스터 플랜',
#  '한국 중부 발전 본사 전경 한국 중부 발전 사장 형구 코로나 장기 화로 경제 어려움 중부 발전 형구 사장 코로나 모두 시국 극복 조치 적극 발굴',
#  '박종환 한국 유총 연맹 총재 신종 코로나 바이러스 감염증 코로나 극복 조기 종식 응원 격려 전하 스테이 스트롱 캠페인 동참 자유 연맹 총재 박항서 베트남 축구',
#  '이상훈 회장 코로나 신규 진자 수도권 발생 정부 수도권 한정 사회 거리 두기 코로나 종식 적극 협조 면서 지금 국민 지탄 치과의사']

# %%
## TF-IDF 기반 단어별 출현빈도 계산
posTfidf = TfidfVectorizer(tokenizer=oktToken, min_df=2)

# %%
posDtm = posTfidf.fit_transform(finalPosDescWords)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
posTfidf.get_feature_names_out()
# Out:
# array(['가', '가격', '가구', '가능성', '가량', '가속', '가수', '가운데', '가장', '가지', '각종',
#        '각지', '간소화', '간식', '갈등', '감사', '감상', '감성', '감소', '감염', '감염병',
#        '감염증', '강의', '강제', '강조', '개발', '개방', '개선', '개월', '개인', '개척', '개최',
#        '개학', '거래', '거리', '거주', '걱정', '건강', '검사', '검역', '게임', '격려', '격리',
#        '결과', '결합', '경관', '경기', '경기도', '경로', '경북', '경영', '경우', '경제',
#        '경제위기', '경주시', '경험', '계기', '계속', '계약', '계층', '계획', '고객', '고등학교',
#        '고용', '고조', '공간', '공감', '공개', '공공시설', '공급', '공무원', '공사', '공식',
#        '공연', '공유', '공익', '공인', '공적', '과장', '과정', '과학기술', '곽상욱', '관객',
#        '관계자', '관광', '관내', '관람', '관련', '관리', '관심', '관악구', '광고', '광주', '교육',
#        '교육감', '교육과정', '교육과정평가원', '교육비', '교육지원청', '교육청', '교회', '구급', '구독',
#        '구입', '구직', '구축', '구현', '국가', '국난', '국내', '국내외', '국무회의', '국민',
#        '국제', '국회', '군민', '군수', '군포시', '규모', '규제', '그간', '그동안', '그룹', '그린',
#        '극복', '극장', '근로자', '글래스', '글로벌', '금리', '금번', '금융', '금은', '급변',
#        '급증', '기간', '기관', '기념', '기록', '기리', '기미', '기반', '기본', '기부', '기술',
#        '기업', '기업인', '기여', '기자', '기적', '기존', '기준', '기회', '기획', '기후', '긴급',
#        '김경준', '김대환', '김돈', '김상철', '김용찬', '김윤욱', '김정식', '김정희', '김포시', '나눔',
#        '나선', '나은', '남성', '남악', '남훈', '내외', '년도', '노력', '노비', '노하우', '녹색',
#        '녹지', '농가', '농민', '농촌', '농협', '누구', '누리', '뉴딜', '뉴스', '뉴시스', '능력',
#        '다단계', '다만', '다소', '다시', '다음', '단계', '단절', '단체', '달라', '달서구', '담당',
#        '담당자', '당국', '당면', '당부', '당초', '대가', '대구', '대구시', '대면', '대비', '대상',
#        '대상자', '대신', '대외', '대우', '대응', '대중교통', '대책', '대처', '대출', '대통령',
#        '대표', '대학', '대한', '대한민국', '대해', '대회', '더구나', '더욱', '더위', '덕분',
#        '데이터', '도내', '도면', '도민', '도시', '도움', '도입', '도지사', '독일', '독자', '돌체',
#        '돕기', '동부', '동선', '동시', '동아오츠카', '동안', '동월', '동참', '두기', '등교',
#        '등락', '디딤돌', '디지털', '딜로이트', '때문', '또한', '라며', '레퍼런스', '로봇', '로부터',
#        '로서', '로스', '롯데', '리그', '리얼', '리치', '리포트', '마련', '마사회', '마스크',
#        '마음', '마케팅', '만원', '만큼', '만하', '맞이', '매년', '매달', '매우', '매일', '매출',
#        '먼저', '메뉴', '메뉴인', '면서', '면세점', '면접', '명의', '모니터링', '모델', '모두',
#        '모든', '모바일', '모습', '모의', '모임', '목표', '무관', '무렵', '무료', '무안', '무안군',
#        '무역', '문의', '문화', '문화생활', '물건', '물량', '물류', '물품', '뮤지션', '미국',
#        '미래', '미술', '미추홀', '민간', '민생', '민원', '민주당', '바이러스', '박람회', '박순',
#        '반영', '반환', '발굴', '발생', '발열', '발전', '발판', '발표', '밤낮없이', '방문',
#        '방문객', '방문자', '방법', '방식', '방안', '방역', '방지', '방침', '백신', '버섯', '번호',
#        '번홀', '범위', '베트남', '변화', '별도', '병원', '병행', '보건', '보건소', '보고', '보수',
#        '보이지', '보장', '보험', '복지부', '본격', '본부', '본부장', '본사', '본점', '봉행',
#        '부담', '부사', '부산', '부장', '부쩍', '부처', '부회장', '분기', '분류', '분석', '분야',
#        '분위기', '분쟁', '분투', '불리', '불어', '브랜드', '브리핑', '비대', '비롯', '비용',
#        '비축', '빛낼', '사람', '사랑', '사례', '사무', '사물인터넷', '사실', '사안', '사업',
#        '사용', '사용자', '사장', '사전', '사진', '사태', '사회', '사회보장', '산시', '산업',
#        '산업혁명', '상공', '상담', '상당', '상승', '상원', '상품', '상황', '생각', '생계', '생산',
#        '생애', '생존', '생중계', '생태계', '생활', '서귀포', '서로', '서면', '서비스', '서서히',
#        '서울', '서울대', '서울시', '선도', '선수금', '선정', '선호', '설명', '설정', '성과',
#        '성금', '성장', '세계', '세계보건기구', '세미나', '세상', '센터', '셀트리온', '소개', '소득',
#        '소방', '소비', '소비자', '소상', '소외', '소재', '소통', '손길', '손해', '솔루션',
#        '송하진', '쇼핑', '수고', '수급', '수도권', '수상', '수안', '수업', '수여', '수요',
#        '수원시', '수익', '수준', '수지', '수출', '수학', '수행', '수혜', '순국선열', '쉐보레',
#        '스님', '스마트', '스스로', '스웨', '스카이', '스케', '스타', '스타트업', '스토리', '시간',
#        '시계', '시국', '시기', '시대', '시민', '시상식', '시설', '시스템', '시작', '시장', '시청',
#        '시합', '시행', '시험', '식품', '신규', '신동빈', '신라', '신문', '신종', '신청',
#        '신한카드', '실무', '실시', '실시간', '실적', '실제', '실험', '쓰기', '아파트', '안성',
#        '안심', '안양시', '안전', '안정', '안정감', '앞서', '애플', '양국', '양사', '양성',
#        '양승조', '어려움', '어르신', '어제', '억원', '언론', '언택트', '업계', '업무', '업자',
#        '업종', '업체', '에너지', '에듀', '엔카', '여건', '여러', '여러분', '여름', '여성', '여수',
#        '여수시', '여자오픈', '여파', '역시', '역할', '연구', '연구소', '연구원', '연기', '연장',
#        '영령', '영세', '영업', '영위', '영향', '영화제', '예년', '예방', '예산', '예상', '예술',
#        '예약', '예정', '오늘', '오브', '오산시', '오전', '오후', '온라인', '온택트', '올해',
#        '완료', '완화', '외국인', '외식', '요양보호사', '요즘', '요청', '용품', '우려', '우리',
#        '우리나라', '우선', '우수', '운영', '운용', '울산', '원금', '원스', '웨이', '위기', '위로',
#        '위법', '위생', '위원장', '위원회', '위축', '위치', '위해', '유급', '유동성', '유엔',
#        '유지', '유플러스', '육성', '은행권', '음압', '응원', '의견', '의견청취', '의료', '의미',
#        '의원', '의회', '이동', '이미지', '이번', '이벤트', '이사장', '이상', '이송', '이슈',
#        '이야기', '이어진', '이용', '이웃', '이익', '이자', '이제', '이하', '이해', '이후',
#        '인건비', '인공', '인기', '인력', '인식', '인원', '인재', '인천', '인테리어', '일간',
#        '일과', '일로', '일본', '일부', '일상', '일손', '일시', '일자리', '일정', '일환',
#        '임상시험', '임시', '임종', '입국', '입항', '자긍심', '자동차', '자료', '자리', '자연',
#        '자연재해', '자영', '자원', '자체', '작품', '잠시', '잠재력', '장관', '장기', '장비',
#        '장애인', '재개', '재건', '재고', '재난', '재즈', '적극', '적시성', '적자', '전경', '전국',
#        '전기차', '전남', '전달', '전망', '전문가', '전반', '전세계', '전염병', '전자', '전쟁',
#        '전체', '전통', '전하', '전환', '절감', '점검', '점화', '접수', '접촉', '정기', '정말',
#        '정문', '정보', '정부', '정상회담', '정책', '정하영', '제공', '제보', '제시', '제안',
#        '제조', '제주', '제주도', '제출', '제품', '제한', '조금', '조기', '조사', '조성', '조치',
#        '조합', '종식', '종합', '주가', '주간', '주관', '주목', '주민', '주식', '주식시장', '주안',
#        '주요', '주제', '주주', '준비', '준수', '중국', '중단', '중랑구', '중부', '중소기업',
#        '중순', '중심', '중앙', '중요성', '중인', '중장', '중학교', '증가', '증진', '지구', '지금',
#        '지급', '지난', '지난달', '지난해', '지능', '지사', '지속', '지식', '지역', '지연', '지원',
#        '지자체', '지점', '지정', '지침', '직원', '직접', '직후', '진단', '진료', '진자', '진행',
#        '질병', '집단', '집중', '집콕', '집합', '징용', '차량', '차례', '차원', '착용', '참석',
#        '참석자', '참여', '참여자', '창문', '창업', '창의', '찾기', '채용', '책임감', '처리',
#        '청년', '청사', '청소년', '청와대', '청장', '체결', '체계', '체온', '초등학교', '촉진',
#        '총장', '최고', '최근', '최대', '최선', '최소', '최용민', '최적', '최초', '추가',
#        '추가경정예산', '추경', '추경안', '추념', '추이', '추진', '추진단', '축구', '축산물', '축소',
#        '출발', '출시', '출입', '충격', '충남', '충남도', '취소', '취약', '취업', '측정',
#        '치과의사', '치료', '치유', '치킨', '친구', '침체', '카드', '카타르', '칸타타', '캠페인',
#        '커뮤니케이션', '컨설팅', '케어', '코로나', '코리아', '콘서트', '콘텐츠', '퀀텀', '크기',
#        '크루즈선', '크리스', '클럽', '타격', '타인', '테마', '테크', '토요일', '토트넘', '톱텍',
#        '통상', '통영시', '통한', '통해', '투여', '투입', '트렌드', '특강', '특별', '특성',
#        '특수교육', '특화', '파악', '파주', '판단', '판매', '판매원', '판정', '패션', '팩토리',
#        '팬데믹', '펀드', '편성', '평가', '폐기물', '포스트', '표고버섯', '표시', '표창장',
#        '프랑크푸르트', '프로그램', '플랫폼', '피해', '필수', '필요성', '하나', '하이닉스', '학교',
#        '학부모', '학비', '학산', '학생', '한국', '한우', '한일', '한컴', '한편', '핫라인', '항만',
#        '해결', '해당', '해법', '해외', '해외여행', '행사', '행정', '행정부', '향후', '허브',
#        '헌신', '혁신', '현대', '현상', '현장', '현재', '현충일', '현황', '협력', '협약', '협업',
#        '협의', '협조', '형구', '형식', '호국', '홍보', '화로', '화상', '화제', '화천군', '화훼',
#        '화훼농', '확대', '확보', '확산', '확인', '확장', '확정', '확진', '환경', '환기', '환자',
#        '활기', '활동', '활성화', '활용', '회복', '회사', '회원', '회의', '회장', '효과', '효율',
#        '휴직', '흐름', '희망', '히어로'], dtype=object)

# %%
posVocas = dict()

for i, word in enumerate(posTfidf.get_feature_names_out()):
    posVocas[word] = posDtm.getcol(i).sum() # 해당 단어의 빈도수

# %%
#빈도수가 높은 것부터 정렬
posWords = sorted(posVocas.items(), key=(lambda x: x[1]), reverse=True)

# %%
posWords
# Out:
# [('코로나', 28.606906262901767),
#  ('의료', 13.296885470147892),
#  ('위해', 11.030793024381511),
#  ('바이러스', 9.43248517406488),
#  ('신종', 8.9988958269972),
#  ('감염증', 8.807143736008022),
#  ('온라인', 7.789613709834091),
#  ('시대', 7.519671379081892),
#  ('사회', 7.177625337894438),
#  ('확산', 6.949652600278028),
#  ('이번', 6.783859498471104),
#  ('통해', 6.518164834657203),
#  ('지역', 6.517036287702728),
#  ('극복', 6.037066148026199),
#  ('어려움', 6.006709582988025),
#  ('포스트', 5.944467797455414),
#  ('기업', 5.474320752205622),
#  ('서울', 5.376343239183752),
#  ('정부', 5.17303483414093),
#  ('언택트', 5.154259929445038),
#  ('최근', 5.115156930234701),
#  ('사태', 5.104917080980284),
#  ('환자', 5.095927991453575),
#  ('생활', 4.982645594660691),
#  ('방역', 4.947559483381463),
#  ('대표', 4.917678952811684),
#  ('공연', 4.910777454696376),
#  ('사업', 4.893911091235726),
#  ('올해', 4.8757803578337935),
#  ('한국', 4.818322291520467),
#  ('우리', 4.781481099730156),
#  ('상황', 4.781254100421748),
#  ('비대', 4.77689565654135),
#  ('개발', 4.769871924703478),
#  ('경제', 4.76088287122301),
#  ('시장', 4.5513884005064185),
#  ('콘서트', 4.51303561249074),
#  ('이후', 4.418354753352077),
#  ('교육', 4.409991324791971),
#  ('예방', 4.355272484018323),
#  ('대응', 4.346721277844243),
#  ('수고', 4.286979815745977),
#  ('대비', 4.239775075352075),
#  ('진자', 4.183410678447919),
#  ('예정', 4.157190923387661),
#  ('지원', 4.147005026297914),
#  ('오후', 4.135917243483419),
#  ('뉴스', 4.093936233479974),
#  ('거리', 4.085575735538436),
#  ('개최', 4.039661329884128),
#  ('잠시', 3.991779994313196),
#  ('중랑구', 3.991779994313196),
#  ('진료', 3.991779994313196),
#  ('가수', 3.824229595855736),
#  ('여파', 3.805364605532681),
#  ('마스크', 3.7636795314209284),
#  ('두기', 3.7227491135686774),
#  ('안전', 3.6932949255421637),
#  ('관련', 3.692762796585472),
#  ('보고', 3.6511068719488686),
#  ('감염', 3.618628801393213),
#  ('장기', 3.5562853247088775),
#  ('영향', 3.503327789626722),
#  ('행사', 3.4693630865441234),
#  ('대한', 3.4455890377131677),
#  ('때문', 3.3486394564092805),
#  ('지난', 3.338654321073039),
#  ('시기', 3.3210862338312026),
#  ('위기', 3.3121803764712237),
#  ('더욱', 3.2416811192637773),
#  ('시간', 3.22206513202837),
#  ('침체', 3.1952235399556144),
#  ('회장', 3.1122657626981907),
#  ('진행', 3.0977834478790958),
#  ('협력', 3.0941466763751313),
#  ('세계', 3.0910071712341862),
#  ('운영', 3.0475109494816106),
#  ('모두', 3.043657802251216),
#  ('제공', 2.91328136185957),
#  ('세미나', 2.910869371704774),
#  ('관심', 2.88481733236107),
#  ('국가', 2.860113978633822),
#  ('주목', 2.8234431986895485),
#  ('건강', 2.808591190349561),
#  ('창업', 2.793991059875253),
#  ('관계자', 2.788080155093118),
#  ('학생', 2.779908719030323),
#  ('국민', 2.7618874231223014),
#  ('지속', 2.6849089407536404),
#  ('국내', 2.681618607881446),
#  ('시민', 2.663132697048598),
#  ('검사', 2.6277816138499697),
#  ('계획', 2.6180550000109992),
#  ('판정', 2.5683926160221127),
#  ('서비스', 2.554686964614845),
#  ('가운데', 2.5450552514625917),
#  ('또한', 2.508374381191415),
#  ('요즘', 2.4990449886052293),
#  ('연기', 2.4944980577838334),
#  ('기자', 2.4888300829510435),
#  ('적극', 2.456796057127705),
#  ('방문', 2.451671732067815),
#  ('방지', 2.423309347067139),
#  ('글래스', 2.404486272079224),
#  ('수도권', 2.4028428497813317),
#  ('프로그램', 2.4024641859274682),
#  ('방식', 2.396231632171925),
#  ('전환', 2.3930685879530422),
#  ('마음', 2.3790409781310373),
#  ('사람', 2.377081862124319),
#  ('판매', 2.3557880794199795),
#  ('대상', 2.339646416618905),
#  ('지금', 2.3257770157704334),
#  ('환경', 2.304995084703028),
#  ('군민', 2.287513966749839),
#  ('발생', 2.278975018168164),
#  ('산업', 2.275618439490991),
#  ('문화', 2.2612801537971423),
#  ('일상', 2.2563824212893566),
#  ('직원', 2.249146230398062),
#  ('증가', 2.249034334003287),
#  ('의원', 2.232805163707224),
#  ('추진', 2.2170765351068873),
#  ('경기', 2.2144600307835343),
#  ('참여', 2.212447238519456),
#  ('리얼', 2.2063585785030577),
#  ('화로', 2.2047989496735667),
#  ('만원', 2.1766433670543397),
#  ('동안', 2.1615249347051213),
#  ('롯데', 2.1564080395797802),
#  ('고용', 2.1530639955840227),
#  ('관리', 2.1502435926375263),
#  ('중심', 2.145285211523516),
#  ('이슈', 2.1039551986215486),
#  ('오전', 2.1032293001820355),
#  ('디지털', 2.076894645407233),
#  ('취소', 2.0650783316792114),
#  ('기회', 2.058034103692031),
#  ('확대', 2.0400488156986234),
#  ('분위기', 2.020887572103122),
#  ('활동', 2.0177786426233206),
#  ('미래', 2.012574276803818),
#  ('본격', 2.0004030373995896),
#  ('도움', 1.9876236249246304),
#  ('최선', 1.9789849218412985),
#  ('금융', 1.9738374437650126),
#  ('그룹', 1.9690344117889627),
#  ('한편', 1.9684573708608455),
#  ('기부', 1.9647372469104234),
#  ('응원', 1.9531693708238416),
#  ('만큼', 1.949406158928156),
#  ('중단', 1.9242153457080393),
#  ('업무', 1.9146713762616918),
#  ('홍보', 1.8995126239616),
#  ('설명', 1.890886932614539),
#  ('대해', 1.8671309293929963),
#  ('앞서', 1.8595898013724201),
#  ('리치', 1.8582937281335585),
#  ('웨이', 1.8582937281335585),
#  ('감사', 1.8568762882819076),
#  ('사진', 1.8513371976923403),
#  ('코리아', 1.8375742984329368),
#  ('미국', 1.8299192731578267),
#  ('공개', 1.829298456646912),
#  ('진단', 1.7978149221757436),
#  ('혁신', 1.7967433968851263),
#  ('지난해', 1.796205506097295),
#  ('집단', 1.7933198402577775),
#  ('유플러스', 1.792537276580852),
#  ('채용', 1.7762120738235203),
#  ('발전', 1.7594264132192974),
#  ('지침', 1.7588412143853076),
#  ('정책', 1.7559851623274039),
#  ('안정', 1.7366052889194084),
#  ('캠페인', 1.7205363678396535),
#  ('변화', 1.7148083496016624),
#  ('양국', 1.6959304039559409),
#  ('고객', 1.6839963123650326),
#  ('협약', 1.6803710912254899),
#  ('실시', 1.6648091887117304),
#  ('동참', 1.6637219611737544),
#  ('백신', 1.6598612581533385),
#  ('공간', 1.6509858070990835),
#  ('테크', 1.6462997542981423),
#  ('독일', 1.6408334796669088),
#  ('사랑', 1.6401856141481912),
#  ('병원', 1.6391286125544016),
#  ('관광', 1.638624741362643),
#  ('실시간', 1.6360528976431281),
#  ('준수', 1.635131065310391),
#  ('주제', 1.6275150392584865),
#  ('전국', 1.6093922986640388),
#  ('거래', 1.6078099075037051),
#  ('경험', 1.5989179612331843),
#  ('이용', 1.5860602116666778),
#  ('경기도', 1.585538732814204),
#  ('농가', 1.5842662531745475),
#  ('직접', 1.5717036051630324),
#  ('시작', 1.5688844237374657),
#  ('관내', 1.5685692203022477),
#  ('수급', 1.5678931083001393),
#  ('현장', 1.5651810777829782),
#  ('국회', 1.564214623121589),
#  ('소비', 1.5637549406872742),
#  ('생존', 1.561387512417159),
#  ('확진', 1.5603130694655198),
#  ('기관', 1.5601835208356647),
#  ('규모', 1.559561394769475),
#  ('언론', 1.5583972678223996),
#  ('양성', 1.5580239906444082),
#  ('순국선열', 1.557310328896166),
#  ('지난달', 1.5564710329818057),
#  ('뉴딜', 1.5524642065705567),
#  ('기술', 1.5481575098415212),
#  ('개척', 1.546085747851805),
#  ('여러분', 1.531040679648031),
#  ('글로벌', 1.5272100044948886),
#  ('마케팅', 1.5184876285176323),
#  ('라며', 1.5131765188461168),
#  ('종식', 1.5080882982274355),
#  ('부담', 1.506952666898482),
#  ('학교', 1.504270621420678),
#  ('기반', 1.502140226228974),
#  ('경제위기', 1.4942549885169052),
#  ('군수', 1.4858136195653426),
#  ('도입', 1.484765759589037),
#  ('활성화', 1.467504143423927),
#  ('차원', 1.4590614667309052),
#  ('영화제', 1.4580490325159485),
#  ('선호', 1.4557815871864497),
#  ('마련', 1.4469858929800568),
#  ('예상', 1.4467183860061925),
#  ('전통', 1.4461605757653724),
#  ('여름', 1.428208923493123),
#  ('환기', 1.4227664433514466),
#  ('생산', 1.4200044075053844),
#  ('서로', 1.4154535454133825),
#  ('업계', 1.412824312242529),
#  ('발열', 1.4127397594952702),
#  ('플랫폼', 1.407073806809846),
#  ('브랜드', 1.4033050310490987),
#  ('카타르', 1.3888991146687182),
#  ('지자체', 1.3815099817091059),
#  ('일정', 1.380186576375654),
#  ('모습', 1.378828996563039),
#  ('작품', 1.3683440826845579),
#  ('분야', 1.368215327734915),
#  ('접촉', 1.3652676321362196),
#  ('가지', 1.365052572264681),
#  ('억원', 1.3581672178208786),
#  ('추경안', 1.3532274221133909),
#  ('노력', 1.3503454440327658),
#  ('거주', 1.3478963995685376),
#  ('펀드', 1.3474600802877978),
#  ('치료', 1.346434075381646),
#  ('협의', 1.3439743049796196),
#  ('일로', 1.3344682117695794),
#  ('실제', 1.3319916513386811),
#  ('셀트리온', 1.3307545178005715),
#  ('프랑크푸르트', 1.3307545178005715),
#  ('이야기', 1.3295427747083433),
#  ('사실', 1.3244064792395402),
#  ('다만', 1.3234112817003922),
#  ('공감', 1.3120204531888597),
#  ('사전', 1.3052540348120976),
#  ('스타트업', 1.302070126457392),
#  ('메뉴', 1.2908278664927997),
#  ('단체', 1.2830729987281508),
#  ('해외', 1.2809149699028521),
#  ('경우', 1.2768954258925982),
#  ('수요', 1.2729820388884239),
#  ('계층', 1.2660802662052215),
#  ('중부', 1.26503254389804),
#  ('가능성', 1.2612108250145335),
#  ('위축', 1.257935408165654),
#  ('트렌드', 1.2565854539501953),
#  ('자리', 1.2549369027192165),
#  ('자동차', 1.248616981818258),
#  ('기준', 1.2481410320096022),
#  ('계기', 1.2436444766123653),
#  ('해당', 1.2426478263817506),
#  ('평가', 1.240965172474335),
#  ('통한', 1.2388252720392192),
#  ('처리', 1.2381638885979995),
#  ('명의', 1.2332160384368749),
#  ('과정', 1.2280617813746022),
#  ('제주', 1.2209570294867986),
#  ('수지', 1.216552772905389),
#  ('초등학교', 1.2119331543630387),
#  ('보건', 1.2075390797811352),
#  ('쉐보레', 1.1979283303311332),
#  ('오산시', 1.1970477351701834),
#  ('조금', 1.1906979018111707),
#  ('매우', 1.1898697505972515),
#  ('확보', 1.1892988202987156),
#  ('안심', 1.1859564981797157),
#  ('서울시', 1.1843315833614037),
#  ('무관', 1.1832013954516671),
#  ('누구', 1.1800972329768225),
#  ('대회', 1.1796053091747614),
#  ('소방', 1.179308928621185),
#  ('활용', 1.1786650755304384),
#  ('기간', 1.1785774097903365),
#  ('위생', 1.1726055085324187),
#  ('소비자', 1.17069367588525),
#  ('주요', 1.1692675722191246),
#  ('광고', 1.1675786557178192),
#  ('방안', 1.1634881084487665),
#  ('대구', 1.1597099465934582),
#  ('회원', 1.156937812451522),
#  ('시청', 1.1554315418793752),
#  ('수안', 1.1544840709937423),
#  ('팬데믹', 1.1483564591082056),
#  ('남성', 1.1452140853370516),
#  ('운용', 1.1438081212515259),
#  ('교회', 1.142723899476049),
#  ('집콕', 1.1391413912954),
#  ('최대', 1.139089232332406),
#  ('다소', 1.1334782728777382),
#  ('시설', 1.1301706242758214),
#  ('전반', 1.1282214767844823),
#  ('구입', 1.1252280030952142),
#  ('체계', 1.1238917895394314),
#  ('면접', 1.1209374815930913),
#  ('민주당', 1.1204684711137078),
#  ('다시', 1.1204060514601473),
#  ('금은', 1.116881791642391),
#  ('지구', 1.1164009647128128),
#  ('부산', 1.1162449440555793),
#  ('결과', 1.1137510446274286),
#  ('모임', 1.1095496264398728),
#  ('리그', 1.107286543212885),
#  ('준비', 1.1071538306216497),
#  ('전달', 1.1028302775388052),
#  ('행정', 1.1028095321815081),
#  ('매출', 1.1018541720778814),
#  ('전경', 1.1003736964685116),
#  ('성과', 1.098677575767083),
#  ('소득', 1.0968024944180614),
#  ('자료', 1.0966250150662917),
#  ('선정', 1.0916362052948614),
#  ('임상시험', 1.0901975863586013),
#  ('국무회의', 1.0897311052145877),
#  ('뉴시스', 1.0897311052145877),
#  ('독자', 1.0897311052145877),
#  ('임시', 1.0897311052145877),
#  ('제출', 1.0897311052145877),
#  ('확정', 1.0897311052145877),
#  ('소외', 1.0883731874640472),
#  ('마사회', 1.0859108875793353),
#  ('관객', 1.0827683729873012),
#  ('폐기물', 1.0824832942562796),
#  ('대출', 1.0805427602304447),
#  ('감염병', 1.0791607657958737),
#  ('아파트', 1.078807896988592),
#  ('수업', 1.0734786628048243),
#  ('현재', 1.0725814937120342),
#  ('공유', 1.0722791116267576),
#  ('미술', 1.0718829654263415),
#  ('집중', 1.0712091439176608),
#  ('위로', 1.070115943903125),
#  ('보건소', 1.0700349030282033),
#  ('스타', 1.0641470970172606),
#  ('개인', 1.0636375631234816),
#  ('격려', 1.0634235443249194),
#  ('선도', 1.0615218071623025),
#  ('최소', 1.060533051221629),
#  ('촉진', 1.0597252746710382),
#  ('접수', 1.0580240305229314),
#  ('부회장', 1.0519500813202451),
#  ('컨설팅', 1.0507090288034855),
#  ('격리', 1.0495012925147846),
#  ('사례', 1.0487036916028034),
#  ('유지', 1.0486056081131343),
#  ('에너지', 1.0428108169789287),
#  ('범위', 1.0420848369189868),
#  ('본부장', 1.0412332557864834),
#  ('스케', 1.0396008954035378),
#  ('투여', 1.0396008954035378),
#  ('업자', 1.0393593000773953),
#  ('중순', 1.0393308277721072),
#  ('사용', 1.037970391542616),
#  ('치킨', 1.0362931735704777),
#  ('차례', 1.0295853973524483),
#  ('공인', 1.0283908876867107),
#  ('소상', 1.0283908876867107),
#  ('쇼핑', 1.0263805462546804),
#  ('면서', 1.0250358393877739),
#  ('시스템', 1.0231171152292233),
#  ('지사', 1.0208371335746067),
#  ('전쟁', 1.0205531677944928),
#  ('로부터', 1.0193838042435637),
#  ('신동빈', 1.0180146255190659),
#  ('중인', 1.0179712602661493),
#  ('추가', 1.0172252589067359),
#  ('본부', 1.0172015158309098),
#  ('게임', 1.0131180331610925),
#  ('취약', 1.00857126535496),
#  ('기념', 1.0077359791678662),
#  ('원금', 1.006903085397413),
#  ('대책', 1.0046526419469024),
#  ('토트넘', 1.001259055917147),
#  ('등교', 0.9984469750786972),
#  ('구급', 0.9953527276726699),
#  ('차량', 0.9953527276726699),
#  ('중국', 0.9951497216214936),
#  ('기업인', 0.9943780486801688),
#  ('스마트', 0.9914370739806434),
#  ('전남', 0.991069442074523),
#  ('무료', 0.9896000732428619),
#  ('이상', 0.9884309783934844),
#  ('울산', 0.9859700089216292),
#  ('기여', 0.9843902563323468),
#  ('무역', 0.9822003402900301),
#  ('분쟁', 0.9822003402900301),
#  ('시험', 0.9814385356495109),
#  ('생태계', 0.9812527714874886),
#  ('대학', 0.9796719185890824),
#  ('향후', 0.9791983038055542),
#  ('활기', 0.9765091729181317),
#  ('정하영', 0.9729990747471968),
#  ('민원', 0.9723398842822121),
#  ('임종', 0.9706193000111769),
#  ('지연', 0.9692224595745305),
#  ('이사장', 0.9680473207588558),
#  ('대한민국', 0.9650447162242659),
#  ('전염병', 0.9649284704569169),
#  ('대신', 0.961833140348195),
#  ('표고버섯', 0.9597890733962104),
#  ('계속', 0.9568883939846158),
#  ('국제', 0.9530101131886028),
#  ('미추홀', 0.949921258904353),
#  ('착용', 0.9498933390928231),
#  ('일환', 0.9493189263724812),
#  ('스님', 0.9471004565546242),
#  ('하이닉스', 0.9461332519841195),
#  ('시합', 0.944387070633597),
#  ('온택트', 0.9408332827293941),
#  ('형식', 0.9391959253723312),
#  ('강의', 0.9385741888989069),
#  ('인기', 0.9375926978116227),
#  ('개학', 0.9359906935222193),
#  ('신규', 0.9296834261017324),
#  ('개선', 0.9274592293765194),
#  ('긴급', 0.9234984085009412),
#  ('고등학교', 0.9193869867619253),
#  ('부처', 0.9186763851271773),
#  ('방문객', 0.918405191580157),
#  ('조치', 0.9163493885541875),
#  ('상품', 0.914555431000156),
#  ('극장', 0.9130293494136708),
#  ('예년', 0.9117052004980855),
#  ('축구', 0.9108126469759535),
#  ('콘텐츠', 0.910326159788885),
#  ('만하', 0.9102973254109334),
#  ('예술', 0.9095474218442217),
#  ('영업', 0.9090561265674784),
#  ('중소기업', 0.9042451191124719),
#  ('이동', 0.9011328193668642),
#  ('비롯', 0.900231436966965),
#  ('농촌', 0.8964990521152989),
#  ('기획', 0.8953928077792229),
#  ('주민', 0.8951912994452903),
#  ('반영', 0.8944762645099735),
#  ('덕분', 0.8943006723095327),
#  ('회복', 0.8933502357708594),
#  ('경영', 0.8920579733262133),
#  ('식품', 0.8907420419990361),
#  ('로서', 0.8881060369117602),
#  ('책임감', 0.8881060369117602),
#  ('구축', 0.8851356909398278),
#  ('해결', 0.8831223062975259),
#  ('이익', 0.8823298773436449),
#  ('민생', 0.8793528170351432),
#  ('체온', 0.8749651639292767),
#  ('공사', 0.8717334998794862),
#  ('수행', 0.8674856864366862),
#  ('인원', 0.867223213747494),
#  ('위원장', 0.8665338618393437),
#  ('음압', 0.8612429825570596),
#  ('화천군', 0.8612429825570596),
#  ('효율', 0.8610594384168782),
#  ('관악구', 0.8595163000135813),
#  ('국난', 0.8593931426035473),
#  ('농협', 0.8589152389643443),
#  ('보험', 0.8589152389643443),
#  ('손해', 0.8589152389643443),
#  ('교육비', 0.8587075909200496),
#  ('학부모', 0.8587075909200496),
#  ('돕기', 0.8579836703795088),
#  ('도시', 0.8573954082066596),
#  ('충남', 0.8549143376579744),
#  ('수원시', 0.8547308091519672),
#  ('문의', 0.8522517008548873),
#  ('가격', 0.8514148241327799),
#  ('과학기술', 0.8512662365658501),
#  ('신문', 0.8497361237301113),
#  ('위원회', 0.8487324695808425),
#  ('수혜', 0.8472437953502969),
#  ('별도', 0.846888949438663),
#  ('청사', 0.8467908393196624),
#  ('공무원', 0.8453464624143351),
#  ('축소', 0.8433317983223989),
#  ('이미지', 0.8411007035759084),
#  ('제보', 0.8405222041130957),
#  ('가장', 0.8387590224355723),
#  ('화훼농', 0.8386311208736235),
#  ('판단', 0.8384962123579869),
#  ('면세점', 0.8382431561016908),
#  ('단계', 0.8380440979089172),
#  ('다단계', 0.8365159397509988),
#  ('당면', 0.8359922718938286),
#  ('소통', 0.8355652758462019),
#  ('특강', 0.8355652758462019),
#  ('분석', 0.8346321378793431),
#  ('공급', 0.832998870380721),
#  ('주간', 0.8328674705562948),
#  ('모델', 0.8314870513296132),
#  ('출시', 0.8305976772316677),
#  ('양사', 0.8302896932197669),
#  ('축산물', 0.830259530180005),
#  ('매년', 0.8278941178697744),
#  ('시상식', 0.8277532522994903),
#  ('호국', 0.8276141968974288),
#  ('강조', 0.8274967981887287),
#  ('한우', 0.8249931320481197),
#  ('해외여행', 0.8249380567734678),
#  ('재난', 0.8248823136501433),
#  ('안양시', 0.8243388070715578),
#  ('주식', 0.8209226245635632),
#  ('송하진', 0.8187954368842851),
#  ('희망', 0.8158094896071816),
#  ('해법', 0.8134630619099554),
#  ('방법', 0.8128677285921395),
#  ('업체', 0.8120822409544142),
#  ('실험', 0.8105572139015329),
#  ('갈등', 0.8082565163168635),
#  ('센터', 0.8068019693586079),
#  ('지점', 0.8058556784307622),
#  ('패션', 0.8051214823701157),
#  ('물품', 0.8042362568049519),
#  ('역할', 0.7999474144304082),
#  ('세계보건기구', 0.7998187117219268),
#  ('자원', 0.7984232789505495),
#  ('우려', 0.7952916531937664),
#  ('이자', 0.7943687912466875),
#  ('물류', 0.7910091747681296),
#  ('업종', 0.7908249010265697),
#  ('성금', 0.7908029019331463),
#  ('의미', 0.7901337434478349),
#  ('당부', 0.7900440809630485),
#  ('사무', 0.7869626820991082),
#  ('총장', 0.7869626820991082),
#  ('국내외', 0.7852215967115592),
#  ('인공', 0.785079832487589),
#  ('지능', 0.785079832487589),
#  ('여수시', 0.7843491392020292),
#  ('당초', 0.7824902898237616),
#  ('현상', 0.78208900258368),
#  ('베트남', 0.7813448126750486),
#  ('예약', 0.7810944933329385),
#  ('청와대', 0.7776681765876194),
#  ('발표', 0.7772387745734128),
#  ('담당자', 0.777079889991525),
#  ('카드', 0.7766003082591595),
#  ('더위', 0.7764634349797658),
#  ('김경준', 0.7705818269791596),
#  ('딜로이트', 0.7705818269791596),
#  ('요청', 0.7695185115317675),
#  ('자영', 0.7665464123643726),
#  ('쓰기', 0.7610084785127134),
#  ('제품', 0.7602631136873855),
#  ('근로자', 0.7602243863214209),
#  ('병행', 0.7598439143484472),
#  ('걱정', 0.7577869589004693),
#  ('경로', 0.7574868509453527),
#  ('일본', 0.7546436250992908),
#  ('여건', 0.753641987149446),
#  ('박순', 0.7523178979910539),
#  ('상담', 0.7519241815138371),
#  ('위치', 0.7482790502996226),
#  ('전기차', 0.7456080321023058),
#  ('담당', 0.743450773776401),
#  ('정상회담', 0.7431522122660581),
#  ('확장', 0.7431522122660581),
#  ('분기', 0.7423207415571632),
#  ('표시', 0.7408138926763652),
#  ('이어진', 0.7406757944878053),
#  ('청년', 0.7388211194566581),
#  ('종합', 0.7387116070812714),
#  ('김포시', 0.7373989520880299),
#  ('시계', 0.7338314647002708),
#  ('중앙', 0.7336497337348721),
#  ('재고', 0.7333116823250595),
#  ('자연재해', 0.7316486765299577),
#  ('불리', 0.731004003439444),
#  ('실적', 0.7306885545750041),
#  ('용품', 0.7296976148560289),
#  ('데이터', 0.7283189806202626),
#  ('참여자', 0.7281429448284977),
#  ('경주시', 0.7277037291290993),
#  ('협업', 0.7271428489256075),
#  ('교육청', 0.7263007744702961),
#  ('일시', 0.7255780480475204),
#  ('본사', 0.7249204692106761),
#  ('청장', 0.7245865868974821),
#  ('외국인', 0.7245426553042489),
#  ('제시', 0.7241781850192162),
#  ('교육과정평가원', 0.7240988634526317),
#  ('그간', 0.7240988634526317),
#  ('능력', 0.7240988634526317),
#  ('모의', 0.7240988634526317),
#  ('수학', 0.7240988634526317),
#  ('주관', 0.7240988634526317),
#  ('장관', 0.722574337674935),
#  ('타격', 0.7213464178864475),
#  ('대면', 0.7205721532234886),
#  ('가구', 0.7203278828152858),
#  ('규제', 0.7174438542063226),
#  ('제한', 0.7171089613501207),
#  ('출입', 0.7165713436293244),
#  ('에듀', 0.7163933043126877),
#  ('사장', 0.7162445221689512),
#  ('형구', 0.7162445221689512),
#  ('급변', 0.7158953829484072),
#  ('팩토리', 0.7151337673204232),
#  ('수출', 0.7147159389017897),
#  ('봉행', 0.7136066770890659),
#  ('일과', 0.7113804642672026),
#  ('그린', 0.7079378408509158),
#  ('상공', 0.706965853134581),
#  ('편성', 0.7055951940841965),
#  ('뮤지션', 0.7053587995406629),
#  ('자연', 0.7041785001629745),
#  ('지식', 0.7023652578111139),
#  ('보장', 0.700888529911257),
#  ('경관', 0.7001749127120069),
#  ('정말', 0.7000038770974039),
#  ('지정', 0.6995374249032775),
#  ('버섯', 0.6992267184401055),
#  ('비용', 0.6990280281445265),
#  ('여러', 0.6987290587621149),
#  ('연장', 0.6971245116510547),
#  ('정보', 0.695994110933728),
#  ('치유', 0.6955659680010393),
#  ('장비', 0.6947901592329593),
#  ('생계', 0.6945378872029805),
#  ('최초', 0.6900525199279951),
#  ('피해', 0.6871809108374459),
#  ('다음', 0.6867127535596089),
#  ('일손', 0.6856437231404711),
#  ('인테리어', 0.6846301003732072),
#  ('제주도', 0.6818424331796796),
#  ('불어', 0.6809213408599067),
#  ('김대환', 0.6790437337880877),
#  ('회사', 0.6769267675665704),
#  ('이송', 0.6762763746218701),
#  ('전문가', 0.6759895014263534),
#  ('조사', 0.6753974187164146),
#  ('전자', 0.6727560913368912),
#  ('역시', 0.6699300664178899),
#  ('완화', 0.6698813616633779),
#  ('대구시', 0.6691663951567504),
#  ('상원', 0.6691663951567504),
#  ('달라', 0.6666421274546405),
#  ('가', 0.6654701636753543),
#  ('제조', 0.664989928636344),
#  ('상승', 0.6629053536497591),
#  ('달서구', 0.661309083090175),
#  ('충격', 0.661272069952039),
#  ('화제', 0.6560732074243877),
#  ('나눔', 0.6552755947150627),
#  ('통영시', 0.65426186212229),
#  ('전체', 0.6539086007791018),
#  ('이제', 0.6536161096551836),
#  ('방문자', 0.6530306377427917),
#  ('외식', 0.6515638519008995),
#  ('이해', 0.6483259037675617),
#  ('가속', 0.6480227786923315),
#  ('경북', 0.6476135549161006),
#  ('이웃', 0.6472925292913605),
#  ('예산', 0.6467557803931057),
#  ('안정감', 0.6432865628868791),
#  ('사회보장', 0.6416656711410414),
#  ('어르신', 0.6416656711410414),
#  ('교육감', 0.6354260342505712),
#  ('이벤트', 0.6351719010646999),
#  ('케어', 0.6338121976188889),
#  ('확인', 0.6335514730710952),
#  ('하나', 0.6323830792801771),
#  ('회의', 0.6321773429658344),
#  ('모바일', 0.6277755227059278),
#  ('상당', 0.6264990704832342),
#  ('톱텍', 0.6258392146298841),
#  ('노비', 0.624269877528701),
#  ('애플', 0.6236467062726747),
#  ('점검', 0.6221519634077954),
#  ('증진', 0.6209039808169754),
#  ('그동안', 0.6199719568871955),
#  ('먼저', 0.6186344889655055),
#  ('개방', 0.6182367472794346),
#  ('손길', 0.6180418057028874),
#  ('의견', 0.6172596347448445),
#  ('필요성', 0.6168196996162965),
#  ('인식', 0.6164713853390125),
#  ('중요성', 0.6162503895223099),
#  ('커뮤니케이션', 0.615964137911123),
#  ('잠재력', 0.614292448519446),
#  ('구현', 0.6141041251675277),
#  ('도면', 0.6141041251675277),
#  ('타인', 0.6141041251675277),
#  ('시행', 0.6136875114900694),
#  ('지급', 0.6128874601034918),
#  ('브리핑', 0.611881283121686),
#  ('산시', 0.6092484448653823),
#  ('남훈', 0.6091144458067166),
#  ('일부', 0.6091144458067166),
#  ('녹지', 0.6078580411603689),
#  ('오늘', 0.607844269541362),
#  ('특성', 0.6037856974810684),
#  ('충남도', 0.6020027647704737),
#  ('집합', 0.6014241880571947),
#  ('매일', 0.5996338421339898),
#  ('참석자', 0.5994587650769942),
#  ('선수금', 0.5989641651655666),
#  ('히어로', 0.5989641651655666),
#  ('사안', 0.5987725543174853),
#  ('세상', 0.5985032565821423),
#  ('측정', 0.5981210004806676),
#  ('이하', 0.5968109799668584),
#  ('허브', 0.5966690058490314),
#  ('효과', 0.5953757451451248),
#  ('소개', 0.5941089608407945),
#  ('의회', 0.5931675099387821),
#  ('생각', 0.5925763521182761),
#  ('최고', 0.5916957316910589),
#  ('기본', 0.5901513094146632),
#  ('급증', 0.5899339651269935),
#  ('대우', 0.5888599844269053),
#  ('대통령', 0.5876785068038808),
#  ('협조', 0.5869373052569367),
#  ('동부', 0.5859698595380121),
#  ('참석', 0.5859596955591779),
#  ('전하', 0.5846584725520068),
#  ('단절', 0.5845714845104137),
#  ('감상', 0.5840513890521306),
#  ('감성', 0.5840513890521306),
#  ('정기', 0.5840513890521306),
#  ('목표', 0.5834670068922208),
#  ('추이', 0.5830637971315664),
#  ('추가경정예산', 0.5809775020688144),
#  ('신청', 0.5798937226506156),
#  ('김정희', 0.5797542673546182),
#  ('동아오츠카', 0.5797542673546182),
#  ('스웨', 0.5797542673546182),
#  ('동선', 0.5791106664549404),
#  ('치과의사', 0.578890961903127),
#  ('테마', 0.577455980150337),
#  ('동월', 0.5774463047320266),
#  ('대중교통', 0.5771169326581427),
#  ('스스로', 0.5771169326581427),
#  ('크기', 0.5771169326581427),
#  ('기후', 0.5761895844909977),
#  ('녹색', 0.5761895844909977),
#  ('분류', 0.574294103931098),
#  ('여성', 0.5740491314852751),
#  ('주가', 0.5727007997459178),
#  ('복지부', 0.5726012294337894),
#  ('질병', 0.5726012294337894),
#  ('장애인', 0.5711521304357294),
#  ('클럽', 0.57033387462909),
#  ('교육지원청', 0.5702239516157943),
#  ('부쩍', 0.5682138179351865),
#  ('도지사', 0.5653807136097406),
#  ('조기', 0.5627695751741496),
#  ('각지', 0.5615646466728745),
#  ('간식', 0.5615646466728745),
#  ('메뉴인', 0.5615646466728745),
#  ('분투', 0.5615646466728745),
#  ('크리스', 0.5615646466728745),
#  ('성장', 0.5609761015441304),
#  ('농민', 0.5606930326583178),
#  ('완료', 0.5599417882494211),
#  ('수여', 0.5586074770425676),
#  ('청소년', 0.5586074770425676),
#  ('토요일', 0.5586074770425676),
#  ('표창장', 0.5586074770425676),
#  ('기리', 0.5583128691820283),
#  ('영령', 0.5583128691820283),
#  ('추념', 0.5571811879133777),
#  ('현충일', 0.5571811879133777),
#  ('부장', 0.5550927248995402),
#  ('간소화', 0.5513093836254039),
#  ('년도', 0.5513093836254039),
#  ('우리나라', 0.5506112945898539),
#  ('기록', 0.5487491966437043),
#  ('전망', 0.548028072443592),
#  ('과장', 0.5463547617526644),
#  ('대가', 0.5463547617526644),
#  ('디딤돌', 0.5463547617526644),
#  ('생애', 0.5463547617526644),
#  ('요양보호사', 0.5463547617526644),
#  ('일자리', 0.5463547617526644),
#  ('중장', 0.5463547617526644),
#  ('출발', 0.5463547617526644),
#  ('취업', 0.5463547617526644),
#  ('각종', 0.5458955952291673),
#  ('노하우', 0.5456102815371418),
#  ('투입', 0.5453906460806137),
#  ('의견청취', 0.5450316925910308),
#  ('전세계', 0.5419498372830488),
#  ('여수', 0.5413659380169364),
#  ('연구', 0.5409345844789935),
#  ('김돈', 0.5405388839179802),
#  ('문화생활', 0.5405388839179802),
#  ('방침', 0.5405388839179802),
#  ('영위', 0.5405388839179802),
#  ('창의', 0.5405388839179802),
#  ('광주', 0.5404112519125696),
#  ('조성', 0.5398826527036484),
#  ('수준', 0.5393647398482477),
#  ('로스', 0.5386373700965146),
#  ('현대', 0.5338452575925252),
#  ('인재', 0.5316395975451816),
#  ('번호', 0.5315986032981919),
#  ('당국', 0.5309617839322689),
#  ('흐름', 0.5296357043941016),
#  ('적자', 0.5296125336031645),
#  ('내외', 0.5294799375072246),
#  ('김윤욱', 0.5265700689193212),
#  ('체결', 0.5259992459113914),
#  ('추경', 0.5234853409680974),
#  ('우선', 0.5221064612548451),
#  ('김상철', 0.5220582724147634),
#  ('레퍼런스', 0.5220582724147634),
#  ('사물인터넷', 0.5220582724147634),
#  ('사용자', 0.5220582724147634),
#  ('산업혁명', 0.5220582724147634),
#  ('솔루션', 0.5220582724147634),
#  ('한컴', 0.5220582724147634),
#  ('수익', 0.5211629683656416),
#  ('현황', 0.5186848207148576),
#  ('대외', 0.5170226078450869),
#  ('연구원', 0.5170226078450869),
#  ('육성', 0.514890173798814),
#  ('조합', 0.5148816209588554),
#  ('최적', 0.5148816209588554),
#  ('구독', 0.5145468440902172),
#  ('매달', 0.5145468440902172),
#  ('물건', 0.5145468440902172),
#  ('신한카드', 0.5145468440902172),
#  ('원스', 0.5145468440902172),
#  ('특화', 0.5145468440902172),
#  ('대처', 0.5118313570116946),
#  ('모든', 0.5118313570116946),
#  ('밤낮없이', 0.5118313570116946),
#  ('헌신', 0.5118313570116946),
#  ('주주', 0.5114495071176376),
#  ('로봇', 0.5079878173207066),
#  ('기존', 0.5062787739388646),
#  ('인천', 0.5042858664034272),
#  ('통상', 0.5040469054758073),
#  ('결합', 0.496922874742852),
#  ('필수', 0.49502556846382184),
#  ('서울대', 0.49291118774713455),
#  ('민간', 0.4928917051544919),
#  ('동시', 0.4908043874781155),
#  ('화훼', 0.49061946132552087),
#  ('교육과정', 0.4903776141569086),
#  ('대상자', 0.4903776141569086),
#  ('특수교육', 0.4903776141569086),
#  ('감소', 0.48914054400917306),
#  ('계약', 0.4887394592932327),
#  ('연구소', 0.4887394592932327),
#  ('서서히', 0.48825458645906583),
#  ('나은', 0.4874141862824788),
#  ('실무', 0.4874141862824788),
#  ('유엔', 0.4874141862824788),
#  ('재건', 0.4874141862824788),
#  ('안성', 0.4866535108532254),
#  ('공공시설', 0.4858378878830509),
#  ('금번', 0.4858378878830509),
#  ('재개', 0.4858378878830509),
#  ('파악', 0.4794829670518773),
#  ('곽상욱', 0.47855047331645145),
#  ('수상', 0.47855047331645145),
#  ('영세', 0.47855047331645145),
#  ('남악', 0.47594089672313217),
#  ('맞이', 0.47594089672313217),
#  ('무안', 0.47594089672313217),
#  ('무안군', 0.47594089672313217),
#  ('창문', 0.47594089672313217),
#  ('친구', 0.47594089672313217),
#  ('가량', 0.47592256718772247),
#  ('누리', 0.47592256718772247),
#  ('무렵', 0.47592256718772247),
#  ('보수', 0.47592256718772247),
#  ('유동성', 0.47592256718772247),
#  ('은행권', 0.47592256718772247),
#  ('번홀', 0.4749818326758342),
#  ('서귀포', 0.4749818326758342),
#  ('스카이', 0.4749818326758342),
#  ('여자오픈', 0.4749818326758342),
#  ('칸타타', 0.4749818326758342),
#  ('어제', 0.4747797270657949),
#  ('강제', 0.4744058658035585),
#  ('고조', 0.4744058658035585),
#  ('더구나', 0.4744058658035585),
#  ('징용', 0.4744058658035585),
#  ('찾기', 0.4744058658035585),
#  ('한일', 0.4744058658035585),
#  ('정문', 0.4721935353167985),
#  ('우수', 0.4656576167163109),
#  ('소재', 0.46463554479861535),
#  ('인력', 0.4645786009909628),
#  ('입국', 0.4645786009909628),
#  ('도내', 0.46129359992057817),
#  ('관람', 0.4565146747068354),
#  ('김정식', 0.4565146747068354),
#  ('돌체', 0.4565146747068354),
#  ('스토리', 0.4565146747068354),
#  ('재즈', 0.4565146747068354),
#  ('최용민', 0.4565146747068354),
#  ('학산', 0.4565146747068354),
#  ('구직', 0.4553297623299169),
#  ('박람회', 0.4553297623299169),
#  ('생중계', 0.4553297623299169),
#  ('엔카', 0.4553297623299169),
#  ('화상', 0.4553297623299169),
#  ('제안', 0.452476394848476),
#  ('금리', 0.4521225595562359),
#  ('양승조', 0.4514372389098291),
#  ('중학교', 0.4434918260823084),
#  ('기적', 0.43402337548579734),
#  ('리포트', 0.43402337548579734),
#  ('모니터링', 0.43402337548579734),
#  ('적시성', 0.43402337548579734),
#  ('부사', 0.42945761948217215),
#  ('반환', 0.4293537954600248),
#  ('학비', 0.4293537954600248),
#  ('김용찬', 0.4274571688289872),
#  ('빛낼', 0.4274571688289872),
#  ('자긍심', 0.4274571688289872),
#  ('행정부', 0.4274571688289872),
#  ('개월', 0.4249079511541558),
#  ('검역', 0.4249079511541558),
#  ('오브', 0.4249079511541558),
#  ('일간', 0.4249079511541558),
#  ('입항', 0.4249079511541558),
#  ('퀀텀', 0.4249079511541558),
#  ('크루즈선', 0.4249079511541558),
#  ('특별', 0.4249079511541558),
#  ('항만', 0.4249079511541558),
#  ('공익', 0.4202611020565479),
#  ('도민', 0.4202611020565479),
#  ('서면', 0.4202611020565479),
#  ('위법', 0.4202611020565479),
#  ('주안', 0.4202611020565479),
#  ('추진단', 0.4202611020565479),
#  ('핫라인', 0.4202611020565479),
#  ('기미', 0.4191215780508454),
#  ('나선', 0.4191215780508454),
#  ('보이지', 0.4191215780508454),
#  ('본점', 0.4191215780508454),
#  ('신라', 0.4191215780508454),
#  ('유급', 0.4191215780508454),
#  ('인건비', 0.4191215780508454),
#  ('절감', 0.4191215780508454),
#  ('휴직', 0.4191215780508454),
#  ('발판', 0.41248965254683767),
#  ('공적', 0.40462063018389877),
#  ('물량', 0.40462063018389877),
#  ('비축', 0.40462063018389877),
#  ('자체', 0.40462063018389877),
#  ('등락', 0.39266095802),
#  ('설정', 0.39266095802),
#  ('점화', 0.39266095802),
#  ('주식시장', 0.39266095802),
#  ('직후', 0.39266095802),
#  ('군포시', 0.39189048072672356),
#  ('파주', 0.39189048072672356),
#  ('판매원', 0.39189048072672356),
#  ('공식', 0.3819992501541536),
#  ('발굴', 0.3581222610844756),
#  ('시국', 0.3581222610844756)]

# %%
## 차트 라이브러리 사용등록
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 차트 그릴때마다 계속 실행하면 한글깨짐이나 오류 현상 발생 가능성이 높음
sns.set_style('darkgrid')

# %%
# 불필요한 경고메시지 제거
import warnings
warnings.filterwarnings('ignore')

# %%
# 한글깨짐 문제 해결
from matplotlib import rcParams, font_manager, rc

font_path = '/Users/gukjinhan/Library/Fonts/NanumGothicCoding-Bold.ttf' # 나눔고딕 코딩사용
font = font_manager.FontProperties(fname=font_path).get_name() # 실제 설치된 폰트 이름 조회
rc('font', family = font) # 한글깨짐현상 해결!
rcParams['axes.unicode_minus'] = False # 한글 사용 시 마이너스 표시 깨짐 해결!

# %%
max = 15
plt.figure(figsize=(15,5))
plt.bar(range(max),[i[1] for i in posWords[:max]], color = 'green')
plt.title('네이버 긍정뉴스 단어 상위 15위', fontsize=14)
plt.xlabel('단어', fontsize=12)
plt.ylabel('빈도수')
# x축 단어 표시
plt.xticks(range(max), [i[0] for i in posWords[:max]], rotation=50)

plt.show()
